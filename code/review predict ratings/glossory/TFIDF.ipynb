# %% [markdown]
# ## Read first 10000 rows from json file

# %%
import json
import pandas as pd
def read_json_nrows(nrows,filename):
    n= 0
    with open(filename) as f:
        while n < nrows:
            if n == 0:
                line = f.readline()
                line = json.loads(line.rstrip())
                train = pd.DataFrame(line,index = [0])
            else:
                temp = pd.DataFrame(json.loads(f.readline().rstrip()),index = [n])
                train = train.append(temp)
            n = n+1
    return train

# %%
train_10000 = read_json_nrows(10000,'review_train.json')

# %%
train_10000.head(5)
# Out:
#    business_id  stars                                               text  \
# 0        31292    1.0  Total bill for this horrible service? Over $8G...
# 1        35344    5.0  I *adore* Travis at the Hard Rock's new Kelly ...
# 2       152538    5.0  I have to say that this office really has it t...
# 3        71871    5.0  Went in for a lunch. Steak sandwich was delici...
# 4        64913    1.0  Today was my second out of three sessions I ha...
#
#                   date
# 0  2013-05-07 04:34:36
# 1  2017-01-14 21:30:33
# 2  2016-11-09 20:09:03
# 3  2018-01-09 20:56:38
# 4  2018-01-30 23:07:38

# %% [markdown]
# ## Cleaning data

# %%
from collections import Counter
from nltk.util import ngrams
import re
import numpy as np 
from nltk.corpus import words
from nltk.corpus import brown
from nltk.corpus import wordnet
from nltk import wordpunct_tokenize

# %% [markdown]
# ### Languages

# %% [markdown]
# When I first tried to apply the *detect* function I got a 'No features in text' error. So I have to find out which review is empty.

# %%
train_10000.loc[6687]
# Out:
# business_id                 137207
# stars                            1
# text                            :(
# date           2017-07-18 20:31:03
# Name: 6687, dtype: object

# %% [markdown]
# This review is not language, but an emoticon.

# %%
def not_language(text):
    # First delete all common emoticons.
    text = re.sub('(?::|;|=)(?:-)?(?:\)|\(|D|P)','',text)
    if re.sub('[\W]+','',text) == '':
        return True
    else:
        return False

# %% [markdown]
# For simplicity, just consider emoticons as English.

# %%
not_lang = train_10000[train_10000.text.apply(not_language)].index.values

# %%
train_10000.loc[not_lang,'lang_type'] = 'english'

# %% [markdown]
# from nltk.corpus import stopwords
# from nltk import wordpunct_tokenize
# languages_ratios = {}
# for i in range(10000):
#     tokens = wordpunct_tokenize(train_10000.text[i])
#     words = [word.lower() for word in tokens]
#     for language in stopwords.fileids():
#         stopwords_set = set(stopwords.words(language))
#         words_set = set(words)
#         common_elements = words_set.intersection(stopwords_set)
#         languages_ratios[language] = len(common_elements)
#     most_rated_language = max(languages_ratios, key=languages_ratios.get)
#     train_10000.loc[i,'lang_type'] = most_rated_language

# %%
from langdetect import detect
for i in range(10000):
    if i in not_lang:
        continue
    else:
        train_10000.loc[i,'lang_type'] = detect(train_10000.text[i])

# %%
re.findall(':[\W]{0,1}',':(nmsl')
# Out:
# [':(']

# %%
train_10000.lang_type.value_counts()
# Out:
# en         9956
# fr           37
# es            3
# english       1
# it            1
# ja            1
# de            1
# Name: lang_type, dtype: int64

# %% [markdown]
# Focus on English only at present.

# %%
train_10000_eng = train_10000[train_10000.lang_type == 'en']

# %% [markdown]
# Most common words and phrases.

# %%
text = ' '.join(train_10000_eng.text.values)
text_trigrams = [i for i in ngrams(text.split(), 1)]
Counter(text_trigrams).most_common(20)
# Out:
# [(('the',), 43484),
#  (('and',), 36445),
#  (('I',), 27219),
#  (('a',), 26196),
#  (('to',), 25807),
#  (('was',), 18766),
#  (('of',), 15249),
#  (('is',), 12814),
#  (('for',), 12221),
#  (('in',), 11026),
#  (('it',), 9188),
#  (('The',), 9180),
#  (('with',), 8640),
#  (('my',), 8424),
#  (('that',), 8146),
#  (('but',), 7072),
#  (('on',), 7003),
#  (('have',), 6583),
#  (('you',), 6540),
#  (('this',), 6388)]

# %%
text = ' '.join(train_10000_eng.text.values)
text_trigrams = [i for i in ngrams(text.split(), 2)]
Counter(text_trigrams).most_common(20)
# Out:
# [(('of', 'the'), 3443),
#  (('and', 'the'), 2772),
#  (('in', 'the'), 2722),
#  (('it', 'was'), 2336),
#  (('I', 'was'), 2307),
#  (('on', 'the'), 2107),
#  (('and', 'I'), 2017),
#  (('to', 'the'), 1836),
#  (('for', 'the'), 1732),
#  (('for', 'a'), 1732),
#  (('I', 'had'), 1559),
#  (('I', 'have'), 1490),
#  (('is', 'a'), 1378),
#  (('to', 'be'), 1358),
#  (('was', 'a'), 1313),
#  (('this', 'place'), 1278),
#  (('with', 'the'), 1262),
#  (('at', 'the'), 1245),
#  (('with', 'a'), 1216),
#  (('to', 'get'), 1206)]

# %%
text = ' '.join(train_10000_eng.text.values)
text_trigrams = [i for i in ngrams(text.split(), 3)]
Counter(text_trigrams).most_common(20)
# Out:
# [(('and', 'it', 'was'), 516),
#  (('one', 'of', 'the'), 451),
#  (('a', 'lot', 'of'), 392),
#  (('I', 'had', 'the'), 338),
#  (('This', 'place', 'is'), 316),
#  (('I', 'have', 'been'), 265),
#  (('I', 'had', 'to'), 262),
#  (('the', 'food', 'was'), 254),
#  (('I', 'ordered', 'the'), 247),
#  (('it', 'was', 'a'), 244),
#  (('of', 'the', 'best'), 239),
#  (('The', 'food', 'was'), 237),
#  (('I', 'had', 'a'), 236),
#  (('some', 'of', 'the'), 206),
#  (('The', 'food', 'is'), 199),
#  (('this', 'place', 'is'), 198),
#  (('The', 'service', 'was'), 187),
#  (('the', 'food', 'is'), 187),
#  (('to', 'get', 'a'), 182),
#  (('This', 'is', 'a'), 181)]

# %%
text = ' '.join(train_10000_eng.text.values)
text_trigrams = [i for i in ngrams(text.split(), 4)]
Counter(text_trigrams).most_common(20)
# Out:
# [(('one', 'of', 'the', 'best'), 126),
#  (('My', 'husband', 'and', 'I'), 88),
#  (('I', 'will', 'definitely', 'be'), 77),
#  (('is', 'one', 'of', 'the'), 73),
#  (('the', 'end', 'of', 'the'), 67),
#  (('in', 'the', 'middle', 'of'), 65),
#  (('for', 'the', 'first', 'time'), 65),
#  (('a', 'great', 'place', 'to'), 62),
#  (('some', 'of', 'the', 'best'), 60),
#  (('and', 'the', 'service', 'was'), 56),
#  (('you', 'are', 'looking', 'for'), 55),
#  (('was', 'one', 'of', 'the'), 54),
#  (('and', 'the', 'food', 'was'), 53),
#  (('I', 'have', 'to', 'say'), 52),
#  (('My', 'wife', 'and', 'I'), 50),
#  (('and', 'the', 'food', 'is'), 50),
#  (('was', 'my', 'first', 'time'), 49),
#  (('one', 'of', 'my', 'favorite'), 49),
#  (('the', 'rest', 'of', 'the'), 48),
#  (('I', "can't", 'wait', 'to'), 47)]

# %% [markdown]
# Oddest words

# %%
text = ' '.join(train_10000_eng.text.values)
text_trigrams = [i for i in ngrams(text.split(), 1)]
Counter(text_trigrams).most_common()[-500:]
# Out:
# [(('qualified,',), 1),
#  (('exuded',), 1),
#  (("'cool'",), 1),
#  (('Danny.',), 1),
#  (('accord',), 1),
#  (('b-day.',), 1),
#  (('Terroni.',), 1),
#  (('raptor',), 1),
#  (('flats',), 1),
#  (('gripe...no',), 1),
#  (('GPS?',), 1),
#  (('yardage',), 1),
#  (('caliber,',), 1),
#  (('troon',), 1),
#  (('Quintero',), 1),
#  (('parking....my',), 1),
#  (('pefect',), 1),
#  (('Dewy',), 1),
#  (('appoinment,',), 1),
#  (('in...)',), 1),
#  (('HVAC/Electrical/etc...',), 1),
#  (('electrical....(I',), 1),
#  (('NHW',), 1),
#  (('compressor',), 1),
#  (('verified',), 1),
#  (('TUESDAY',), 1),
#  (('compressor....',), 1),
#  (('occasions....',), 1),
#  (('SH!*',), 1),
#  (('Moe',), 1),
#  (('matted',), 1),
#  (('Choosing',), 1),
#  (('changing,',), 1),
#  (('eats!',), 1),
#  (('loong',), 1),
#  (('lo-mean,',), 1),
#  (('Discovered',), 1),
#  (('Beach.',), 1),
#  (('Thrilled',), 1),
#  (('favs:',), 1),
#  (('DELISH!)',), 1),
#  (('is..',), 1),
#  (('Woo',), 1),
#  (('Che.',), 1),
#  (('grilles,',), 1),
#  (('bugogi',), 1),
#  (('thicker,',), 1),
#  (('Louie,',), 1),
#  (('hmmm,',), 1),
#  (('names),',), 1),
#  (("'flatbread'",), 1),
#  (("'tacos',",), 1),
#  (('specialized?',), 1),
#  (("'asian",), 1),
#  (("sauce',",), 1),
#  (("'12'",), 1),
#  (("'5',",), 1),
#  (('singing,',), 1),
#  (("'it",), 1),
#  (("somewhere',",), 1),
#  (("'let's",), 1),
#  (("drink'!",), 1),
#  (('hoopla',), 1),
#  (('pedestrians.',), 1),
#  (('t.o.',), 1),
#  (('piazza...might',), 1),
#  (('cobblestones',), 1),
#  (('though...better',), 1),
#  (('distillery.',), 1),
#  (('food/drinks',), 1),
#  (('scoreboard',), 1),
#  (('keeps!',), 1),
#  (('amusing',), 1),
#  (('experience.Ordered',), 1),
#  (('Yada.',), 1),
#  (('Dina',), 1),
#  (('Yemen',), 1),
#  (('master.',), 1),
#  (('Samples',), 1),
#  (('EZMart',), 1),
#  (('Ames.',), 1),
#  (('saxby',), 1),
#  (('denizens',), 1),
#  (('bodied',), 1),
#  (('A+++',), 1),
#  (('Ultra',), 1),
#  (('Cooling.',), 1),
#  (('&Pylte',), 1),
#  (('YUMMMMMMMMMMMMMMMMM',), 1),
#  (('consumer.',), 1),
#  (('finish...',), 1),
#  (('Africa..."',), 1),
#  (('"famous".',), 1),
#  (('zagat',), 1),
#  (('exaggerated',), 1),
#  (('Dor-Stop.',), 1),
#  (('incredible?',), 1),
#  (('jumbot,',), 1),
#  (('verbally.',), 1),
#  (('catch.',), 1),
#  (('flavor/seasoning',), 1),
#  (('(tasted',), 1),
#  (('powder-based).',), 1),
#  (('wetter',), 1),
#  (('scrambled.',), 1),
#  (('Edmonton,',), 1),
#  (('MEH.',), 1),
#  (('advantage)',), 1),
#  (('"Hi"',), 1),
#  (('you?")',), 1),
#  (('thrusting',), 1),
#  (('fliers',), 1),
#  (('WITNESSED',), 1),
#  (('guarentee',), 1),
#  (('drummed',), 1),
#  (('expire).',), 1),
#  (('cringing',), 1),
#  (('sip).',), 1),
#  (('GOING',), 1),
#  (('distractions)',), 1),
#  (('13/30',), 1),
#  (('Froyo',), 1),
#  (('Kokomo.',), 1),
#  (('networking',), 1),
#  (('colleagues!',), 1),
#  (('sport.',), 1),
#  (('Hotels.com',), 1),
#  (('CPKs,',), 1),
#  (('top-of-the-line',), 1),
#  (('strip-center',), 1),
#  (('(save',), 1),
#  (('cleanest',), 1),
#  (('cooked.Not',), 1),
#  (('Before,',), 1),
#  (('"French',), 1),
#  (('Grocery"',), 1),
#  (('"French",',), 1),
#  (('"Grocery"',), 1),
#  (('tostadas.',), 1),
#  (('chef!!',), 1),
#  (('antipasta.',), 1),
#  (('waiter"Jordan"',), 1),
#  (('Hawaii?',), 1),
#  (('mega-bucks,',), 1),
#  (('Franklin',), 1),
#  (('Crafts,',), 1),
#  (('Wal-Mart',), 1),
#  (('crafter',), 1),
#  (('Oahu',), 1),
#  (('California:',), 1),
#  (('beads,',), 1),
#  (('baubles,',), 1),
#  (('frames,',), 1),
#  (('Franklin,',), 1),
#  (('cashieer',), 1),
#  (('super-friendly',), 1),
#  (('cafe~',), 1),
#  (('Coffees,',), 1),
#  (('well~',), 1),
#  (('"minor"',), 1),
#  (('$54',), 1),
#  (('skyrocket',), 1),
#  (('15-18',), 1),
#  (('clinica',), 1),
#  (('familia',), 1),
#  (('expensive?',), 1),
#  (('guys?',), 1),
#  (('slices...on',), 1),
#  (('Henderson,',), 1),
#  (('Sam.',), 1),
#  (('lesbians.',), 1),
#  (('LGBT',), 1),
#  (('...weird)',), 1),
#  (('massages,',), 1),
#  (('(peeled',), 1),
#  (('eat)',), 1),
#  (('Ethnic',), 1),
#  (('Cajun,',), 1),
#  (('2:30pm.',), 1),
#  (('Arizona...',), 1),
#  (('appreciative.',), 1),
#  (('elote',), 1),
#  (('specialists.',), 1),
#  (('5:30pm',), 1),
#  (('"ok",',), 1),
#  (('under.',), 1),
#  (('Hhhhhhoooorible!',), 1),
#  (('RECEPTIONIST',), 1),
#  (('HUFFED',), 1),
#  (('PUFFED',), 1),
#  (('"ok,status',), 1),
#  (('quo',), 1),
#  (('restaurant"',), 1),
#  (('transplants',), 1),
#  (('2).',), 1),
#  (('seated."',), 1),
#  (('SIT',), 1),
#  (('COMMUNAL',), 1),
#  (('TABLE?"',), 1),
#  (('serval',), 1),
#  (('tables(besides',), 1),
#  (('EMPTY!i',), 1),
#  (('when?',), 1),
#  (('defeat',), 1),
#  (('COMMUNAL?',), 1),
#  (('charge"',), 1),
#  (('side......',), 1),
#  (('"....In',), 1),
#  (('54',), 1),
#  (('mark!',), 1),
#  (('will......and',), 1),
#  (('GRADE:',), 1),
#  (('FAIL!',), 1),
#  (('greatest?',), 1),
#  (('evolves',), 1),
#  (('leaps',), 1),
#  (('Roll?',), 1),
#  (('scientists',), 1),
#  (('instead?',), 1),
#  (('sectional.',), 1),
#  (('snatching',), 1),
#  (('"Sugar',), 1),
#  (('Raw",',), 1),
#  (('critter',), 1),
#  (('nice.)',), 1),
#  (('tolerating',), 1),
#  (('moi.',), 1),
#  (('(outside',), 1),
#  (('Savannah).',), 1),
#  (('fancy-pants',), 1),
#  (('chicken-y?',), 1),
#  (('uber-romantic',), 1),
#  (('not-great',), 1),
#  (('table.....Sigh',), 1),
#  (('389,',), 1),
#  (('june',), 1),
#  (('11,2016,',), 1),
#  (('8:45pm',), 1),
#  (('Airport,',), 1),
#  (('Crown',), 1),
#  (('junk.',), 1),
#  (('TRIED',), 1),
#  (('backseat.',), 1),
#  (('SQUEEZED',), 1),
#  (('weave',), 1),
#  (('junkpile.',), 1),
#  (('headrest',), 1),
#  (('BLARING',), 1),
#  (('Dangerously',), 1),
#  (('Louis-Simon',), 1),
#  (('Ca',), 1),
#  (('Roule.',), 1),
#  (('perched',), 1),
#  (('"Dining',), 1),
#  (('Arroyo"',), 1),
#  (('dining/lounge',), 1),
#  (('table),',), 1),
#  (('unmotivated',), 1),
#  (('upscale-casual',), 1),
#  (('match..',), 1),
#  (('saying..',), 1),
#  (('Wiseguy.',), 1),
#  (('wiseguy.',), 1),
#  (('pizza),',), 1),
#  (('splurging',), 1),
#  (('while?',), 1),
#  (('juggernauts,',), 1),
#  (('LGO,',), 1),
#  (('groovy.',), 1),
#  (('adjective',), 1),
#  (('skeletons',), 1),
#  (('overshadow',), 1),
#  (('interesting--short,',), 1),
#  (('pie!',), 1),
#  (('down),',), 1),
#  (('jenga).',), 1),
#  (('meal!!',), 1),
#  (('"conservative"',), 1),
#  (('Republican',), 1),
#  (('mayor',), 1),
#  (('"Trib"',), 1),
#  (('Greensburg',), 1),
#  (('strike.',), 1),
#  (('Press,',), 1),
#  (('1992',), 1),
#  (('Mellon',), 1),
#  (('Review,',), 1),
#  (('conservative,',), 1),
#  (('afloat.',), 1),
#  (('1992,',), 1),
#  (('"Pittsburgh',), 1),
#  (('Review"',), 1),
#  (('Democrats,',), 1),
#  (('strike,',), 1),
#  (('absorbed',), 1),
#  (('publication',), 1),
#  (('supermarkets,',), 1),
#  (('stored.',), 1),
#  (('comics,',), 1),
#  (('obituaries',), 1),
#  (('ads.',), 1),
#  (('low-lit,',), 1),
#  (('BYOB!',), 1),
#  (('eaten!!',), 1),
#  (('go-',), 1),
#  (('tempeh',), 1),
#  (('night!!!',), 1),
#  (('lot!!!',), 1),
#  (('65+',), 1),
#  (('45+',), 1),
#  (('helluva',), 1),
#  (('meal."',), 1),
#  (('ROACHES',), 1),
#  (('不要在这里吃！',), 1),
#  (('我们刚在这里吃午饭，在我们的汤里发现了一个蟑螂，我把它展示给服务员，她说：哦，对不起。你不必付饭费"，这意味着他们的厨房里有很多蟑螂，他们知道，她一点都不惊讶。',),
#   1),
#  (('ommmmmg',), 1),
#  (("Roberto's,",), 1),
#  (('curiosity,',), 1),
#  (("Ami's",), 1),
#  (("Angeles'",), 1),
#  (('Koreatown',), 1),
#  (('Koreatown,',), 1),
#  (('enclave',), 1),
#  (('"halmoni"',), 1),
#  (('grandkids,',), 1),
#  (('"Express"',), 1),
#  (('crib.',), 1),
#  (('"express"',), 1),
#  (('configure',), 1),
#  (('respectively).',), 1),
#  (('verdict?',), 1),
#  (('bu,',), 1),
#  (('bap,',), 1),
#  (('Delicous!!',), 1),
#  (('against?',), 1),
#  (('altercation,',), 1),
#  (('deprecation',), 1),
#  (('atmospheric',), 1),
#  (("mark...I've",), 1),
#  (('downpoint.',), 1),
#  (('anyway),',), 1),
#  (('fresh.....',), 1),
#  (("Italian...it's",), 1),
#  (('waterfall/pool',), 1),
#  (('$5-10',), 1),
#  (('fleek!',), 1),
#  (('(strange',), 1),
#  (('know),',), 1),
#  (('Monorail',), 1),
#  (('air!',), 1),
#  (('Literally,',), 1),
#  (('bells',), 1),
#  (('friendly;',), 1),
#  (('Damian',), 1),
#  (('eighty',), 1),
#  (('SIDE',), 1),
#  (('EFFECTS',), 1),
#  (('prescribed.',), 1),
#  (('is."',), 1),
#  (('elderly!',), 1),
#  (("Lee's.",), 1),
#  (('prob.',), 1),
#  (("won'",), 1),
#  (('registered',), 1),
#  (('psssh',), 1),
#  (('bye!',), 1),
#  (('blah!!!',), 1),
#  (('POW',), 1),
#  (('BANG.',), 1),
#  (("Ashley's",), 1),
#  (('exhibition',), 1),
#  (('animation',), 1),
#  (('cartoons',), 1),
#  (('SpongeBob',), 1),
#  (('SquarePants,',), 1),
#  (('Looney',), 1),
#  (('Tunes,',), 1),
#  (('beer/pint',), 1),
#  (('empanada..',), 1),
#  (('(running',), 1),
#  (('(non-toxic',), 1),
#  (('materials,',), 1),
#  (('insulation,',), 1),
#  (('museum!',), 1),
#  (('piggy,',), 1),
#  (('11:50',), 1),
#  (('matinee!',), 1),
#  (('Tequila.',), 1),
#  (('"one',), 1),
#  (('hundred,',), 1),
#  (('spiny',), 1),
#  (('plants"',), 1),
#  (('that...they',), 1),
#  (('tequila...lots',), 1),
#  (('tequila...a',), 1),
#  (('siphon',), 1),
#  (('1978',), 1),
#  (('Nogales',), 1),
#  (('evidently,',), 1),
#  (('agaves',), 1),
#  (('believed).',), 1),
#  (('club"...nice!',), 1),
#  (('club"',), 1),
#  (('bulletproof...I',), 1),
#  (('"tequila"',), 1),
#  (('agaves,',), 1),
#  (('(whoever',), 1),
#  (('"they"',), 1),
#  (('control...I',), 1),
#  (('juice:)',), 1),
#  (('club...you',), 1),
#  (('thanking',), 1),
#  (('stars:)',), 1),
#  (('euphemism...dear',), 1),
#  (('privilege:)',), 1),
#  (('today...no,',), 1),
#  (('Tecate',), 1),
#  (("cerveza's",), 1),
#  (('silly...dad',), 1),
#  (('buying:)',), 1),
#  (('BTW).',), 1),
#  (('tacos...(ok,',), 1),
#  (('salty...and',), 1),
#  (('salty...',), 1),
#  (('jam-packed',), 1),
#  (('tacos...I',), 1),
#  (('club:)',), 1),
#  (('Haylee',), 1),
#  (('y.o.',), 1),
#  (('jeep.',), 1),
#  (('(Camry',), 1),
#  (('SE),',), 1),
#  (('visually.',), 1),
#  (('bleached',), 1),
#  (('blond.',), 1),
#  (('(Meaning',), 1),
#  (('fades,',), 1),
#  (('Sunny',), 1),
#  (('Clay',), 1),
#  (('achievement.',), 1),
#  (('deliver....This',), 1),
#  (('family/table',), 1),
#  (('conveinent',), 1),
#  (('"Mike"',), 1),
#  (('shake.....which',), 1),
#  (('Relaxing',), 1),
#  (('Table-side',), 1),
#  (('Humor',), 1),
#  (('Physician,',), 1),
#  (('Jongeys',), 1),
#  (('anesthetic',), 1),
#  (('Hummmm...',), 1),
#  (('"new',), 1),
#  (('drugs"',), 1),
#  (('"better",',), 1),
#  (('injections',), 1),
#  (('momentary)',), 1),
#  (('"at-home"',), 1),
#  (('post-surgical',), 1),
#  (('Kyou',), 1),
#  (('free-gluten',), 1),
#  (('(bun',), 1),
#  (('requested)',), 1),
#  (('whack-a-mole',), 1),
#  (('"Southern',), 1),
#  (('Burger"',), 1),
#  (('spooky)',), 1),
#  (('adequately',), 1),
#  (('toppinged',), 1),
#  (('burning,',), 1),
#  (('(yea',), 1),
#  (('gloves!)',), 1),
#  (('reclaimed-paper',), 1),
#  (('capacity.',), 1),
#  (('location(',), 1),
#  (('problens',), 1),
#  (('york',), 1),
#  (('SLS.',), 1),
#  (('Landmark',), 1),
#  (('Village.',), 1),
#  (('cosy',), 1),
#  (('$0.85',), 1),
#  (('bag)',), 1),
#  (('"etsu"just',), 1),
#  (('$8.95',), 1),
#  (('Toronto),',), 1),
#  (('lacking/confusing',), 1),
#  (('Baldwin.',), 1),
#  (('Baldwin,',), 1),
#  (('Konnichiwa',), 1),
#  (('Bocca.',), 1),
#  ((',felt',), 1),
#  (('balyaged',), 1),
#  (('constantly!',), 1),
#  (('bellpeppers,',), 1),
#  (('Pam',), 1),
#  (('willingly',), 1),
#  (('accommodated!',), 1),
#  (('(Matt!)',), 1),
#  (('visit--worth',), 1)]

# %% [markdown]
# Here I found two sentences in Chinese:
# - (('不要在这里吃！',), 1),
# - (('我们刚在这里吃午饭，在我们的汤里发现了一个蟑螂，我把它展示给服务员，她说：哦，对不起。你不必付饭费"，这意味着他们的厨房里有很多蟑螂，他们知道，她一点都不惊讶。',),
#
# Most of these rare words have some punctuations.

# %%
text = ' '.join(train_10000_eng.text.values)
text_trigrams = [i for i in ngrams(text.split(), 2)]
Counter(text_trigrams).most_common()[-20:]
# Out:
# [(('visit!', "Haven't"), 1),
#  (('years', 'bc'), 1),
#  (('something', 'drew'), 1),
#  (('whites', 'mixed'), 1),
#  (('with', 'bellpeppers,'), 1),
#  (('bellpeppers,', 'onions'), 1),
#  (('tomatoes,', 'avocado'), 1),
#  (('fruit,', 'with'), 1),
#  (('muffin.', 'Super'), 1),
#  (('Super', 'healthy'), 1),
#  (('with', 'Pam'), 1),
#  (('Pam', 'instead'), 1),
#  (('they', 'willingly'), 1),
#  (('willingly', 'accommodated!'), 1),
#  (('accommodated!', 'This'), 1),
#  (('server', '(Matt!)'), 1),
#  (('(Matt!)', 'was'), 1),
#  (('AWESOME!', 'Come'), 1),
#  (('and', 'visit--worth'), 1),
#  (('visit--worth', 'it!'), 1)]

# %% [markdown]
# ### Check bad words

# %% [markdown]
# #### First emoticons

# %%
def find_emoticons(text):
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)',text)
    if emoticons == []:
        return False
    else:
        return True

# %%
eg1 = np.where(train_10000_eng.text.apply(find_emoticons) == True)[0][0]

# %%
train_10000_eng.iloc[eg1].text
# Out:
# "Man, I love Toronto! Hiding in a strip mall on Overlea, find a dingy looking restaurant that serves up fantastic, cheap kabob...be warned regardless of when you come here you'll likely be waiting for a table as this place is always overrun with people...If you're a fan of perfectly grilled spicy meat, you must try this place out...now that I've been here I need to limit how many times I go here per month :)\n\nTake the drive out and have some kabob...if you don't own a car, borrow one or get a zipcar membership...totally worth it!"

# %% [markdown]
# Here we can find one  :)  together with two '\n'

# %%
re.sub('\\n','',train_10000_eng.iloc[eg1].text)
# Out:
# "Man, I love Toronto! Hiding in a strip mall on Overlea, find a dingy looking restaurant that serves up fantastic, cheap kabob...be warned regardless of when you come here you'll likely be waiting for a table as this place is always overrun with people...If you're a fan of perfectly grilled spicy meat, you must try this place out...now that I've been here I need to limit how many times I go here per month :)Take the drive out and have some kabob...if you don't own a car, borrow one or get a zipcar membership...totally worth it!"

# %% [markdown]
# #### Check typos

# %%
# Most packages can't handle some words like 'nooooo'. 
def check_same(word):
    intervals = {}
    for index,letter in enumerate(word):
        if letter == word[index-1]:
            if letter in intervals.keys():
                interval = intervals.pop(letter)
                lastguy = interval[len(interval)-1] 
                if lastguy[1] == (index-1):
                    lastguy = (lastguy[0],index)
                    interval[len(interval)-1] = lastguy
                    intervals[letter] = interval
                else:
                    lastguy1 = (index-1,index)
                    interval.append(lastguy1)
                    intervals[letter] = interval
            else:
                intervals[letter] = [(index-1,index)]
    return intervals

# %%
# I have never seen a word with three continuous same letter, so I will delete till two.
def no_more_than_2(word,dupli):
    for key in dupli.keys():
        for interval in dupli[key]:
            length = interval[1]-interval[0]+1
            regex = '(%s'%key + '{%i})'%length
            word = re.sub(regex,key+key,word)
    return word

# %%
from pattern.en import suggest
from itertools import combinations
def right_spelling(word,dupli):
    key_list = []
    for key in dupli.keys():
        key_list.append(key)
    n = len(key_list)
    for i in range(n):
        for comb in combinations(key_list,i):
            for letter in comb:
                regex = '(%s'%letter + '{2})'
                new_word = re.sub(regex,letter,word)
                if new_word in brown.words():
                    return new_word
    return suggest(word)[0][0]

# %%
def no_typo(word):
    if len(word) == len(set(word)):
        return word
    if suggest(word)[0][1] == 1:
        return suggest(word)[0][0]
    else:
        duplicates = check_same(word)
        two = no_more_than_2(word,duplicates)
        suggest_two = suggest(two)
        if suggest_two[0][1] == 1:
            return suggest_two[0][0]
        else:
            return right_spelling(two,duplicates)
        
        return right_spelling(word)

# %%
no_typo('finaaallly')
# Out:
# 'finally'

# %% [markdown]
# #### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk import word_tokenize, pos_tag
from nltk.corpus import wordnet

# %%
from nltk.stem.porter import PorterStemmer
porter = PorterStemmer()
def tokenizer_porter(text):
    return [porter.stem(word) for word in text.split()]

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return None
    
wnl = WordNetLemmatizer()
def lemmatizer(text):
    tokens = word_tokenize(text)
    lemmas = []
    tagged = pos_tag(tokens)
    for tag in tagged:
        wordnet_pos = get_wordnet_pos(tag[1]) or wordnet.NOUN
        lemmas.append(wnl.lemmatize(tag[0], pos=wordnet_pos))
    return lemmas

# %% [markdown]
# #### Stop-words

# %% [markdown]
# I think words which mean negative are important.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jywsi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jywsi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jywsi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
stop.pop(stop.index('but'))
stop.pop(stop.index('not'))
preposition = ['of','with','at','from','into','during',
               'including','until','till','against','among',
               'throughout','despite','towards','upon','concerning','to','in',
               'for','on','by','about','like','through','over',
               'before','between','after','since','without','under',
               'within','along','following','across','behind',
               'beyond','plus','except','but','up','out','around','down','off','above','near']
for prep in preposition:
    if prep in stop:
        stop.pop(stop.index(prep))

# %% [markdown]
# #### Convert n't to not

# %%
def no_abbreviation(text):
    text = re.sub('n\'t',' not',text)
    return text

# %% [markdown]
# #### Adversatives

# %%
but = ['yet','however','nonetheless','whereas','nevertheless']
although = ['although','though','notwithstanding','albeit']

# %%
def change_but(text):
    for x in but:
        text = re.sub(x,'but',text)
    return text
def change_although(text):
    for x in although:
        text = re.sub(x,'although',text)
    return text
def change_adversatives(text):
    text = change_but(text)
    text = change_although(text)
    return text

# %% [markdown]
# Now I want to capture the key information near but and although.

# %% [markdown]
# def although_phrase(text):
#     words = text.split()
#     for (index,word) in enumerate(words):
#         if word == 'altough.':
#             for x in range(index,index-10,-1):
#                 if re.sub('(.*)\.([a-z])\..*','\\2',str(wordnet.synsets(words[x])[0])) in ['v','adj']

# %% [markdown]
# #### Phrases

# %%
def preprocessing(text):

    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)',text)

    text = re.sub('\\n',' ',text)

    text = no_abbreviation(text)

    text = re.sub('[\W]+',' ', text.lower())

    text = change_adversatives(text)

    tokens = lemmatizer(text)
    text = ''
    for index, token in enumerate(tokens):

        #tokens[index] = no_typo(token)
        if token in stop:
            tokens[index] = ''
        else:
            text = text + tokens[index] + ' '
    return {'text':text,'emoticons':emoticons}

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jywsi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from tqdm import tqdm, tqdm_pandas
tqdm.pandas()
dictionary = train_10000_eng.text.progress_apply(preprocessing)
# Out:
# 100%|██████████| 9956/9956 [02:02<00:00, 81.24it/s]

# %%
emoticons = [dictionary[i]['emoticons'] for i in train_10000_eng.index]

# %%
texts = [dictionary[i]['text'] for i in train_10000_eng.index]

# %%
from gensim.models.phrases import Phrases, Phraser
# Out:
# D:\anaconda\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
sentence_stream = [sent.split(' ') for sent in texts]

# %%
bigram = Phraser(Phrases(sentence_stream, min_count=5, threshold=5))

# %%
gg = bigram[sentence_stream]

# %%
gg[]

# %% [markdown]
# ## TF IDF

# %%
def concatenate(text):
    for x in text:
        return " ".join(text)

# %%
text1 = []
for i in range(len(gg)):
    text1.append(concatenate(gg[i]))

# %%
text1[5]
# Out:
# 'first to admit not excite_about go to la tavolta food snob group_of friend suggest go for_dinner look online at menu to nothing_special seem overpriced im also not big on order pasta go out ala outnumber thank_goodness order sea_bass special to_die for cooked perfectly_season perfectly perfect portion not say_enough good thing_about dish server ask seem proud_of dish say not chef incredible job hubby get crab tortellini also love heard mmmm good from around table waiter super_nice even give_u free_dessert of last people in restaurant service_slow place_pack but jug of wine large_group with good conversation not seem to bother anyone order calamari fry zucchini appetizer leave out mussel sea_bass special highly_recommend chicken_parm crab tortellini also good big chicken romano bit_bland house_salad teeny make_reservation but_still expect to wait for food go with large_group of people plan for to loud not go with date unless fight not feel_like hear_anything to say ask to sit in side room available'

# %%
TfidfVectorizer?

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer(analyzer='word', min_df = 1)

# %%
response =  tf.fit_transform(text1)

# %%
response
# Out:
# <9956x23714 sparse matrix of type '<class 'numpy.float64'>'
# 	with 472413 stored elements in Compressed Sparse Row format>

# %%
feature_names = tf.get_feature_names()

# %%
res_df = pd.DataFrame(response.toarray(),columns = feature_names)

# %%
res_df.loc[1]
# Out:
# 00                 0.0
# 000                0.0
# 00_pm              0.0
# 00am               0.0
# 00pm               0.0
# 01                 0.0
# 01pm               0.0
# 02                 0.0
# 025                0.0
# 03                 0.0
# 03pm               0.0
# 04                 0.0
# 05                 0.0
# 055                0.0
# 05am               0.0
# 06                 0.0
# 0600               0.0
# 07                 0.0
# 0700               0.0
# 08                 0.0
# 09                 0.0
# 0_50               0.0
# 0_star             0.0
# 0t                 0.0
# 10                 0.0
# 100                0.0
# 1000               0.0
# 10000              0.0
# 100psi             0.0
# 100th              0.0
#                   ...
# zoe                0.0
# zoey               0.0
# zoinks             0.0
# zoltan             0.0
# zombie             0.0
# zomg               0.0
# zomggggg           0.0
# zone               0.0
# zoo                0.0
# zounds             0.0
# zoës               0.0
# zucchini           0.0
# zuchinni           0.0
# zuma               0.0
# zumba              0.0
# zupas              0.0
# zuppas             0.0
# zzz                0.0
# çoban              0.0
# über               0.0
# 不要在这里吃             0.0
# 他们知道               0.0
# 你不必付饭费             0.0
# 在我们的汤里发现了一个蟑螂      0.0
# 她一点都不惊讶            0.0
# 她说                 0.0
# 对不起                0.0
# 我们刚在这里吃午饭          0.0
# 我把它展示给服务员          0.0
# 这意味着他们的厨房里有很多蟑螂    0.0
# Name: 1, Length: 23714, dtype: float64

# %%
value = sorted(res_df.iloc[1], reverse = True)[:10] 
value
# Out:
# [0.5023896319308714,
#  0.4118900882633719,
#  0.20985684249575187,
#  0.16075168978832,
#  0.15341055294175138,
#  0.13066056721340277,
#  0.10231372742103392,
#  0.09643067535454679,
#  0.09643067535454679,
#  0.09643067535454679]

# %%
names = np.array(feature_names)[np.argsort(res_df.iloc[1])[-10:]][::-1]
names
# Out:
# array(['travis', 'blowout', 'hair', 'perfectly', 'shampoo', 'stylist',
#        'way', 'scented', 'swoosh', 'admirable'], dtype='<U36')

# %%
dd = dict(zip(names,value))

# %%
# Out:
# {'travis': 0.5023896319308714,
#  'blowout': 0.4118900882633719,
#  'hair': 0.20985684249575187,
#  'perfectly': 0.16075168978832,
#  'shampoo': 0.15341055294175138,
#  'stylist': 0.13066056721340277,
#  'way': 0.10231372742103392,
#  'scented': 0.09643067535454679,
#  'swoosh': 0.09643067535454679,
#  'admirable': 0.09643067535454679}

# %%
def gettoptfidf(df,x):
    feature_names = tf.get_feature_names()
    list1 = []
    for i in range(len(df)):
        value = sorted(df.iloc[i], reverse = True)[:x] 
        names = np.array(feature_names)[np.argsort(df.iloc[i])[-x:]][::-1]
        dd = dict(zip(names,value))
        list1.append(dd)
    return list1

# %%
tfidf_final = gettoptfidf(res_df,15)

# %%
tfidf_final
# Out:
# [{'pill': 0.48217652192556987,
#   '8gs': 0.29372499295778365,
#   '69': 0.25980364066631106,
#   'crook': 0.25980364066631106,
#   'total_bill': 0.2509210120736448,
#   'nerve': 0.2336420097484103,
#   'er': 0.2226291196217625,
#   'cent': 0.21968627052071552,
#   'hospital': 0.21831375365221206,
#   'charge_u': 0.21699965978217223,
#   'horrible_service': 0.20909732131681763,
#   '19': 0.20811703118950603,
#   'avoid': 0.17055894564129642,
#   'online': 0.16459773154591745,
#   'cost': 0.14930023408962892},
#  {'travis': 0.5023896319308714,
#   'blowout': 0.4118900882633719,
#   'hair': 0.20985684249575187,
#   'perfectly': 0.16075168978832,
#   'shampoo': 0.15341055294175138,
#   'stylist': 0.13066056721340277,
#   'way': 0.10231372742103392,
#   'scented': 0.09643067535454679,
#   'swoosh': 0.09643067535454679,
#   'admirable': 0.09643067535454679,
#   'pagent': 0.09643067535454679,
#   'beauuuutiful': 0.09643067535454679,
#   'bouncey': 0.09643067535454679,
#   'style': 0.09481202425400279,
#   'wrist': 0.09232053645901393},
#  {'dental': 0.43747035833123804,
#   'office': 0.4179003951657497,
#   'insurance': 0.2539456591269185,
#   'help': 0.24431208148551428,
#   'synergy': 0.19370242282730757,
#   'phillipp': 0.19370242282730757,
#   'bailey': 0.17504480687466417,
#   'jewel': 0.16819352097682996,
#   'organized': 0.1654745395940169,
#   'feel_comfortable': 0.155588574306194,
#   'friendly_professional': 0.15407957936018463,
#   'assistant': 0.15012615254233835,
#   'dentist': 0.1392511043039497,
#   'procedure': 0.1385607970582682,
#   'sign_up': 0.13429044378682933},
#  {'summation': 0.2915380131974286,
#   'distribute': 0.2751859500583724,
#   'dawn': 0.26441512141981127,
#   'steak_sandwich': 0.2601406417115604,
#   'friendly_accommodate': 0.24716127900929652,
#   'perfect_amount': 0.2236661571229861,
#   'caesar_salad': 0.2212025536047687,
#   'leaf': 0.21782985316797632,
#   'go': 0.2092134392759882,
#   'absolutely_delicious': 0.20862084877617415,
#   'pub': 0.204146922645948,
#   'dressing': 0.19785002013761305,
#   'across': 0.19617949953116187,
#   'happy_with': 0.1745383431497395,
#   'perfectly': 0.16921200149157203},
#  {'reset': 0.34487191015550617,
#   'timer': 0.22991460677033743,
#   'gum': 0.22205387758758957,
#   'burn': 0.21049936745085168,
#   'session': 0.18251773903955476,
#   'admit': 0.16839949396068135,
#   'neglect': 0.16654040819069219,
#   'to': 0.15703166232241875,
#   'boyfriend': 0.1471621716926269,
#   'teeth': 0.13945330658074245,
#   'in': 0.12324986715016721,
#   'pain': 0.11987175088186675,
#   'at_point': 0.11935290616284448,
#   'room': 0.1120637094950374,
#   'check': 0.10950381338329791},
#  {'tortellini': 0.2376159419778527,
#   'sea_bass': 0.20339560304123414,
#   'large_group': 0.1834560862704211,
#   'crab': 0.1701711319276662,
#   'seem': 0.16963411508986342,
#   'not': 0.16706160792984068,
#   'go': 0.15667424824600545,
#   'to': 0.1555956394910261,
#   'tavolta': 0.13682686287851592,
#   'romano': 0.13682686287851592,
#   'outnumber': 0.13682686287851592,
#   'special': 0.12686012441485514,
#   'jug': 0.12685710449310938,
#   'good': 0.12219711776625182,
#   'also': 0.1200374070212463},
#  {'dessert': 0.42183179735602755,
#   'tracy': 0.3500779843730646,
#   'tremendously': 0.2192166332911221,
#   'table': 0.20088350736773172,
#   'increase': 0.19493389523296314,
#   'must_say': 0.18008031051432105,
#   'mango': 0.16119493029285845,
#   'for': 0.15239561862171064,
#   'like': 0.1433631990743496,
#   'in': 0.1251104070688827,
#   'also': 0.11574025911244902,
#   'shave_ice': 0.11455483493115438,
#   'taro': 0.11455483493115438,
#   '0_50': 0.11455483493115438,
#   'tapioca': 0.10828651494567415},
#  {'down_hill': 0.5395019490920906,
#   'quality': 0.2818490678294633,
#   'many_option': 0.2442688315445601,
#   'spend_money': 0.24003323721112704,
#   'service_slow': 0.23626068303459608,
#   'go': 0.22579034146229135,
#   'clearly': 0.19051809615744075,
#   '15': 0.18443130418424375,
#   'write': 0.18416657167489936,
#   'cut': 0.1629634221048638,
#   'change': 0.15224836847137113,
#   'food': 0.14916482542912965,
#   'worth': 0.14838928344579877,
#   'year': 0.14728367154441163,
#   'on': 0.14613671063274042},
#  {'66': 0.5392163140340608,
#   'register': 0.418978456707307,
#   'big_deal': 0.418978456707307,
#   'giant': 0.3960552047070213,
#   'buy': 0.27044437840816005,
#   'best': 0.18908914489141712,
#   'about': 0.18750346174910418,
#   'place': 0.12924250320385802,
#   'get': 0.1276794767568742,
#   'with': 0.11580142863458084,
#   'not': 0.10407731810998798,
#   'fabrice': 0.0,
#   'ez': 0.0,
#   'ezmart': 0.0,
#   'f13': 0.0},
#  {'machine': 0.4146185693048936,
#   'play': 0.27507313397121635,
#   'quarter': 0.2534739600868812,
#   'row': 0.2471629515416951,
#   'sister': 0.22964999145748238,
#   'gentler': 0.17968998431990046,
#   'spend': 0.1793123389616301,
#   'tilt': 0.16659704562161665,
#   'pac': 0.16659704562161665,
#   'fun': 0.16175791558834757,
#   'league': 0.1560263971193587,
#   'pin': 0.15127928929614282,
#   'bowling': 0.14748879690446137,
#   'teen': 0.14584522876059589,
#   'saturday_morning': 0.14163024394898036},
#  {'walk_in': 0.42268873555062664,
#   'smdh': 0.27083346962675925,
#   'non_existent': 0.22960829710444663,
#   'over_past': 0.2272280129991799,
#   '5_min': 0.21925046548902843,
#   'different_thing': 0.2175507070987901,
#   'several_year': 0.2144175302231914,
#   'oh_well': 0.20441162787466538,
#   'at_bar': 0.17319235770087876,
#   'walk_out': 0.1700220319435235,
#   'sit_at': 0.1700220319435235,
#   'afternoon': 0.1639938626677017,
#   'on_friday': 0.16292211871426548,
#   'realize': 0.15898411929459003,
#   'list': 0.155099778633571},
#  {'salad': 0.2759745355148984,
#   'entree': 0.25536825383725015,
#   'delicious': 0.21762924780481593,
#   'calamari': 0.21384408665320662,
#   'tender': 0.18896985362641086,
#   'right': 0.18198196042761383,
#   'eat': 0.16014428460362323,
#   '92': 0.15782213514246618,
#   'wonderful': 0.15108976717272032,
#   'riesling': 0.137038350941836,
#   'marinara_sauce': 0.134823017540298,
#   'diablo': 0.134823017540298,
#   'comfortably': 0.13112098648341977,
#   'bit_bland': 0.13112098648341977,
#   'review': 0.13044231068502526},
#  {'bachelorette': 0.38330741626332276,
#   'reach_out': 0.3657078357315506,
#   'michael': 0.3344104303158514,
#   'save': 0.25587398937084843,
#   'planning': 0.19447229982489006,
#   'overwhelmed': 0.19165370813166138,
#   'vega_trip': 0.1828539178657753,
#   'in_law': 0.16284219273613001,
#   'info': 0.16056138481180104,
#   'vip': 0.15718532167221796,
#   'carpet': 0.1559578541284126,
#   'package': 0.14967938004844825,
#   'smooth': 0.14922354968360665,
#   'sister': 0.14547025121552137,
#   'red': 0.13241158080856733},
#  {'duck': 0.3375287286762665,
#   'congee': 0.2844803776114852,
#   'hubby': 0.21161730474272175,
#   'pho': 0.21061664856579132,
#   'mine': 0.2043052452063177,
#   'before': 0.19221389072129283,
#   'bside': 0.16895331419841125,
#   'gist': 0.14944144074826912,
#   'place': 0.14638049865804703,
#   'order': 0.1388849296584774,
#   'another_couple': 0.13570922292424398,
#   'ahead': 0.1320214496755643,
#   'menu': 0.12761421301373238,
#   'understaffed': 0.12719177837289175,
#   'bad_part': 0.12719177837289175},
#  {'in_downtown': 0.4588665826513638,
#   'lot_of': 0.3928449666738956,
#   'poor_quality': 0.27628543255290383,
#   'anything_wrong': 0.2663610617248309,
#   'high_quality': 0.21141895685772358,
#   'case': 0.20223332311184716,
#   'price_reasonable': 0.20048623063462853,
#   'downtown': 0.19186381445003672,
#   'pasta': 0.18312040942599606,
#   'staff_friendly': 0.17531964453664078,
#   'pizza': 0.14428952556313876,
#   'option': 0.14346418228681096,
#   'owner': 0.14273788801934503,
#   'place': 0.1421637574043191,
#   'amazing': 0.1400503903325756},
#  {'tika': 0.2731063436186071,
#   'ovens': 0.2731063436186071,
#   'lunch_today': 0.24016199446596792,
#   'tandoori': 0.2315352034337137,
#   'biryani': 0.22913494363695092,
#   'great_addition': 0.2248437444527046,
#   'bbq_chicken': 0.21335886428958772,
#   'masala': 0.21202587866609796,
#   'staff_helpful': 0.21202587866609796,
#   'in_cleveland': 0.210749633341267,
#   'scene': 0.20030487729171936,
#   'naan': 0.19943562109854024,
#   'assist': 0.19543138332800372,
#   'casual': 0.18087234447104844,
#   'with': 0.1660867563584038},
#  {'slim': 0.3183437586775763,
#   'sweet_tea': 0.31372983127193677,
#   'grill_chicken': 0.28881617554812755,
#   'texas': 0.27530770243560554,
#   'two_year': 0.27530770243560554,
#   'brew': 0.27217218091929873,
#   'since_open': 0.2692691414298602,
#   'never_disappoint': 0.25529707584696165,
#   'fan': 0.21749185907614277,
#   'ago': 0.21258882994097744,
#   'live': 0.19616066564628973,
#   'plus': 0.18398208741563313,
#   'huge': 0.1704405874850763,
#   'salad': 0.16290758903399347,
#   'fresh': 0.14927967975291462},
#  {'side': 0.31247338347764436,
#   'carb': 0.3054837210562515,
#   'vegetarian': 0.30447059068602933,
#   'on_wednesday': 0.2394383977239626,
#   'except': 0.22374961191780912,
#   'heavy': 0.20482370472259318,
#   'bbq': 0.20226849987205353,
#   'menu': 0.1956488664852738,
#   'main': 0.18935452898531885,
#   'extremely_salty': 0.14994360743259966,
#   'overload': 0.1475196503460646,
#   'night': 0.1404731515143411,
#   'completely_different': 0.13736110539089239,
#   'friendly': 0.1314205413843662,
#   'potato_salad': 0.12293097128072489},
#  {'sandwich_shop': 0.27875317586790394,
#   'search_for': 0.23178305485373185,
#   'deli': 0.226907260557968,
#   'limit': 0.22261806666739795,
#   'on_strip': 0.2126861106835373,
#   'cashier': 0.2092835039794992,
#   'price_reasonable': 0.20747550503163878,
#   'value': 0.20254348970184896,
#   'snack': 0.20178387914660859,
#   'exactly': 0.19256221248164473,
#   'counter': 0.18819643184867813,
#   'order': 0.18611518598021876,
#   'like': 0.1845241167129922,
#   'prepare': 0.18384913348431048,
#   'walk': 0.1682546626595517},
#  {'on_planet': 0.3697306964896524,
#   'lamb': 0.2867148498355666,
#   'to_die': 0.2839738499079219,
#   'mexican': 0.28037194630110834,
#   'chef': 0.2579320773122641,
#   'pick': 0.2554551385850232,
#   'wow': 0.24921403374154877,
#   'taco': 0.243664397382053,
#   'fish': 0.2411040921523224,
#   'style': 0.23452136978983912,
#   'meat': 0.20623094754358112,
#   'amazing': 0.2035851745500987,
#   'dish': 0.1977144198186044,
#   'flavor': 0.19403219275325628,
#   'drink': 0.16958272919971323},
#  {'sewer': 0.24798263950142269,
#   'plumbsmart': 0.24798263950142269,
#   'landscape': 0.23407355185263282,
#   'wayne': 0.22491187003243354,
#   'scott': 0.21806891962482838,
#   'pipe': 0.21520009594248754,
#   'plumbing': 0.20805627350953076,
#   'badly': 0.1977232867435465,
#   'competitive': 0.1963266400323423,
#   'superior': 0.1949981501558392,
#   'damage': 0.17884983083340125,
#   'future': 0.1754839907733718,
#   'particularly': 0.16979070522199927,
#   'pleased_with': 0.16552009783358076,
#   'pricing': 0.16423346598414654},
#  {'snap': 0.24399217917472787,
#   'watch': 0.23169139873246783,
#   'jewelry': 0.2220883111363756,
#   'shock': 0.1926106367008592,
#   'repair': 0.17312842472227677,
#   'work': 0.15317849087478524,
#   'fix': 0.15207484838897056,
#   'shouting': 0.15030642833730662,
#   'someone': 0.14013571199639321,
#   'say': 0.13750257131882598,
#   'exhaust': 0.1305123964816985,
#   'chalk_up': 0.1305123964816985,
#   'conduct_business': 0.1305123964816985,
#   'blond': 0.1305123964816985,
#   'completely_unprofessional': 0.12840256029895433},
#  {'pettuccine': 0.41049906520168594,
#   'piccata': 0.3805884437681615,
#   'delicate': 0.32652933489847935,
#   'veal': 0.3133515349035464,
#   'staff_super': 0.2823200217429115,
#   'delightful': 0.28122751009259644,
#   'classic': 0.23565682519445508,
#   'kind': 0.22222304691398023,
#   'morning': 0.21930087868602768,
#   'yummy': 0.20537259185811974,
#   'owner': 0.1785455608649043,
#   'fresh': 0.1644419643470507,
#   'restaurant': 0.137862445231648,
#   'love': 0.12579023410531615,
#   'also': 0.12004281014907082},
#  {'hot_pot': 0.6621591976933514,
#   'shabu': 0.17392065023752515,
#   'quality_quantity': 0.1679743419537272,
#   'soup_base': 0.1613919920588658,
#   'perspective': 0.1613919920588658,
#   'hot_water': 0.1613919920588658,
#   'miserable': 0.15364718285574205,
#   'appetite': 0.14903486782217953,
#   'quantity': 0.14706483296088066,
#   'judge': 0.13576792682788277,
#   'must_say': 0.13419731930179007,
#   'anyways': 0.13369922962469408,
#   'good': 0.13170360904495462,
#   'im': 0.1296860789018142,
#   'limit': 0.12889099159455225},
#  {'westgate': 0.32011148697982245,
#   'balcony': 0.29075168682084074,
#   'wristband': 0.27130648754698694,
#   'theater': 0.23829339796459584,
#   'seat': 0.21570092171372965,
#   'superbowl': 0.21253885234278883,
#   'bet': 0.1934078461072544,
#   'to': 0.17119933090720302,
#   'in_line': 0.15835211211868339,
#   'watch': 0.14560898331059394,
#   'upstairs': 0.14347813204846577,
#   'at': 0.13976369449717255,
#   'auditorium': 0.13565324377349347,
#   'patron': 0.13216694558689054,
#   'in': 0.12093271529195358},
#  {'lettuce_wrap': 0.40860201801576584,
#   'dish': 0.31296628051895775,
#   'raku': 0.2517109775694272,
#   'panang': 0.23337029814049243,
#   'drunken_noodle': 0.2226416884368177,
#   'seabass': 0.2185628603296613,
#   'meal': 0.20027097035967828,
#   'in_mouth': 0.17834825985368818,
#   'start_off': 0.17380110080800645,
#   'setting': 0.173113789249229,
#   'terrific': 0.1687457778564605,
#   'intimate': 0.1681767235102076,
#   'duck': 0.16761965015001343,
#   'rating': 0.15249907250394035,
#   'on_yelp': 0.1518836957622602},
#  {'toe': 0.29050412512210844,
#   'toenail': 0.2446262674692351,
#   'charge': 0.24097382535630926,
#   'wait_until': 0.19366941674807228,
#   'girl': 0.18988632230500774,
#   'pay': 0.16523954795314902,
#   'design': 0.15449085737202112,
#   'nail': 0.14645316041881395,
#   'tell': 0.13882445159778978,
#   'to': 0.12712298653648288,
#   'extra': 0.12297659404313158,
#   'stone_massage': 0.12231313373461755,
#   'not_even': 0.1167137536393315,
#   'ask_for': 0.11416066944005453,
#   'glue': 0.11300412911472457},
#  {'scottsdale_location': 0.3658152545965921,
#   'care_less': 0.36051329725464304,
#   'ignore_u': 0.34396030991706167,
#   '10_min': 0.31827745597798784,
#   'manner': 0.2956759832538899,
#   'sit_at': 0.2573662904856452,
#   'walk_out': 0.2573662904856452,
#   'downtown': 0.25035506118474427,
#   'bartender': 0.2338687128073455,
#   'love_place': 0.21443219599374788,
#   'water': 0.20266696322990638,
#   'bar': 0.1797624666817467,
#   'menu': 0.1617215960426215,
#   'could': 0.1504020621337035,
#   'but': 0.07868333929305933},
#  {'gi': 0.3909272223784847,
#   'west_valley': 0.35455777391717613,
#   'resto': 0.34377034298613524,
#   'wont': 0.28799986634833713,
#   'let_u': 0.2830889116945656,
#   'support': 0.2637934777691838,
#   'best': 0.25879778256036784,
#   'chinese': 0.24638927667104835,
#   'trust': 0.23554706074031995,
#   '5_star': 0.21354377878541123,
#   'wrong': 0.21130764604471997,
#   'highly_recommend': 0.18590833169177612,
#   'business': 0.18221366161896083,
#   'come': 0.11065817766266929,
#   'place': 0.08844419192047419},
#  {'scampi': 0.3496862110388081,
#   'freind': 0.3496862110388081,
#   'lasagna': 0.2731853528424816,
#   'hamburger': 0.25761721435078,
#   'get': 0.19539239393352012,
#   'special': 0.1693242512826149,
#   'under_cook': 0.1560132662283678,
#   'manger': 0.15375208200510976,
#   'pretty_bland': 0.15172938379197454,
#   'dish': 0.15138036001946611,
#   'pretty_disappointed': 0.14989963068968432,
#   'ok_nothing': 0.14989963068968432,
#   'chicken': 0.1468986435130787,
#   'last_weekend': 0.14154244793121787,
#   'attach': 0.14044512773666623},
#  {'in_pittsburgh': 0.46634499880574065,
#   'transformation': 0.31182483166358016,
#   'epitomize': 0.31182483166358016,
#   'rumor': 0.29748947304472706,
#   'must_visit': 0.26066851241924915,
#   'alike': 0.26066851241924915,
#   'visitor': 0.24703328251236034,
#   'none': 0.22869114917185684,
#   'process': 0.1851282847278668,
#   'feel_like': 0.18321671948850343,
#   'second': 0.16857257860476305,
#   'local': 0.1664834696046922,
#   'atmosphere': 0.1535270457149646,
#   'place': 0.14569806471271976,
#   'definitely': 0.12754518598553785},
#  {'tire': 0.5531934553262393,
#   'two': 0.34207482815585377,
#   '280': 0.2825658618192581,
#   'tread': 0.2736402667178579,
#   'new_tire': 0.24225443838000485,
#   'tell': 0.21380669766517013,
#   'on': 0.16405068981035695,
#   'car': 0.1378784686169532,
#   'buy': 0.13377214576907112,
#   'couple_month': 0.12424021361670894,
#   'discount_tire': 0.12260576122552957,
#   'new': 0.11676569192398906,
#   'take_car': 0.10608895700217873,
#   'price': 0.10072969677533236,
#   'pressure': 0.0979520352549291},
#  {'coke': 0.2992164907912092,
#   'bring_u': 0.2762319298879751,
#   'somewhere': 0.26819721889580983,
#   'server': 0.24198915464339607,
#   'between': 0.22109132152354366,
#   'handheld': 0.1915034606658378,
#   'hover': 0.17692852054590175,
#   'meet_friend': 0.16067050689685328,
#   'terminal': 0.15766149772005728,
#   'get_attention': 0.15382778700554675,
#   'piss': 0.15382778700554675,
#   '20_min': 0.1477786403060296,
#   'starter': 0.143799412098421,
#   'napkin': 0.1345607641797023,
#   'credit_card': 0.13234532819469566},
#  {'smokey': 0.27815620737325325,
#   'catfish': 0.2042016181717069,
#   'place': 0.20001904789653052,
#   'garlic_fry': 0.18949162099708486,
#   'buffalo': 0.16596573888730154,
#   'ok': 0.16270048554041347,
#   'go': 0.15861065147652179,
#   'on_wall': 0.15133193795801878,
#   'chili': 0.14999572062515884,
#   'brisket': 0.14564338813088618,
#   'bbq': 0.13520705730643964,
#   'also': 0.13502333339070258,
#   'fairly': 0.1323224760819187,
#   'head': 0.12406730825956155,
#   'delicious': 0.11938106884171772},
#  {'piccadilly': 0.4323450324265812,
#   'frozen_yogurt': 0.39212232734436087,
#   'chocolate_caramel': 0.3140161975662469,
#   'turtle': 0.28933751968416094,
#   'yogurt': 0.23678962998917996,
#   'kiwispoon': 0.22579658363222188,
#   'mochi': 0.19009599687296871,
#   'topping': 0.1859381890131081,
#   'brownie': 0.16782534995815274,
#   'ice_cream': 0.11938861427296216,
#   'at': 0.11136139717074363,
#   'marginally': 0.1080862581066453,
#   'froyo': 0.09986003214595,
#   'height': 0.0937975866430807,
#   'flavor': 0.09183895873313633},
#  {'banh_mi': 0.38062761552231156,
#   'fish_taco': 0.3242046094723365,
#   'pork_belly': 0.3141698229019956,
#   'crispy': 0.25197999453078324,
#   'baguette': 0.20133039505552558,
#   'bam': 0.19520491173305865,
#   'esp': 0.18819301134584168,
#   'tender_juicy': 0.18118111095862469,
#   'corn_beef': 0.17831029281452565,
#   'benedict': 0.17699247009957583,
#   'hash': 0.17455305760567655,
#   'ham': 0.16141567389599262,
#   'chip_salsa': 0.15544111231226673,
#   'compliment': 0.15440377350877565,
#   'service_excellent': 0.15108571744179844},
#  {'buffet': 0.33967501640012937,
#   'cold': 0.3215560199874065,
#   'food': 0.19758155412768083,
#   'towards_end': 0.1859404877966465,
#   'forgot': 0.18324555224638855,
#   'chief': 0.18083485024964144,
#   'server': 0.17554520261113496,
#   'lamp': 0.16614890803158275,
#   'at_bellagio': 0.16385894777580495,
#   'many_option': 0.16177746738441798,
#   'horrible_experience': 0.16177746738441798,
#   'rio': 0.16177746738441798,
#   'crab_leg': 0.15422137021673193,
#   'freshly_make': 0.1528342481439855,
#   'must_say': 0.14855075317902436},
#  {'ahwahtukee': 0.40177840383876595,
#   'breakfast_spot': 0.32272249426649446,
#   'wait_until': 0.30452829849081825,
#   'family_run': 0.29344729547528003,
#   'croissant': 0.29185332577428386,
#   'flat': 0.2625781269830695,
#   'support': 0.25956004448246467,
#   'bomb': 0.25540240988269386,
#   'twice': 0.20664936985294846,
#   'fantastic': 0.19015329964885277,
#   'business': 0.17928944458783447,
#   'item': 0.17524421467361856,
#   'new': 0.15895173251723183,
#   'ca_not': 0.15311909705840107,
#   'well': 0.11971739502919965},
#  {'cooky': 0.3681984766398554,
#   'hate': 0.2122850843449781,
#   'foccacia': 0.16806984149765147,
#   'macadamia': 0.16276090805358212,
#   'wateringly': 0.16276090805358212,
#   'breakfast': 0.1616596601008994,
#   'belief': 0.15864297935436164,
#   'pizza': 0.1543722017569537,
#   'excellent': 0.1533150888181671,
#   'dessert_section': 0.1499694531771095,
#   'portuguese': 0.1477958651887756,
#   'white_chocolate': 0.145851524477889,
#   'chimichurri': 0.14248693174470622,
#   'ice_cold': 0.1410098101288185,
#   'soft_serve': 0.13717799830063687},
#  {'body': 0.5051752027187052,
#   'sac': 0.2628137320825498,
#   'operating': 0.24366406107418673,
#   'slipper': 0.23246222163314725,
#   'room': 0.226610907759245,
#   'butcher': 0.22451439006582363,
#   'surgery': 0.19303508484657642,
#   'nasty': 0.17805221823409173,
#   'wish_could': 0.17388541383821332,
#   'ruin': 0.172801857885505,
#   'promise': 0.166215244260314,
#   'alone': 0.1641977689677697,
#   'talk_about': 0.16055736129330261,
#   'dirty': 0.15418865296429424,
#   'out': 0.15279449098655581},
#  {'wonton_soup': 0.6610070103621383,
#   'satay': 0.33050350518106913,
#   'roti': 0.30519820457672975,
#   'fried': 0.24445381227718607,
#   'definitely_back': 0.22374842725992472,
#   'noodle': 0.21825106264009028,
#   'shrimp': 0.20274863556168296,
#   'dish': 0.1668841323084353,
#   'chicken': 0.1619434162847406,
#   'ever': 0.1526419039385745,
#   'one_of': 0.14473304983058394,
#   'delicious': 0.13881303914420298,
#   'best': 0.12760234629958442,
#   'service': 0.1045756930462655,
#   'great': 0.09470341236024298},
#  {'inside': 0.2475092033956818,
#   'dress': 0.23875329024617703,
#   'on_list': 0.23362751691171008,
#   'door': 0.22511938931457945,
#   'let': 0.2119502312278368,
#   'caucasian': 0.2018695610974219,
#   'line': 0.20063893645970518,
#   'flip_flop': 0.18330867524927913,
#   'guy': 0.1822589867247205,
#   'heel': 0.17319583555601226,
#   'pull_out': 0.16875191726476485,
#   'of': 0.16173697578310692,
#   'jean': 0.15992472456788645,
#   'people': 0.1531881480943216,
#   'particular': 0.14187820617555022},
#  {'jose': 0.604640191461767,
#   'excellent_service': 0.42106129401859194,
#   'thanks': 0.34208744433357985,
#   'dinner': 0.28690728851930414,
#   'could_not': 0.28316916860891583,
#   'sure': 0.26779549549065645,
#   'back': 0.2198079211751715,
#   'food': 0.15184182064501822,
#   'good': 0.14938687261289493,
#   'for': 0.11041245355181088,
#   'fabreze': 0.0,
#   'fabricate': 0.0,
#   'fabrication': 0.0,
#   'eyes': 0.0,
#   'ez': 0.0},
#  {'coupon': 0.27169777887964325,
#   'eat': 0.22063805642396775,
#   'crab_legs': 0.18065134004439237,
#   '37': 0.18065134004439237,
#   'self_serve': 0.17847280783383318,
#   'mirage': 0.17465440454164177,
#   'retail': 0.17138350737337044,
#   'flag_down': 0.16852261739225896,
#   'bar_area': 0.16262934323636527,
#   'wine_beer': 0.15970741907264624,
#   'price_point': 0.15881093994417386,
#   'two_people': 0.1547905563585537,
#   'drink': 0.1545910342884292,
#   'layout': 0.15137266647915879,
#   'unlimited': 0.14896441084945655},
#  {'playground': 0.46549083208860875,
#   'crap': 0.31582380486353623,
#   'duck': 0.2727956963447311,
#   'green': 0.18526377277197206,
#   'on': 0.1821571440299119,
#   'to': 0.16304550773580723,
#   'im': 0.1621110172224081,
#   'waterfall': 0.13998157022440652,
#   'nice': 0.13167257751891498,
#   'swing': 0.13161863446662386,
#   'slide': 0.12915370368003165,
#   'kid': 0.11466020724084076,
#   'equipment': 0.11141837427655352,
#   'in': 0.10877447477833103,
#   'think_about': 0.10773953240777094},
#  {'project': 0.3864666193061004,
#   'paul': 0.27573415516213606,
#   'ace': 0.27322011299574944,
#   'store': 0.22769607799139194,
#   'help': 0.21860517034134283,
#   'yourselfer': 0.17332074157046984,
#   'bra': 0.16069189164813202,
#   'name': 0.16036495084133204,
#   'personalized': 0.15330448801632915,
#   'hardware': 0.15049592750340582,
#   'every_aspect': 0.14806304172579424,
#   'home_depot': 0.14806304172579424,
#   'bounce': 0.14399746012967762,
#   'big': 0.14318357722096323,
#   'in_tempe': 0.13786707758106803},
#  {'burger': 0.4810032137050027,
#   'cajun': 0.2364844219043466,
#   'bun': 0.19316046826323038,
#   'beer_batter': 0.1876183939972751,
#   'patio': 0.18151084269936688,
#   'jones': 0.17857747925862197,
#   'topping': 0.17467160612573449,
#   'jalapeños': 0.16872565190721986,
#   'spicy': 0.15325212974478955,
#   'lime': 0.145317096821853,
#   'ring': 0.14370451679435045,
#   'avocado': 0.13348533946507962,
#   'strawberry': 0.13071379380993178,
#   'soda': 0.13071379380993178,
#   'small': 0.12493027039341903},
#  {'lamb': 0.29014551222768503,
#   'unsavory': 0.23109097943071188,
#   'rogan': 0.22379135554584262,
#   'bit': 0.20225257388150059,
#   'josh': 0.1959152476110431,
#   'give_chance': 0.19025321944555573,
#   'chicken_tikka': 0.1886156237261738,
#   'run_down': 0.18562700558607798,
#   'samosa': 0.18295359556068644,
#   'masala': 0.17940728624755245,
#   'from_outside': 0.1718333469674307,
#   'dining_room': 0.17024695999787773,
#   'naan': 0.16875394544989247,
#   'surprised': 0.16127372345794408,
#   'friday': 0.15637899992956986},
#  {'employee': 0.4173521065349911,
#   'entire_time': 0.30990911157694473,
#   'from_outside': 0.3003680360006304,
#   'chat_with': 0.2949851821937053,
#   'drive_thru': 0.2868984702974771,
#   'window': 0.2458367814604878,
#   'make': 0.2400002773117185,
#   'talk_to': 0.23014248730404233,
#   'head': 0.22675071173413233,
#   'hand': 0.2076029174138341,
#   'cook': 0.19546586911224348,
#   'food': 0.19150702589606755,
#   'busy': 0.18760373550991652,
#   'before': 0.16000846069280747,
#   'people': 0.14842733982598244},
#  {'grill_cheese': 0.28969240151689946,
#   'goat_cheese': 0.2646514550678319,
#   'fateful': 0.19240430458832436,
#   'accomadate': 0.19240430458832436,
#   'ther': 0.17838494911453198,
#   'portobello': 0.17018415187808358,
#   'fritter': 0.16198335464163516,
#   'patrick': 0.15985236924151294,
#   'red_wine': 0.15165157200506452,
#   'rd': 0.14912006550471088,
#   'vegetarian_option': 0.1479639991678428,
#   'never_hear': 0.14390530298937118,
#   'shopping_center': 0.13976320193139438,
#   'let_tell': 0.13976320193139438,
#   'venture': 0.13902764252110578},
#  {'machine': 0.6319311066260626,
#   'break': 0.279039130508639,
#   'sew': 0.24522716595080785,
#   '35th': 0.19917836260272315,
#   'vac': 0.19068883650252663,
#   'repair': 0.17206567545527748,
#   'to': 0.16987500142495224,
#   'ave': 0.14994586092043205,
#   'still': 0.11625923870620537,
#   'people': 0.10509962661218858,
#   'bill': 0.103830437577295,
#   'elna': 0.09958918130136157,
#   'sewing': 0.09958918130136157,
#   'kings': 0.09958918130136157,
#   'damm': 0.09534441825126332},
#  {'gtfoh': 0.2627682534567692,
#   'continuo': 0.2627682534567692,
#   'permanently': 0.24362189620493896,
#   'forehead': 0.23745814589082445,
#   'deem': 0.23242199518720774,
#   'option': 0.22974390325644595,
#   'hh': 0.22122209416947644,
#   'th': 0.2183117886389942,
#   'stamp': 0.2183117886389942,
#   'staff': 0.18772683440611954,
#   'last_visit': 0.1870597982542331,
#   'hit_miss': 0.18217255548351818,
#   'across': 0.16928342530052165,
#   'personable': 0.16747147389907754,
#   'patron': 0.16340201837813015},
#  {'first_class': 0.6825626166155571,
#   'cocktail': 0.4694065447850657,
#   'overall': 0.3569700428391461,
#   'restaurant': 0.2792808394262182,
#   'great': 0.19558342931224104,
#   'food': 0.18871912089149892,
#   'good': 0.18566794808226522,
#   'f_ckin': 0.0,
#   'eyelash': 0.0,
#   'eyeliner': 0.0,
#   'eyes': 0.0,
#   'ez': 0.0,
#   'ezmart': 0.0,
#   'f13': 0.0,
#   'f21': 0.0},
#  {'club': 0.30554306942937864,
#   'cute': 0.3014111952337923,
#   'mailer': 0.24162484221738495,
#   'watch_sport': 0.2284144284784596,
#   'music_playing': 0.2284144284784596,
#   'at_ease': 0.20562157539601486,
#   'on_monday': 0.18944978877190552,
#   'greet_by': 0.18613925554273783,
#   'shirt': 0.18248384625375566,
#   'good': 0.17909285572222045,
#   'say': 0.16306825019160223,
#   'wear': 0.16266083075953658,
#   'baby': 0.1610166751736279,
#   'toast': 0.15770614194446017,
#   'center': 0.15714398228055831},
#  {'kristine': 0.2288555227543576,
#   'anna': 0.21143779291979464,
#   'cole': 0.21143779291979464,
#   'everyone': 0.2093591945021438,
#   'flood': 0.20124907411888315,
#   'award': 0.19620652607526265,
#   'tim': 0.19620652607526265,
#   'night': 0.19445444109416887,
#   'privacy': 0.19014649197313907,
#   'with': 0.18556811213954033,
#   'communication': 0.16314557799877286,
#   'work': 0.16240794036021683,
#   'compliment': 0.15918460341610557,
#   'blow_away': 0.15815880905120977,
#   'gentleman': 0.1576611992766439},
#  {'boba_tea': 0.6265461987359131,
#   'jelly': 0.26499464134046435,
#   'milk_tea': 0.1766630942269762,
#   'milk': 0.16236971118653837,
#   'chewy': 0.1567277540984971,
#   'ball': 0.1485509110468665,
#   'snack': 0.14290895395882525,
#   'fruit': 0.14264419782243076,
#   'honeydew': 0.12026178337462531,
#   'lee_lee': 0.11149902365026,
#   'flavored': 0.10637313780867665,
#   'explosion': 0.10637313780867665,
#   'fry': 0.10291758621736145,
#   'popcorn_chicken': 0.10273626392589469,
#   'slush': 0.10124725196709326},
#  {'kale': 0.4282786449726372,
#   'farm': 0.408958619759924,
#   'fresh_delicious': 0.39465724406356106,
#   'grit': 0.3614961647108998,
#   'yum': 0.311791569559154,
#   'unique': 0.29200737068202026,
#   'would_definitely': 0.2856505010598856,
#   'choice': 0.24311730454570862,
#   'menu': 0.19927847923396663,
#   'f_cking': 0.0,
#   'eyes': 0.0,
#   'ez': 0.0,
#   'ezmart': 0.0,
#   'f13': 0.0,
#   'f21': 0.0},
#  {'snicker': 0.413693971047615,
#   'ooooooh': 0.22889432120757056,
#   'sanwiches': 0.22889432120757056,
#   'waaaaaaay': 0.22889432120757056,
#   'midwestern': 0.21913821974812486,
#   'veil': 0.21221615560307777,
#   'tasty': 0.1982310305545557,
#   'bachelorette_party': 0.19553798999858502,
#   'red_meat': 0.19270395268418644,
#   'tot': 0.187875513379012,
#   'super_fun': 0.18207279090690592,
#   'palm': 0.18207279090690592,
#   'but_hey': 0.1701277713867612,
#   'damn_good': 0.16910372293464657,
#   'cookie': 0.14959152001575526},
#  {'teaser': 0.4000551096561162,
#   'galley': 0.37090547704588805,
#   'on_earth': 0.3126062118254319,
#   'pair_with': 0.2973445731576776,
#   'milkshake': 0.2973445731576776,
#   'melt_in': 0.2875963810309053,
#   'heaven': 0.2700643163224042,
#   'phenomenal': 0.2476369658426673,
#   'mouth': 0.24545184940155296,
#   'boy': 0.2413953064338952,
#   'potato': 0.2182079034308844,
#   'burger': 0.1814373574143106,
#   'like': 0.10868216955064193,
#   'fab': 0.0,
#   'fabian': 0.0},
#  {'vegetarian': 0.2674304980210671,
#   'dinner': 0.26015852849635973,
#   'others': 0.23403891716356753,
#   'server': 0.18349393582356785,
#   'dark': 0.18341385137107194,
#   'would': 0.16888498182000328,
#   'tip': 0.15950817074437426,
#   '165': 0.14521197767392324,
#   'incase': 0.14062507071974897,
#   'not': 0.13228072936058602,
#   'hush_puppy': 0.12769530621822206,
#   'moon': 0.12601540007096892,
#   'on_facebook': 0.1244957401115485,
#   'like': 0.12361724529463272,
#   'grace': 0.12310839926404779},
#  {'cash': 0.4676644927572941,
#   'unqualified': 0.24782938812584795,
#   'take': 0.23869855954050823,
#   'wo_not': 0.2369511505637459,
#   'incapable': 0.2247728762160323,
#   'knight': 0.21506710392823486,
#   'concession': 0.2079276963229326,
#   'slight': 0.19361174876976314,
#   'pink': 0.18341566025889658,
#   'register': 0.18176595431688,
#   'stupid': 0.17873930300511606,
#   'upstairs': 0.17474995651109726,
#   'worker': 0.16134877792347227,
#   'handle': 0.154093328290915,
#   'section': 0.15006453484992477},
#  {'pretzel': 0.3523945873811551,
#   'cheese_dip': 0.3062493455371286,
#   'wonton': 0.17619729369057754,
#   'caesar_salad': 0.16767087749481252,
#   'with': 0.15678795512918142,
#   'for': 0.15236134493765235,
#   'tuna': 0.149118261049476,
#   'sauce': 0.14491134268672687,
#   'on_side': 0.13336862867230892,
#   'patio': 0.13167999765732788,
#   'to': 0.13124284499963987,
#   'sausage': 0.13068132672321095,
#   'guests': 0.11049247329948836,
#   'may': 0.11015022580670786,
#   'of': 0.10716217045500255},
#  {'awful': 0.3009320054570382,
#   'luke_warm': 0.21515497752345059,
#   'pretty': 0.21266111631642035,
#   'national': 0.20976399962337244,
#   'fixing': 0.20976399962337244,
#   'entire_experience': 0.20143174981362538,
#   'grease': 0.18770852210380015,
#   'cheeseburger': 0.18770852210380015,
#   'day': 0.1844510624380735,
#   'tray': 0.18107667572744954,
#   'best_thing': 0.17508196907180457,
#   'napkin': 0.17191775149252458,
#   'shower': 0.17018393709398927,
#   'difficult_to': 0.16908726241615962,
#   'disappointment': 0.1670197195147093},
#  {'system': 0.38503830945323547,
#   'psvr': 0.3240202414170522,
#   'employee': 0.24037531527142628,
#   'tell': 0.23472365902550008,
#   'first': 0.18287356167449828,
#   'get': 0.17333425525191887,
#   'gamestop': 0.1620101207085261,
#   'illiminate': 0.1620101207085261,
#   '01pm': 0.1620101207085261,
#   'name': 0.14989980314997467,
#   'launch': 0.1464051397872707,
#   'department_store': 0.14330009428551832,
#   'come': 0.13171465890041448,
#   'write_down': 0.12887010336012847,
#   'midnight': 0.12117252552009596},
#  {'mario': 0.32908671306646575,
#   'pizza': 0.24995384450691802,
#   'scarpariello': 0.18949865985037193,
#   'recycle': 0.18949865985037193,
#   'local': 0.18760308898329753,
#   'backwards': 0.16761407068137912,
#   'quite_possibly': 0.1618833829475615,
#   'bend': 0.15953711996379152,
#   'ala': 0.1555397172642738,
#   'penne': 0.1522119645624651,
#   'marketing': 0.14686808920623892,
#   'work_hard': 0.14686808920623892,
#   'vodka': 0.1436306777546019,
#   'jerk': 0.1417320788128686,
#   'lasagna': 0.1417320788128686},
#  {'kabob': 0.3434435192499782,
#   'overlea': 0.23765062216539865,
#   'overrun': 0.23765062216539865,
#   'borrow': 0.22033443707362904,
#   'hiding': 0.22033443707362904,
#   'zipcar': 0.22033443707362904,
#   'per_month': 0.2030182519818594,
#   'dingy': 0.19506264903652468,
#   'regardless_of': 0.17774646394475505,
#   'totally_worth': 0.17557274795585784,
#   'strip_mall': 0.1699981814785475,
#   'membership': 0.16687135905057726,
#   'limit': 0.15578107647501876,
#   'must_try': 0.15396340415195692,
#   'likely': 0.1531018713856066},
#  {'severn': 0.2949282378450699,
#   'checkup': 0.2823575904105154,
#   'arise': 0.248297279246992,
#   'discomfort': 0.24207587939616043,
#   'bella': 0.23937826295257744,
#   'whatsoever': 0.22058621566719144,
#   'family_friend': 0.213109460873217,
#   'currently': 0.20619133436917997,
#   'plan_on': 0.19451938844738947,
#   'las_vega': 0.1927473043544996,
#   'pain': 0.18134672148937356,
#   'great_experience': 0.1755619912698374,
#   'drop': 0.17523391380312575,
#   'smile': 0.17490927176567045,
#   'live_in': 0.17154604299633222},
#  {'sign': 0.3203730871297172,
#   'stitch': 0.27861444954041753,
#   'wreck': 0.25269388611307564,
#   'right': 0.2237122112989022,
#   'toy': 0.2150001069408386,
#   'paperwork': 0.21255143785037262,
#   'wish_would': 0.21255143785037262,
#   'nervous': 0.21139688452151018,
#   'stuffed': 0.19788032273709566,
#   'earlier': 0.19254649830351,
#   'super_nice': 0.18800602872791528,
#   '5_minute': 0.1809693586765775,
#   'several_time': 0.17667554187056933,
#   'doctor': 0.17595569613613174,
#   'otherwise': 0.17595569613613174},
#  {'expect': 0.2505964091854884,
#   'to': 0.19894383376723104,
#   'restaurant': 0.19584702582201713,
#   'at': 0.17256460859680142,
#   'italian_restaurant': 0.16944206078447058,
#   'kabob': 0.16855030458121836,
#   'venetian': 0.14945687022380946,
#   '4_5': 0.14866581474960297,
#   'not': 0.14240277711980232,
#   'piece_of': 0.13226032106065225,
#   'reservation': 0.13052873643213633,
#   'accommodate': 0.1299776886788998,
#   'sell': 0.12292355364975266,
#   'know': 0.1169486743908184,
#   'waiter': 0.1161778578202859},
#  {'skirt_steak': 0.3162110000988231,
#   'ahi_tuna': 0.2974065042479209,
#   'not_familiar': 0.2974065042479209,
#   'lively': 0.29269409253982087,
#   'atmosphere_great': 0.2750166925368521,
#   'ravioli': 0.2750166925368521,
#   'scottsdale': 0.23722948558850213,
#   'loud': 0.21814810796337614,
#   'fairly': 0.21814810796337614,
#   'list': 0.20867221975824427,
#   'wine': 0.19675608503847983,
#   'guess': 0.1882344662497074,
#   'really_good': 0.18317878042079472,
#   'appetizer': 0.18260720989012144,
#   'huge': 0.17407864263716055},
#  {'bm': 0.5344835099485136,
#   'ether': 0.2672417549742568,
#   'fry': 0.22870005405428945,
#   'mmm': 0.2146579430686814,
#   'hometown': 0.21257605657633558,
#   'many_thing': 0.19743423712444966,
#   'bloody_mary': 0.18848804008268497,
#   'hand_down': 0.1643227398764933,
#   'presentation': 0.16224085338414745,
#   'rock': 0.1615798202551496,
#   'not_disappoint': 0.1584896078092116,
#   'nail': 0.15317330577878047,
#   'veggie': 0.1461401486350586,
#   'seriously': 0.14558014447448805,
#   'bacon': 0.14293625631000878},
#  {'cost': 0.30082676865712127,
#   'initial': 0.2822350542154081,
#   'insurance': 0.2586314758326391,
#   'additional': 0.24478800876958465,
#   'talk': 0.22238608590854556,
#   'doubled': 0.19727662863158602,
#   'payless': 0.17827474151155823,
#   'traveler': 0.1744937869288786,
#   'waiver': 0.17129703537867802,
#   'misleading': 0.17129703537867802,
#   'collision': 0.16608531792731787,
#   'purposely': 0.16192384191230896,
#   'rent_from': 0.15549189980885078,
#   'experienced': 0.15549189980885078,
#   'small': 0.15492124212734393},
#  {'quiet': 0.34277080317616165,
#   'margarita': 0.3381496671958015,
#   'front': 0.3245711081489762,
#   'grill': 0.3187877315997842,
#   'sign': 0.3126801615403093,
#   'miss': 0.2831799016267646,
#   'almost': 0.2646253070023559,
#   'waitress': 0.2605054053820826,
#   'pizza': 0.24976250731115424,
#   'bar': 0.23846692842975645,
#   'small': 0.22304893788717792,
#   'out': 0.16512942517703702,
#   'great': 0.13360402513504402,
#   'good': 0.12683070999206816,
#   'place': 0.12304142091915066},
#  {'basement': 0.39503816388194823,
#   'sell': 0.2617103887124032,
#   'donnells': 0.24831275426287183,
#   'waterproof': 0.24831275426287183,
#   'subsequently': 0.23021968312220203,
#   'say': 0.22716022581404163,
#   'exactly_need': 0.21212661198153224,
#   'flood': 0.20905214684185808,
#   'would': 0.20736334637753742,
#   'nick': 0.19751908194097412,
#   'bet': 0.1694712558441486,
#   'crew': 0.16822803116860746,
#   'amount': 0.16041695851800686,
#   'hopefully': 0.15588385784253295,
#   'quote': 0.15302041069935685},
#  {'yelp': 0.28245451747665207,
#   'chef': 0.27854650790080127,
#   'cielo': 0.25758856154046705,
#   'discerning': 0.23881961758183073,
#   'kudos': 0.2236664182950024,
#   'compel': 0.2168613607939525,
#   'across_board': 0.2168613607939525,
#   'tenderloin': 0.2048974743363661,
#   'soo': 0.1861285303777298,
#   'judge': 0.17785944810029514,
#   'of_mine': 0.17715608745442585,
#   'impress': 0.17580191216894697,
#   'even': 0.17016417244482934,
#   'mac_cheese': 0.15838714349578956,
#   'really_nice': 0.15362440023679397},
#  {'allergy': 0.26117838873384464,
#   'on_side': 0.21198433893248178,
#   'music': 0.18946981925863005,
#   'on': 0.16314025568729928,
#   'fryer': 0.16225721073107863,
#   'also': 0.1609329273862491,
#   'bravo': 0.15443839522638636,
#   'chicken_parmesan': 0.15443839522638636,
#   'sever': 0.15240666816298634,
#   'whatever_reason': 0.14889085734081342,
#   'update_review': 0.14334331945524045,
#   'seem_bit': 0.14217426021057175,
#   'tasted': 0.13809946614122148,
#   'olive_oil': 0.13634520532888392,
#   'but': 0.1348269674823136},
#  {'prc': 0.40471240258565944,
#   'roof': 0.30893432724971165,
#   'manage': 0.28544733800252825,
#   'job': 0.19730391969232888,
#   'roofer': 0.19373122702371898,
#   'consult': 0.1876117103921692,
#   'spec': 0.18286504452643554,
#   'investment': 0.17898673612305852,
#   'phoenix_area': 0.17286721949150868,
#   'installation': 0.16424224522239797,
#   'roughly': 0.15812272859084817,
#   'tile': 0.1513486432703748,
#   'inspection': 0.1486293968593808,
#   'initial': 0.1447510884560038,
#   'replacement': 0.14147202542323267},
#  {'par': 0.4324225541397452,
#   'bagel': 0.3539222629481456,
#   'awful': 0.33352721297968774,
#   'rude': 0.2780175167495034,
#   'help': 0.23816466037917428,
#   'seem': 0.23410422781071713,
#   'want_to': 0.21014627729958882,
#   'staff': 0.20235416624313796,
#   'not': 0.19761773930159082,
#   'never': 0.19664861231000424,
#   'always': 0.1896612963659922,
#   'up': 0.18813901954884368,
#   'nice': 0.18208294951518222,
#   'out': 0.16467145794954952,
#   'to': 0.16104778075358683},
#  {'practice': 0.3106443084216955,
#   'room': 0.30919566848418195,
#   'friendly_welcome': 0.20126348567368205,
#   'compromise': 0.20126348567368205,
#   'elbow': 0.19861574726563894,
#   'facility_clean': 0.196220576530475,
#   'factory': 0.1920224619576531,
#   'friendly_professional': 0.19016010846603915,
#   'first_timer': 0.18842629884507595,
#   'accessible': 0.18528091502836247,
#   'goal': 0.18528091502836247,
#   'yoga': 0.18119677013804325,
#   'teacher': 0.17997066004547616,
#   'neat': 0.16506680744604546,
#   'push': 0.15867783441727024},
#  {'rude': 0.4319220333570792,
#   'owner': 0.38278839895133226,
#   'odd': 0.2859011533009322,
#   'super_nice': 0.2842779257979452,
#   'mix': 0.26605700183318637,
#   'incredibly': 0.2604893104371496,
#   'idea': 0.23762929728172102,
#   'average': 0.22748217889952366,
#   'space': 0.22587506609350033,
#   'wife': 0.21762979537887195,
#   'hand': 0.2165106140804472,
#   'coffee': 0.20704421648953103,
#   'problem': 0.20629931734653884,
#   'great': 0.10349434193176786,
#   'on': 0.09783479943669483},
#  {'defalco': 0.35250778306073227,
#   'parmigiana': 0.17089136158156534,
#   'bit': 0.17008212774762899,
#   'time': 0.16792691079922586,
#   'grub': 0.16660946411302982,
#   'ex': 0.16660946411302982,
#   'during_busy': 0.16660946411302982,
#   'tricky': 0.1647528213480878,
#   'recommend': 0.16444723993108973,
#   'authentic_italian': 0.16146356476677565,
#   'first_timer': 0.15999139963032355,
#   'unless_want': 0.15861428111461023,
#   'favorite_spot': 0.15861428111461023,
#   'goody': 0.1573206771128457,
#   'hour_wait': 0.15494735217709513},
#  {'sylvia': 0.41100511314878097,
#   'charlotte': 0.3001862164010724,
#   'sell': 0.21659038063562722,
#   'apartment': 0.17961049538368973,
#   'to': 0.1557944643059498,
#   'chip': 0.15022697465112145,
#   'notice': 0.13954495754076088,
#   'need': 0.1386602750141445,
#   '626': 0.137001704382927,
#   'give': 0.1363888379701237,
#   'last': 0.1278211429910398,
#   'furnished': 0.1270192063386695,
#   'show': 0.1218291740039489,
#   'graham': 0.11895978740820781,
#   'uptown': 0.1111973212749991},
#  {'individualize': 0.2775873406678297,
#   'fulfil': 0.25736120481201497,
#   'hot_pot': 0.2336981427917285,
#   'hot_water': 0.22784254262118542,
#   'walnut': 0.2151398977909206,
#   'electric': 0.21347200693591378,
#   'temp': 0.21189431753108123,
#   'customize': 0.21039757171739012,
#   'adjust': 0.2050774020902423,
#   'pot': 0.1901714358615754,
#   'run_out': 0.18673450969710367,
#   'difficult': 0.18609316199242557,
#   'st': 0.1825156083466405,
#   'in_case': 0.17932915707541341,
#   'locate': 0.16716413505374125},
#  {'rc_wiley': 0.33099274776592097,
#   'purchase': 0.2683669531738646,
#   '500': 0.262045335813046,
#   'apparently': 0.2050368130259389,
#   '2months': 0.17286432373957758,
#   'couldbe': 0.17286432373957758,
#   'emele': 0.17286432373957758,
#   'iwent': 0.17286432373957758,
#   '2300': 0.16549637388296048,
#   'anything': 0.1560042091306144,
#   'leap': 0.15290078040896232,
#   'pay': 0.149052110068242,
#   'making': 0.13625031152390416,
#   'supervisor': 0.13397589692511283,
#   'ashley': 0.13397589692511283},
#  {'photo': 0.3586933399168033,
#   'cut': 0.27979966297136094,
#   'show': 0.2508882055226432,
#   'salon': 0.22884911263701,
#   'exactly': 0.21329469677506846,
#   'hair': 0.20466406072161825,
#   'explain': 0.19630803742503303,
#   'aveda': 0.18007224024713403,
#   'mortify': 0.1743841790811463,
#   'hideous': 0.16331943387787115,
#   'butcher': 0.16067924597059333,
#   'try': 0.15992503282198764,
#   'fixed': 0.15835043519201583,
#   'matter_bad': 0.15835043519201583,
#   'big_mistake': 0.1543827663682961},
#  {'napa': 0.32915850033526795,
#   'hmmm': 0.31790464454210576,
#   'filter': 0.3020432256607711,
#   'hour_half': 0.2801515751893721,
#   '10_min': 0.2765928436200062,
#   'pull_up': 0.2661987822679659,
#   'take_forever': 0.2579947096525853,
#   'oil': 0.2341872415543004,
#   'let_know': 0.23249838624153107,
#   'find_out': 0.21466717004721633,
#   'part': 0.2048359827559458,
#   'later': 0.19140277969883407,
#   'not_even': 0.16998194852428827,
#   'guy': 0.15575151730259051,
#   'into': 0.1529855026745679},
#  {'bonus_point': 0.3056640322224763,
#   'laura': 0.3056640322224763,
#   'dive_bar': 0.2857185804865456,
#   'must_see': 0.27507296612062737,
#   'cute_little': 0.2557102790100722,
#   'u_feel': 0.24717979968305934,
#   'chill': 0.2280597677955507,
#   'in_city': 0.22207826370115205,
#   'at_home': 0.2040696884250957,
#   'vibe': 0.20144878530005975,
#   'bartender': 0.19225452514550315,
#   'look_like': 0.1827360473230971,
#   'in_area': 0.1803358932455101,
#   'yummy': 0.17611665981931154,
#   'cut': 0.17455504460922616},
#  {'lay_out': 0.4303841850234335,
#   'in_phoenix': 0.34801627144141556,
#   'interior': 0.3472158435923867,
#   'definitely_come': 0.3411766443396548,
#   'tea': 0.32077003961891815,
#   'unique': 0.30970682540839123,
#   'happy': 0.2503468035294362,
#   'tasty': 0.2423380742872412,
#   'back': 0.1838550369173333,
#   'really': 0.17530454082165167,
#   'well': 0.16675762328744992,
#   'like': 0.15203847509991544,
#   'place': 0.12121923617607469,
#   'to': 0.07955199817796764,
#   'f_ckin': 0.0},
#  {'eggplant': 0.4942120978427047,
#   'xlb': 0.2457317981617714,
#   'northerner': 0.2457317981617714,
#   'goooood': 0.22782678591677447,
#   'mince': 0.21735302517849814,
#   'obsess': 0.2133710861512745,
#   'americanized': 0.20415764719081075,
#   'dish': 0.20368802245215975,
#   'darn': 0.19738039194157903,
#   'obsess_with': 0.19738039194157903,
#   'dumpling': 0.17036148410544144,
#   'everything_else': 0.16363798844350727,
#   'to_die': 0.14627681675655976,
#   'sound': 0.14493809894779133,
#   'avoid': 0.1426904669669546},
#  {'beals': 0.4249315765908402,
#   'son': 0.36362228715409034,
#   'dr': 0.234208207719997,
#   'office': 0.22919056868745913,
#   'minecraft': 0.2124657882954201,
#   'dos': 0.19200086574447334,
#   'conservative': 0.18792879952208053,
#   'never_felt': 0.1690048003073984,
#   'feel_rush': 0.1690048003073984,
#   'satisfied_with': 0.16602243945497383,
#   'med': 0.15890992514407287,
#   'wonderful_experience': 0.15696656696178302,
#   'toy': 0.15696656696178302,
#   'solution': 0.15273993590324614,
#   'answer_question': 0.13370618447908764},
#  {'loco': 0.5546370302173671,
#   'bloodys': 0.3246255792777294,
#   'watering': 0.30097204719320647,
#   'football_game': 0.27731851510868355,
#   'hole': 0.23709710967783607,
#   'since_open': 0.23456818747167354,
#   'mill': 0.23109486998149123,
#   'on_sunday': 0.2023385923815364,
#   'come': 0.17594763939405078,
#   'local': 0.16068916129428462,
#   'great': 0.15269944322388,
#   'especially': 0.15069768491860255,
#   'breakfast': 0.1494678280890028,
#   'on': 0.14434914144149563,
#   'awesome': 0.12571378095849994},
#  {'skewer': 0.46228921511486454,
#   'kebob': 0.3743227937392601,
#   'barg': 0.1932662251798334,
#   'amex': 0.18716139686963004,
#   'plate': 0.18703704653359432,
#   'koobideh': 0.1785571246267245,
#   'one': 0.17744259026538475,
#   'parsley': 0.16995285238381894,
#   'radish': 0.16384802407361554,
#   'chicken_breast': 0.16057683158592836,
#   'of': 0.14995286138471925,
#   'friendly_attentive': 0.14827265032627412,
#   'two_people': 0.14370782628652604,
#   'flavourful': 0.14053465127760104,
#   'basil': 0.13995322459407988},
#  {'beer': 0.2826154127256778,
#   'cheer_': 0.24948602586234883,
#   'pull_out': 0.22967404645625814,
#   'cell_phone': 0.22620920539688247,
#   'catch_up': 0.22164229295512622,
#   '90': 0.21095906283803986,
#   'eventually': 0.20997004449354514,
#   'everytime': 0.2090114623617551,
#   'chat_with': 0.20717849480682393,
#   'hey': 0.20380748352087233,
#   'good': 0.19849130013940242,
#   'im': 0.19545066834437172,
#   'wait_staff': 0.18789451890932768,
#   'weird': 0.18181809673480562,
#   'non': 0.17295511669493752},
#  {'girlfriend': 0.2338797426610579,
#   'epoxy': 0.1884855690820476,
#   'attentative': 0.1884855690820476,
#   'encountered': 0.1884855690820476,
#   'resin': 0.1884855690820476,
#   'william': 0.17475174851968986,
#   '10_buck': 0.17033044583052517,
#   'equate': 0.17033044583052517,
#   'residue': 0.16671797849907746,
#   'feel': 0.165079010736897,
#   'sticker': 0.158684208478465,
#   '05': 0.158684208478465,
#   'bucket': 0.15298415793671968,
#   'server': 0.15201597630639746,
#   'table': 0.14350042172230465},
#  {'mission': 0.36541166459748436,
#   'on_menu': 0.21337413483402976,
#   'great': 0.20688682236416736,
#   'upside_down': 0.18786429459820217,
#   'candle': 0.17184064713970726,
#   'skeptical': 0.159744595934216,
#   'melt_in': 0.15809266214769438,
#   'wine_list': 0.15510564396338214,
#   'huge_fan': 0.15510564396338214,
#   'caramel': 0.1544155259472986,
#   'live_up': 0.15374541419531557,
#   'date_night': 0.1524607927913788,
#   'possibly': 0.15184429661053106,
#   'setting': 0.15124381514229143,
#   'to_perfection': 0.14644376679321694},
#  {'bubble_tea': 0.42230710891320944,
#   'thai_food': 0.39543007868467417,
#   'curry': 0.3520057006362126,
#   'mango': 0.35125487740427624,
#   'polite': 0.3416189864003121,
#   'especially': 0.2669095037179033,
#   'ever': 0.2179581242590501,
#   'everything': 0.2087470005775621,
#   'nice': 0.1848080101194877,
#   'best': 0.1822040169369424,
#   'love': 0.17618744098611794,
#   'service': 0.14932414567251814,
#   'great': 0.13522746759812634,
#   'extremely_rude': 0.0,
#   'extremely_helpful': 0.0},
#  {'hoodies': 0.40758463036096726,
#   'antigua': 0.40758463036096726,
#   'shop': 0.37210492278497054,
#   'fortunate': 0.33862739697550714,
#   'saving': 0.33862739697550714,
#   'several_year': 0.3089291330467935,
# ...
#   'entertain': 0.17210817773730697,
#   'whether': 0.1566286577253966},
#  {'pie': 0.4741403891911923,
#   'chop': 0.2222204646075225,
#   'cabbage': 0.2222204646075225,
#   'flavour': 0.1843546442184021,
#   'texture': 0.18232308396252392,
#   'ilicious': 0.1545576338925527,
#   'julienne': 0.14796996518311276,
#   'apricot': 0.1432959398500825,
#   'finely': 0.13420375573418739,
#   'beef_rib': 0.1320342458076123,
#   'large_piece': 0.1320342458076123,
#   'braised': 0.1320342458076123,
#   'enjoy': 0.12482002429935017,
#   'butter_chicken': 0.12414610800671325,
#   'savoury': 0.12414610800671325},
#  {'tom': 0.4259823304714247,
#   'philly': 0.41859584430502145,
#   'cause': 0.3244780666097661,
#   'steak': 0.28939016152922953,
#   'pizza': 0.2519902942308835,
#   'cheese': 0.2502647102368201,
#   'amaze': 0.22356443086136274,
#   'ever': 0.21726224218126247,
#   'little': 0.20079699581484303,
#   'take': 0.1761611919747793,
#   'well': 0.17077412135995348,
#   'one': 0.1679249203728575,
#   'order': 0.15704298569627,
#   'great': 0.13479572241108162,
#   'food': 0.13006485428140363},
#  {'alternator': 0.28659201719553884,
#   'safety': 0.2762507724426296,
#   'vehicle': 0.22136683737060373,
#   'ron': 0.21641389585156262,
#   'check': 0.17655337518192007,
#   'new_battery': 0.1588680478975317,
#   'to': 0.15318616513398367,
#   'assistant_manager': 0.14922325946888032,
#   'say': 0.14605383697224333,
#   'despite': 0.14365058148859533,
#   'call': 0.138505328223338,
#   'on': 0.13311054014060097,
#   'cost': 0.12172801828145965,
#   'rav': 0.11463680687821555,
#   'clamp': 0.11463680687821555},
#  {'wic': 0.6220305353124131,
#   'store': 0.3113059406468173,
#   'tell': 0.19311661690673843,
#   'call': 0.1713120552754781,
#   'manager': 0.1650051498517538,
#   'cashier': 0.1642802123192284,
#   'take': 0.1638791734652695,
#   'sign_post': 0.15431845605856512,
#   'front': 0.15231755344436715,
#   'to': 0.1389448374203154,
#   'speak_with': 0.12129438055503369,
#   'milk': 0.1199750785729833,
#   'say': 0.10838911389274039,
#   'window': 0.10354863397406465,
#   'on': 0.0987836663159058},
#  {'aside': 0.42474936479630876,
#   'in_charlotte': 0.3690244928577077,
#   'likely': 0.3558221707549346,
#   'sushi': 0.2791462741550797,
#   'charge': 0.26044220270942353,
#   'place': 0.2392643380428956,
#   'amazing': 0.23570750061333706,
#   'go_back': 0.21795732377639376,
#   'over': 0.19892092226892824,
#   'drink': 0.19634003966735994,
#   'nice': 0.17753012436919585,
#   'well': 0.16457434318231268,
#   'would': 0.15374576870721607,
#   'service': 0.14344364259658612,
#   'great': 0.12990210286504936},
#  {'cursing': 0.3723004172302101,
#   'word': 0.3013388122865136,
#   'nasty': 0.27205044045102017,
#   'puta': 0.2677064525555167,
#   'in_front': 0.2228287637436822,
#   'disrespectful': 0.20918792934938676,
#   'korean': 0.17712258381976256,
#   'customer': 0.17302812010290494,
#   'unprofessional': 0.169309621110669,
#   'worker': 0.1668609938318989,
#   'totally': 0.14794729312532492,
#   'use': 0.14745034699150103,
#   'understand': 0.13620622179315853,
#   'insults': 0.13385322627775836,
#   'chingado': 0.13385322627775836},
#  {'26th': 0.25022599431816245,
#   'stunna': 0.25022599431816245,
#   'wknd': 0.2395606786586059,
#   'gaudy': 0.23199351677232308,
#   'grown': 0.23199351677232308,
#   'anyhow': 0.20099028779326214,
#   'first_trip': 0.1990409587385455,
#   'definitely': 0.1897838352789586,
#   'living_room': 0.1896590149192356,
#   'sexy': 0.18837564307898894,
#   'spent': 0.17988544245222388,
#   'living': 0.17419793036153117,
#   'gold': 0.17347723034907456,
#   'shade': 0.17347723034907456,
#   'suite': 0.16076122171383964},
#  {'dentist': 0.5943633333471302,
#   'resident': 0.3091864359246689,
#   'teeth': 0.22178133960528557,
#   'crown': 0.16965379760345792,
#   'schedule_appointment': 0.15459321796233444,
#   'problem': 0.14535353090748346,
#   'change': 0.143629771497024,
#   'find_out': 0.11923213205992318,
#   'to': 0.11752343586361555,
#   'work': 0.10532189369875095,
#   'implant': 0.10334713168392108,
#   'drawn': 0.10334713168392108,
#   'coaching': 0.09894219451933021,
#   'extraction': 0.09581684186335934,
#   'without': 0.0944127140158096},
#  {'francisco': 0.2493145127823757,
#   'anne': 0.23785290810338755,
#   'from_san': 0.22639130342439934,
#   'marie': 0.22071878528152813,
#   'fell_in': 0.21195138925565304,
#   'last_weekend': 0.2084133031510016,
#   'adorable': 0.2024400609453055,
#   'yard': 0.19986848934052887,
#   'picky': 0.19751147508690675,
#   'drink': 0.1911840000596931,
#   'much_fun': 0.19053328493516483,
#   'hidden_gem': 0.18800014677655918,
#   'last_year': 0.18642930959903134,
#   'blast': 0.17907168025617665,
#   'super_nice': 0.1737222261474413},
#  {'vicuna': 0.48753978706086315,
#   'million': 0.3601871494050416,
#   'thorough': 0.32257088305052656,
#   'not_mind': 0.31237968276399564,
#   'fabulous': 0.29721746736321075,
#   'question': 0.2845462442437915,
#   'lol': 0.28216207150418415,
#   'patient': 0.27243120788969555,
#   'dr': 0.26871577922217216,
#   'ask': 0.18865305984952638,
#   'f_ckin': 0.0,
#   'fabrication': 0.0,
#   'eyes': 0.0,
#   'ez': 0.0,
#   'ezmart': 0.0},
#  {'club': 0.5073808537315762,
#   'hard_rock': 0.34996223026399564,
#   'rain': 0.33208637480720954,
#   'currently': 0.31041528383909095,
#   'on_sunday': 0.2767483434277384,
#   'hand_down': 0.27301241439963597,
#   'similar': 0.268455217331902,
#   'in_vega': 0.21628248662443533,
#   'hot': 0.19972378904296995,
#   'night': 0.1805920498541411,
#   'new': 0.17565791357755697,
#   'best': 0.1407041139582728,
#   'place': 0.09617131596576119,
#   'in': 0.08421186031960674,
#   'to': 0.06311391321892362},
#  {'call': 0.3057491564414452,
#   'associate': 0.244313699892229,
#   'clicklist': 0.216908253585971,
#   'email': 0.20674728079408838,
#   'husband': 0.20617103440011614,
#   'cell_phone': 0.17294683574240607,
#   'to': 0.16102712392094898,
#   'confirm': 0.15405473511776788,
#   'store': 0.1488222898394997,
#   'of': 0.14725936513893803,
#   'take': 0.13927777243573394,
#   'well': 0.13501860963843432,
#   'number': 0.13268978141128196,
#   'order': 0.12416240477962238,
#   'nellis': 0.11328253813037845},
#  {'rock': 0.3552316303490715,
#   'granny': 0.29376417230488533,
#   'yardbird': 0.23367317475519195,
#   'back_soon': 0.22954963668181133,
#   'exception': 0.2211521429749516,
#   'dude': 0.21576799460366944,
#   'chic': 0.21455683293768232,
#   'legit': 0.21226832954750063,
#   'find_new': 0.21118468628996467,
#   'fry_chicken': 0.2004914461615702,
#   'gluten_free': 0.1949870224131899,
#   'favorite_place': 0.18822250283456765,
#   'country': 0.18225662939691104,
#   'hate': 0.17761581517453576,
#   'make': 0.16709537282196665},
#  {'argumentative': 0.26053548139558663,
#   '00am': 0.22910753376162932,
#   '00pm': 0.21858804908747032,
#   'operation': 0.21264812000574654,
#   'many_option': 0.20226650042130506,
#   'professionalism': 0.19663921872202583,
#   'on_website': 0.19663921872202583,
#   'horrible_service': 0.19372752619882092,
#   'acknowledge': 0.19281929274979717,
#   'lead_to': 0.18716010145351297,
#   'communication': 0.18572945581520678,
#   'in_charlotte': 0.18182244621180596,
#   'walk_away': 0.18063031743830515,
#   '45': 0.1763040605357193,
#   'pm': 0.17483671578943083},
#  {'carl': 0.6507538157315147,
#   'ok': 0.3193569364027616,
#   'burger': 0.30827655873922805,
#   'jr': 0.3006131311065035,
#   'n_out': 0.2594318367729954,
#   'think': 0.2512601516660603,
#   'truly': 0.1842124912561272,
#   'far': 0.1711278323404492,
#   'cool': 0.16793990928804808,
#   'big': 0.14038357268066054,
#   'thing': 0.12232205241920174,
#   'people': 0.11955599901960864,
#   'go': 0.07783229959047396,
#   'good': 0.07588103011145153,
#   'in': 0.06445963393614616},
#  {'bff': 0.5927202344328926,
#   'happy_hour': 0.3435482930738102,
#   'meet': 0.3292147945973605,
#   'love_place': 0.3100208855615355,
#   'atmosphere': 0.28260787766899875,
#   'everything': 0.22477431953783214,
#   'drink': 0.22008176260725684,
#   'price': 0.21129420625205922,
#   'come': 0.16777890423458988,
#   'service': 0.16078905632772075,
#   'great': 0.14561005393176546,
#   'food': 0.14049963980893682,
#   'to': 0.08800405983873762,
#   'eyelash': 0.0,
#   'ezmart': 0.0},
#  {'kelly': 0.2943549804322343,
#   'drink': 0.2815649569484975,
#   'table': 0.226134866589633,
#   'crumbs': 0.19801641698736488,
#   'to': 0.1970313364265908,
#   'mysterious': 0.18957641618449333,
#   'abound': 0.18957641618449333,
#   'bar': 0.16625110063156742,
#   'stain': 0.15115442021434505,
#   'wipe': 0.1500867193514206,
#   '22': 0.14810278046744701,
#   'regardless_of': 0.14810278046744701,
#   'sticky': 0.14462544892772802,
#   'pay_attention': 0.14164671854854904,
#   'weak': 0.14164671854854904},
#  {'lunch': 0.28802824786204223,
#   'ravi': 0.27395785909149317,
#   'combo': 0.17321465043277195,
#   'wrap': 0.17321465043277195,
#   'space': 0.15561304147212884,
#   'to': 0.15082512543941234,
#   'about': 0.14289640061720243,
#   'blackboard': 0.1405345200134783,
#   'large': 0.13775689954104592,
#   'communal_table': 0.13697892954574659,
#   'today': 0.13611339942858622,
#   'prefect': 0.1340738006026037,
#   'lucky_enough': 0.12761308119172907,
#   'return_soon': 0.1259342567626029,
#   'turn_down': 0.12441557533625563},
#  {'update_review': 0.36752420479204795,
#   'edible': 0.32882302315015394,
#   'min': 0.303004939446758,
#   '3_star': 0.29455244521603097,
#   'solid': 0.2799769684609877,
#   'average': 0.24314405589288446,
#   'fix': 0.2379348220327481,
#   'fish': 0.23771059492355995,
#   'sushi': 0.23771059492355995,
#   'quick': 0.22343112171349094,
#   'good': 0.21002343717092878,
#   'house': 0.20812997533386596,
#   'come_back': 0.19427675410720133,
#   'since': 0.1853709574872237,
#   'from': 0.13028323651330506},
#  {'vietnamese': 0.4232780427104102,
#   'egg_roll': 0.4095372588247342,
#   'compliment': 0.39008759473158994,
#   'pho': 0.36511977293757614,
#   'crispy': 0.3183026805410484,
#   'prepare': 0.3171146393432339,
#   'hear': 0.2992038904760853,
#   'delicious': 0.20194296153541136,
#   'nice': 0.18828683789627693,
#   'fabreze': 0.0,
#   'fabian': 0.0,
#   'eyeliner': 0.0,
#   'eyes': 0.0,
#   'ez': 0.0,
#   'ezmart': 0.0},
#  {'safe': 0.45721100975559253,
#   'inch': 0.17323523176238265,
#   'wide': 0.17237645555166145,
#   'agree': 0.14849880627191747,
#   'foot': 0.1437163745204652,
#   'call': 0.13936962835832456,
#   'four': 0.13061350556048437,
#   'indentation': 0.12048767684520216,
#   'covering': 0.12048767684520216,
#   'highlander': 0.12048767684520216,
#   'scuffed': 0.12048767684520216,
#   'spend': 0.1202344539843867,
#   'move': 0.11616076439133126,
#   'seamlessly': 0.11535216280661352,
#   'pallet': 0.11535216280661352},
#  {'venetian': 0.22720422117156264,
#   'evolve': 0.20527054236651252,
#   'aspect_of': 0.18322035579485138,
#   'indeed': 0.16673696958796927,
#   'room': 0.1528785098595468,
#   'shopping': 0.1463349531782045,
#   'to': 0.13441522922382124,
#   'of': 0.131702975861618,
#   'crowd': 0.12389797605336739,
#   'calculated': 0.11820134675980301,
#   'disneyworld': 0.11820134675980301,
#   'straddle': 0.11820134675980301,
#   'ambition': 0.11820134675980301,
#   'pinnacle': 0.11820134675980301,
#   'auspex': 0.11820134675980301},
#  {'2000': 0.5232021502178357,
#   'chill': 0.4129646782971665,
#   'vibe': 0.3647782053754119,
#   'sandwich': 0.28376048159820677,
#   'pizza': 0.28026365484307997,
#   'since': 0.2512279106013004,
#   'awesome': 0.2468507827668318,
#   'eat': 0.21560390990277678,
#   'love': 0.19533007230940233,
#   'food': 0.1446581565325672,
#   'good': 0.14231935253771497,
#   'but': 0.11712549994338979,
#   'ezmart': 0.0,
#   'eyes': 0.0,
#   'f13': 0.0},
#  {'salon': 0.31146457739967137,
#   'tea': 0.29344847137486274,
#   'bang': 0.28045156432621193,
#   'stylist': 0.2601439197867117,
#   'hair': 0.20891146719018486,
#   'cut_hair': 0.19540817985691422,
#   'layer': 0.1774733477801766,
#   'wavy': 0.1279950251220524,
#   'swept': 0.1279950251220524,
#   'to': 0.1273582829112711,
#   'fringe': 0.12253952738489954,
#   'blunt': 0.12253952738489954,
#   'person': 0.12160700337818536,
#   'bobby': 0.1156664130803473,
#   'converse': 0.1156664130803473},
#  {'really': 0.2192986545069265,
#   'table': 0.19987761975800836,
#   'carcassonne': 0.17502409379561915,
#   'slat': 0.17502409379561915,
#   'to': 0.17415339410774344,
#   'lattes': 0.16756408863730365,
#   'overlooked': 0.16756408863730365,
#   '22nd': 0.15816559364454238,
#   'couch_area': 0.1548111255856233,
#   'snake': 0.1519749632533458,
#   'lo': 0.1473511204273078,
#   'criticism': 0.1473511204273078,
#   'board_game': 0.1436590532350032,
#   'behold': 0.1436590532350032,
#   'table_ready': 0.1436590532350032},
#  {'great_job': 0.4223207418855647,
#   'nail': 0.40432124861225405,
#   'veena': 0.3527100218381859,
#   'kathy': 0.3119766787643614,
#   'nail_shop': 0.3013102656227664,
#   'fav': 0.25356038052154656,
#   'not_mind': 0.2259906732816864,
#   'friendly_staff': 0.20729467642382113,
#   'daughter': 0.1970900013380495,
#   'love_place': 0.1766209066491761,
#   'busy': 0.15682421914750969,
#   'around': 0.14086145524228683,
#   'clean': 0.13983566081007875,
#   'wait': 0.12027019541258678,
#   'always': 0.11808856109191554},
#  {'watermelon': 0.4842459234306884,
#   'spiced': 0.22271213624064298,
#   'chicken': 0.21562145637199182,
#   'well_seasoned': 0.21531894271998195,
#   'not_overly': 0.18822722416553125,
#   'fry_chicken': 0.1829517680634273,
#   'fried_chicken': 0.18096182731661595,
#   'totally': 0.1481452648480608,
#   'doubtful': 0.13403233840100293,
#   'persistently': 0.13403233840100293,
#   'mean': 0.13178251912654898,
#   'with': 0.13006027587664917,
#   'greasiness': 0.12831951387399718,
#   'issue': 0.12603645351652928,
#   'juiciness': 0.12426620036657707},
#  {'doughy': 0.5552048756004682,
#   'tasteless': 0.4738556554229111,
#   'yummy': 0.3524126185561139,
#   'dry': 0.35083372608767327,
#   'pot_sticker': 0.29261422616908445,
#   'chicken_wing': 0.24955016603495864,
#   'fried_rice': 0.23861100962954981,
#   'not': 0.12286505692837849,
#   'eyelash': 0.0,
#   'eyeliner': 0.0,
#   'eyes': 0.0,
#   'ez': 0.0,
#   'ezmart': 0.0,
#   'f13': 0.0,
#   'f21': 0.0},
#  {'thing_happen': 0.3182896428008105,
#   'ihop': 0.314990024332384,
#   'another': 0.3048261162492646,
#   'denny': 0.29147032582663307,
#   'nope': 0.2765881918146017,
#   'give_another': 0.2676400930915572,
#   'burnt': 0.2586429774495323,
#   'figure': 0.2473945205344895,
#   'shot': 0.2432980667865151,
#   'toast': 0.2312998513437294,
#   'to': 0.22297193774861818,
#   'honestly': 0.21500378584885227,
#   'go': 0.17961408605533413,
#   'think': 0.1449586570777217,
#   'find': 0.13283116811293982},
#  {'gift_card': 0.5356556557491743,
#   'herbst': 0.3557651267467245,
#   'sarra': 0.3557651267467245,
#   'issue': 0.3345414651042168,
#   'nearby': 0.2267416605863627,
#   'terrible': 0.1974169906859632,
#   'thanks': 0.18189370755700454,
#   'receive': 0.1738720163380454,
#   'worth': 0.1606342139405601,
#   'store': 0.155792709924841,
#   'with': 0.13808879583533046,
#   'leave': 0.13351488268398584,
#   'use': 0.13063485741072114,
#   'one_of': 0.12787633509843097,
#   'after': 0.11438146698060357},
#  {'to': 0.2453528405464178,
#   '911': 0.22033164293243276,
#   'painter': 0.20356264830903587,
#   'wide_open': 0.19983335099136074,
#   'dangerous': 0.18485721684759918,
#   'complex': 0.16808822222420222,
#   'addict': 0.16383297929318116,
#   'living': 0.16021542603276007,
#   'paint': 0.1542852898421917,
#   'apartment': 0.15085840327949598,
#   'home': 0.14940056413747824,
#   'management': 0.13804802091707652,
#   'come': 0.12473676271497654,
#   'live': 0.12114499522850772,
#   'door': 0.1189732304432188},
#  {'gm': 0.495780783555773,
#   'hire': 0.3591352838284342,
#   'would_highly': 0.3485538476719994,
#   'ice_cream': 0.29636772320169785,
#   'worth': 0.25308128827666154,
#   'recommend': 0.2270478776943,
#   'new': 0.22175020796976716,
#   'since': 0.2209117863491201,
#   'location': 0.2194500949169592,
#   'use': 0.20581691282516584,
#   'make': 0.15941198114228355,
#   'to': 0.1593497622400349,
#   'like': 0.1522733269647705,
#   'come': 0.15189940411650782,
#   'place': 0.12140648196141653},
#  {'many': 0.30517417218737225,
#   'breakfast_burrito': 0.2848968825299413,
#   'rainbow': 0.2848968825299413,
#   'fresh_delicious': 0.27708207693610837,
#   'freshly_make': 0.26012929720647404,
#   'donut': 0.255797789242966,
#   'creative': 0.2451102765894381,
#   'pastry': 0.23736634168314127,
#   'delish': 0.23489291168291573,
#   'solid': 0.22052638704078653,
#   'yum': 0.21890350922003027,
#   'regular': 0.1860205260970995,
#   'fast': 0.1821229327291193,
#   'stuff': 0.17705821756585732,
#   'breakfast': 0.170573439367851},
#  ...]
