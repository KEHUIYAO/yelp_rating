# %% [markdown]
# ## Read first 10000 rows from json file

# %%
import json
import pandas as pd
def read_json_nrows(nrows,filename):
    n= 0
    with open(filename) as f:
        while n < nrows:
            if n == 0:
                line = f.readline()
                line = json.loads(line.rstrip())
                train = pd.DataFrame(line,index = [0])
            else:
                temp = pd.DataFrame(json.loads(f.readline().rstrip()),index = [n])
                train = train.append(temp)
            n = n+1
    return train

# %%
train_10000 = read_json_nrows(10000,'review_train.json')

# %%
train_10000.head(5)
# Out:
#    business_id  stars                                               text  \
# 0        31292    1.0  Total bill for this horrible service? Over $8G...
# 1        35344    5.0  I *adore* Travis at the Hard Rock's new Kelly ...
# 2       152538    5.0  I have to say that this office really has it t...
# 3        71871    5.0  Went in for a lunch. Steak sandwich was delici...
# 4        64913    1.0  Today was my second out of three sessions I ha...
#
#                   date
# 0  2013-05-07 04:34:36
# 1  2017-01-14 21:30:33
# 2  2016-11-09 20:09:03
# 3  2018-01-09 20:56:38
# 4  2018-01-30 23:07:38

# %% [markdown]
# ## Cleaning data

# %%
from collections import Counter
from nltk.util import ngrams
import re
import numpy as np 
from nltk.corpus import words
from nltk.corpus import brown
from nltk.corpus import wordnet
from nltk import wordpunct_tokenize

# %% [markdown]
# ### Languages

# %% [markdown]
# When I first tried to apply the *detect* function I got a 'No features in text' error. So I have to find out which review is empty.

# %%
train_10000.loc[6687]
# Out:
# business_id                 137207
# stars                            1
# text                            :(
# date           2017-07-18 20:31:03
# Name: 6687, dtype: object

# %% [markdown]
# This review is not language, but an emoticon.

# %%
def not_language(text):
    # First delete all common emoticons.
    text = re.sub('(?::|;|=)(?:-)?(?:\)|\(|D|P)','',text)
    if re.sub('[\W]+','',text) == '':
        return True
    else:
        return False

# %% [markdown]
# For simplicity, just consider emoticons as English.

# %%
not_lang = train_10000[train_10000.text.apply(not_language)].index.values

# %%
train_10000.loc[not_lang,'lang_type'] = 'english'

# %% [markdown]
# from nltk.corpus import stopwords
# from nltk import wordpunct_tokenize
# languages_ratios = {}
# for i in range(10000):
#     tokens = wordpunct_tokenize(train_10000.text[i])
#     words = [word.lower() for word in tokens]
#     for language in stopwords.fileids():
#         stopwords_set = set(stopwords.words(language))
#         words_set = set(words)
#         common_elements = words_set.intersection(stopwords_set)
#         languages_ratios[language] = len(common_elements)
#     most_rated_language = max(languages_ratios, key=languages_ratios.get)
#     train_10000.loc[i,'lang_type'] = most_rated_language

# %%
from langdetect import detect
for i in range(10000):
    if i in not_lang:
        continue
    else:
        train_10000.loc[i,'lang_type'] = detect(train_10000.text[i])

# %%
re.findall(':[\W]{0,1}',':(nmsl')
# Out:
# [':(']

# %%
train_10000.lang_type.value_counts()
# Out:
# en         9958
# fr           36
# es            3
# de            1
# ja            1
# english       1
# Name: lang_type, dtype: int64

# %% [markdown]
# Focus on English only at present.

# %%
train_10000_eng = train_10000[train_10000.lang_type == 'en']

# %% [markdown]
# Most common words and phrases.

# %%
text = ' '.join(train_10000_eng.text.values)
text_trigrams = [i for i in ngrams(text.split(), 1)]
Counter(text_trigrams).most_common(20)
# Out:
# [(('the',), 43484),
#  (('and',), 36448),
#  (('I',), 27219),
#  (('a',), 26196),
#  (('to',), 25807),
#  (('was',), 18766),
#  (('of',), 15249),
#  (('is',), 12815),
#  (('for',), 12221),
#  (('in',), 11026),
#  (('it',), 9188),
#  (('The',), 9181),
#  (('with',), 8640),
#  (('my',), 8424),
#  (('that',), 8146),
#  (('but',), 7073),
#  (('on',), 7003),
#  (('have',), 6583),
#  (('you',), 6540),
#  (('this',), 6388)]

# %%
text = ' '.join(train_10000_eng.text.values)
text_trigrams = [i for i in ngrams(text.split(), 2)]
Counter(text_trigrams).most_common(20)
# Out:
# [(('of', 'the'), 3443),
#  (('and', 'the'), 2772),
#  (('in', 'the'), 2722),
#  (('it', 'was'), 2336),
#  (('I', 'was'), 2307),
#  (('on', 'the'), 2107),
#  (('and', 'I'), 2017),
#  (('to', 'the'), 1836),
#  (('for', 'the'), 1732),
#  (('for', 'a'), 1732),
#  (('I', 'had'), 1559),
#  (('I', 'have'), 1490),
#  (('is', 'a'), 1378),
#  (('to', 'be'), 1358),
#  (('was', 'a'), 1313),
#  (('this', 'place'), 1278),
#  (('with', 'the'), 1262),
#  (('at', 'the'), 1245),
#  (('with', 'a'), 1216),
#  (('to', 'get'), 1206)]

# %%
text = ' '.join(train_10000_eng.text.values)
text_trigrams = [i for i in ngrams(text.split(), 3)]
Counter(text_trigrams).most_common(20)
# Out:
# [(('and', 'it', 'was'), 516),
#  (('one', 'of', 'the'), 451),
#  (('a', 'lot', 'of'), 392),
#  (('I', 'had', 'the'), 338),
#  (('This', 'place', 'is'), 316),
#  (('I', 'have', 'been'), 265),
#  (('I', 'had', 'to'), 262),
#  (('the', 'food', 'was'), 254),
#  (('I', 'ordered', 'the'), 247),
#  (('it', 'was', 'a'), 244),
#  (('of', 'the', 'best'), 239),
#  (('The', 'food', 'was'), 237),
#  (('I', 'had', 'a'), 236),
#  (('some', 'of', 'the'), 206),
#  (('The', 'food', 'is'), 199),
#  (('this', 'place', 'is'), 198),
#  (('The', 'service', 'was'), 187),
#  (('the', 'food', 'is'), 187),
#  (('to', 'get', 'a'), 182),
#  (('This', 'is', 'a'), 181)]

# %%
text = ' '.join(train_10000_eng.text.values)
text_trigrams = [i for i in ngrams(text.split(), 4)]
Counter(text_trigrams).most_common(20)
# Out:
# [(('one', 'of', 'the', 'best'), 126),
#  (('My', 'husband', 'and', 'I'), 88),
#  (('I', 'will', 'definitely', 'be'), 77),
#  (('is', 'one', 'of', 'the'), 73),
#  (('the', 'end', 'of', 'the'), 67),
#  (('in', 'the', 'middle', 'of'), 65),
#  (('for', 'the', 'first', 'time'), 65),
#  (('a', 'great', 'place', 'to'), 62),
#  (('some', 'of', 'the', 'best'), 60),
#  (('and', 'the', 'service', 'was'), 56),
#  (('you', 'are', 'looking', 'for'), 55),
#  (('was', 'one', 'of', 'the'), 54),
#  (('and', 'the', 'food', 'was'), 53),
#  (('I', 'have', 'to', 'say'), 52),
#  (('My', 'wife', 'and', 'I'), 50),
#  (('and', 'the', 'food', 'is'), 50),
#  (('was', 'my', 'first', 'time'), 49),
#  (('one', 'of', 'my', 'favorite'), 49),
#  (('the', 'rest', 'of', 'the'), 48),
#  (('I', "can't", 'wait', 'to'), 47)]

# %% [markdown]
# Oddest words

# %%
text = ' '.join(train_10000_eng.text.values)
text_trigrams = [i for i in ngrams(text.split(), 1)]
Counter(text_trigrams).most_common()[-500:]
# Out:
# [(('qualified,',), 1),
#  (('exuded',), 1),
#  (("'cool'",), 1),
#  (('Danny.',), 1),
#  (('accord',), 1),
#  (('b-day.',), 1),
#  (('Terroni.',), 1),
#  (('raptor',), 1),
#  (('flats',), 1),
#  (('gripe...no',), 1),
#  (('GPS?',), 1),
#  (('yardage',), 1),
#  (('caliber,',), 1),
#  (('troon',), 1),
#  (('Quintero',), 1),
#  (('parking....my',), 1),
#  (('pefect',), 1),
#  (('Dewy',), 1),
#  (('appoinment,',), 1),
#  (('in...)',), 1),
#  (('HVAC/Electrical/etc...',), 1),
#  (('electrical....(I',), 1),
#  (('NHW',), 1),
#  (('compressor',), 1),
#  (('verified',), 1),
#  (('TUESDAY',), 1),
#  (('compressor....',), 1),
#  (('occasions....',), 1),
#  (('SH!*',), 1),
#  (('Moe',), 1),
#  (('matted',), 1),
#  (('Choosing',), 1),
#  (('changing,',), 1),
#  (('eats!',), 1),
#  (('loong',), 1),
#  (('lo-mean,',), 1),
#  (('Discovered',), 1),
#  (('Beach.',), 1),
#  (('Thrilled',), 1),
#  (('favs:',), 1),
#  (('DELISH!)',), 1),
#  (('is..',), 1),
#  (('Woo',), 1),
#  (('Che.',), 1),
#  (('grilles,',), 1),
#  (('bugogi',), 1),
#  (('thicker,',), 1),
#  (('Louie,',), 1),
#  (('hmmm,',), 1),
#  (('names),',), 1),
#  (("'flatbread'",), 1),
#  (("'tacos',",), 1),
#  (('specialized?',), 1),
#  (("'asian",), 1),
#  (("sauce',",), 1),
#  (("'12'",), 1),
#  (("'5',",), 1),
#  (('singing,',), 1),
#  (("'it",), 1),
#  (("somewhere',",), 1),
#  (("'let's",), 1),
#  (("drink'!",), 1),
#  (('hoopla',), 1),
#  (('pedestrians.',), 1),
#  (('t.o.',), 1),
#  (('piazza...might',), 1),
#  (('cobblestones',), 1),
#  (('though...better',), 1),
#  (('distillery.',), 1),
#  (('food/drinks',), 1),
#  (('scoreboard',), 1),
#  (('keeps!',), 1),
#  (('amusing',), 1),
#  (('experience.Ordered',), 1),
#  (('Yada.',), 1),
#  (('Dina',), 1),
#  (('Yemen',), 1),
#  (('master.',), 1),
#  (('Samples',), 1),
#  (('EZMart',), 1),
#  (('Ames.',), 1),
#  (('saxby',), 1),
#  (('denizens',), 1),
#  (('bodied',), 1),
#  (('A+++',), 1),
#  (('Ultra',), 1),
#  (('Cooling.',), 1),
#  (('&Pylte',), 1),
#  (('YUMMMMMMMMMMMMMMMMM',), 1),
#  (('consumer.',), 1),
#  (('finish...',), 1),
#  (('Africa..."',), 1),
#  (('"famous".',), 1),
#  (('zagat',), 1),
#  (('exaggerated',), 1),
#  (('Dor-Stop.',), 1),
#  (('incredible?',), 1),
#  (('jumbot,',), 1),
#  (('verbally.',), 1),
#  (('catch.',), 1),
#  (('flavor/seasoning',), 1),
#  (('(tasted',), 1),
#  (('powder-based).',), 1),
#  (('wetter',), 1),
#  (('scrambled.',), 1),
#  (('Edmonton,',), 1),
#  (('MEH.',), 1),
#  (('advantage)',), 1),
#  (('"Hi"',), 1),
#  (('you?")',), 1),
#  (('thrusting',), 1),
#  (('fliers',), 1),
#  (('WITNESSED',), 1),
#  (('guarentee',), 1),
#  (('drummed',), 1),
#  (('expire).',), 1),
#  (('cringing',), 1),
#  (('sip).',), 1),
#  (('GOING',), 1),
#  (('distractions)',), 1),
#  (('13/30',), 1),
#  (('Froyo',), 1),
#  (('Kokomo.',), 1),
#  (('networking',), 1),
#  (('colleagues!',), 1),
#  (('sport.',), 1),
#  (('Hotels.com',), 1),
#  (('CPKs,',), 1),
#  (('top-of-the-line',), 1),
#  (('strip-center',), 1),
#  (('(save',), 1),
#  (('cleanest',), 1),
#  (('cooked.Not',), 1),
#  (('Before,',), 1),
#  (('"French',), 1),
#  (('Grocery"',), 1),
#  (('"French",',), 1),
#  (('"Grocery"',), 1),
#  (('tostadas.',), 1),
#  (('chef!!',), 1),
#  (('antipasta.',), 1),
#  (('waiter"Jordan"',), 1),
#  (('Hawaii?',), 1),
#  (('mega-bucks,',), 1),
#  (('Franklin',), 1),
#  (('Crafts,',), 1),
#  (('Wal-Mart',), 1),
#  (('crafter',), 1),
#  (('Oahu',), 1),
#  (('California:',), 1),
#  (('beads,',), 1),
#  (('baubles,',), 1),
#  (('frames,',), 1),
#  (('Franklin,',), 1),
#  (('cashieer',), 1),
#  (('super-friendly',), 1),
#  (('cafe~',), 1),
#  (('Coffees,',), 1),
#  (('well~',), 1),
#  (('"minor"',), 1),
#  (('$54',), 1),
#  (('skyrocket',), 1),
#  (('15-18',), 1),
#  (('clinica',), 1),
#  (('familia',), 1),
#  (('expensive?',), 1),
#  (('guys?',), 1),
#  (('slices...on',), 1),
#  (('Henderson,',), 1),
#  (('Sam.',), 1),
#  (('lesbians.',), 1),
#  (('LGBT',), 1),
#  (('...weird)',), 1),
#  (('massages,',), 1),
#  (('(peeled',), 1),
#  (('eat)',), 1),
#  (('Ethnic',), 1),
#  (('Cajun,',), 1),
#  (('2:30pm.',), 1),
#  (('Arizona...',), 1),
#  (('appreciative.',), 1),
#  (('elote',), 1),
#  (('specialists.',), 1),
#  (('5:30pm',), 1),
#  (('"ok",',), 1),
#  (('under.',), 1),
#  (('Hhhhhhoooorible!',), 1),
#  (('RECEPTIONIST',), 1),
#  (('HUFFED',), 1),
#  (('PUFFED',), 1),
#  (('"ok,status',), 1),
#  (('quo',), 1),
#  (('restaurant"',), 1),
#  (('transplants',), 1),
#  (('2).',), 1),
#  (('seated."',), 1),
#  (('SIT',), 1),
#  (('COMMUNAL',), 1),
#  (('TABLE?"',), 1),
#  (('serval',), 1),
#  (('tables(besides',), 1),
#  (('EMPTY!i',), 1),
#  (('when?',), 1),
#  (('defeat',), 1),
#  (('COMMUNAL?',), 1),
#  (('charge"',), 1),
#  (('side......',), 1),
#  (('"....In',), 1),
#  (('54',), 1),
#  (('mark!',), 1),
#  (('will......and',), 1),
#  (('GRADE:',), 1),
#  (('FAIL!',), 1),
#  (('greatest?',), 1),
#  (('evolves',), 1),
#  (('leaps',), 1),
#  (('Roll?',), 1),
#  (('scientists',), 1),
#  (('instead?',), 1),
#  (('sectional.',), 1),
#  (('snatching',), 1),
#  (('"Sugar',), 1),
#  (('Raw",',), 1),
#  (('critter',), 1),
#  (('nice.)',), 1),
#  (('tolerating',), 1),
#  (('moi.',), 1),
#  (('(outside',), 1),
#  (('Savannah).',), 1),
#  (('fancy-pants',), 1),
#  (('chicken-y?',), 1),
#  (('uber-romantic',), 1),
#  (('not-great',), 1),
#  (('table.....Sigh',), 1),
#  (('389,',), 1),
#  (('june',), 1),
#  (('11,2016,',), 1),
#  (('8:45pm',), 1),
#  (('Airport,',), 1),
#  (('Crown',), 1),
#  (('junk.',), 1),
#  (('TRIED',), 1),
#  (('backseat.',), 1),
#  (('SQUEEZED',), 1),
#  (('weave',), 1),
#  (('junkpile.',), 1),
#  (('headrest',), 1),
#  (('BLARING',), 1),
#  (('Dangerously',), 1),
#  (('Louis-Simon',), 1),
#  (('Ca',), 1),
#  (('Roule.',), 1),
#  (('perched',), 1),
#  (('"Dining',), 1),
#  (('Arroyo"',), 1),
#  (('dining/lounge',), 1),
#  (('table),',), 1),
#  (('unmotivated',), 1),
#  (('upscale-casual',), 1),
#  (('match..',), 1),
#  (('saying..',), 1),
#  (('Wiseguy.',), 1),
#  (('wiseguy.',), 1),
#  (('pizza),',), 1),
#  (('splurging',), 1),
#  (('while?',), 1),
#  (('juggernauts,',), 1),
#  (('LGO,',), 1),
#  (('groovy.',), 1),
#  (('adjective',), 1),
#  (('skeletons',), 1),
#  (('overshadow',), 1),
#  (('interesting--short,',), 1),
#  (('pie!',), 1),
#  (('down),',), 1),
#  (('jenga).',), 1),
#  (('meal!!',), 1),
#  (('"conservative"',), 1),
#  (('Republican',), 1),
#  (('mayor',), 1),
#  (('"Trib"',), 1),
#  (('Greensburg',), 1),
#  (('strike.',), 1),
#  (('Press,',), 1),
#  (('1992',), 1),
#  (('Mellon',), 1),
#  (('Review,',), 1),
#  (('conservative,',), 1),
#  (('afloat.',), 1),
#  (('1992,',), 1),
#  (('"Pittsburgh',), 1),
#  (('Review"',), 1),
#  (('Democrats,',), 1),
#  (('strike,',), 1),
#  (('absorbed',), 1),
#  (('publication',), 1),
#  (('supermarkets,',), 1),
#  (('stored.',), 1),
#  (('comics,',), 1),
#  (('obituaries',), 1),
#  (('ads.',), 1),
#  (('low-lit,',), 1),
#  (('BYOB!',), 1),
#  (('eaten!!',), 1),
#  (('go-',), 1),
#  (('tempeh',), 1),
#  (('night!!!',), 1),
#  (('lot!!!',), 1),
#  (('65+',), 1),
#  (('45+',), 1),
#  (('helluva',), 1),
#  (('meal."',), 1),
#  (('ROACHES',), 1),
#  (('不要在这里吃！',), 1),
#  (('我们刚在这里吃午饭，在我们的汤里发现了一个蟑螂，我把它展示给服务员，她说：哦，对不起。你不必付饭费"，这意味着他们的厨房里有很多蟑螂，他们知道，她一点都不惊讶。',),
#   1),
#  (('ommmmmg',), 1),
#  (("Roberto's,",), 1),
#  (('curiosity,',), 1),
#  (("Ami's",), 1),
#  (("Angeles'",), 1),
#  (('Koreatown',), 1),
#  (('Koreatown,',), 1),
#  (('enclave',), 1),
#  (('"halmoni"',), 1),
#  (('grandkids,',), 1),
#  (('"Express"',), 1),
#  (('crib.',), 1),
#  (('"express"',), 1),
#  (('configure',), 1),
#  (('respectively).',), 1),
#  (('verdict?',), 1),
#  (('bu,',), 1),
#  (('bap,',), 1),
#  (('Delicous!!',), 1),
#  (('against?',), 1),
#  (('altercation,',), 1),
#  (('deprecation',), 1),
#  (('atmospheric',), 1),
#  (("mark...I've",), 1),
#  (('downpoint.',), 1),
#  (('anyway),',), 1),
#  (('fresh.....',), 1),
#  (("Italian...it's",), 1),
#  (('waterfall/pool',), 1),
#  (('$5-10',), 1),
#  (('fleek!',), 1),
#  (('(strange',), 1),
#  (('know),',), 1),
#  (('Monorail',), 1),
#  (('air!',), 1),
#  (('Literally,',), 1),
#  (('bells',), 1),
#  (('friendly;',), 1),
#  (('Damian',), 1),
#  (('eighty',), 1),
#  (('SIDE',), 1),
#  (('EFFECTS',), 1),
#  (('prescribed.',), 1),
#  (('is."',), 1),
#  (('elderly!',), 1),
#  (("Lee's.",), 1),
#  (('prob.',), 1),
#  (("won'",), 1),
#  (('registered',), 1),
#  (('psssh',), 1),
#  (('bye!',), 1),
#  (('blah!!!',), 1),
#  (('POW',), 1),
#  (('BANG.',), 1),
#  (("Ashley's",), 1),
#  (('exhibition',), 1),
#  (('animation',), 1),
#  (('cartoons',), 1),
#  (('SpongeBob',), 1),
#  (('SquarePants,',), 1),
#  (('Looney',), 1),
#  (('Tunes,',), 1),
#  (('beer/pint',), 1),
#  (('empanada..',), 1),
#  (('(running',), 1),
#  (('(non-toxic',), 1),
#  (('materials,',), 1),
#  (('insulation,',), 1),
#  (('museum!',), 1),
#  (('piggy,',), 1),
#  (('11:50',), 1),
#  (('matinee!',), 1),
#  (('Tequila.',), 1),
#  (('"one',), 1),
#  (('hundred,',), 1),
#  (('spiny',), 1),
#  (('plants"',), 1),
#  (('that...they',), 1),
#  (('tequila...lots',), 1),
#  (('tequila...a',), 1),
#  (('siphon',), 1),
#  (('1978',), 1),
#  (('Nogales',), 1),
#  (('evidently,',), 1),
#  (('agaves',), 1),
#  (('believed).',), 1),
#  (('club"...nice!',), 1),
#  (('club"',), 1),
#  (('bulletproof...I',), 1),
#  (('"tequila"',), 1),
#  (('agaves,',), 1),
#  (('(whoever',), 1),
#  (('"they"',), 1),
#  (('control...I',), 1),
#  (('juice:)',), 1),
#  (('club...you',), 1),
#  (('thanking',), 1),
#  (('stars:)',), 1),
#  (('euphemism...dear',), 1),
#  (('privilege:)',), 1),
#  (('today...no,',), 1),
#  (('Tecate',), 1),
#  (("cerveza's",), 1),
#  (('silly...dad',), 1),
#  (('buying:)',), 1),
#  (('BTW).',), 1),
#  (('tacos...(ok,',), 1),
#  (('salty...and',), 1),
#  (('salty...',), 1),
#  (('jam-packed',), 1),
#  (('tacos...I',), 1),
#  (('club:)',), 1),
#  (('Haylee',), 1),
#  (('y.o.',), 1),
#  (('jeep.',), 1),
#  (('(Camry',), 1),
#  (('SE),',), 1),
#  (('visually.',), 1),
#  (('bleached',), 1),
#  (('blond.',), 1),
#  (('(Meaning',), 1),
#  (('fades,',), 1),
#  (('Sunny',), 1),
#  (('Clay',), 1),
#  (('achievement.',), 1),
#  (('deliver....This',), 1),
#  (('family/table',), 1),
#  (('conveinent',), 1),
#  (('"Mike"',), 1),
#  (('shake.....which',), 1),
#  (('Relaxing',), 1),
#  (('Table-side',), 1),
#  (('Humor',), 1),
#  (('Physician,',), 1),
#  (('Jongeys',), 1),
#  (('anesthetic',), 1),
#  (('Hummmm...',), 1),
#  (('"new',), 1),
#  (('drugs"',), 1),
#  (('"better",',), 1),
#  (('injections',), 1),
#  (('momentary)',), 1),
#  (('"at-home"',), 1),
#  (('post-surgical',), 1),
#  (('Kyou',), 1),
#  (('free-gluten',), 1),
#  (('(bun',), 1),
#  (('requested)',), 1),
#  (('whack-a-mole',), 1),
#  (('"Southern',), 1),
#  (('Burger"',), 1),
#  (('spooky)',), 1),
#  (('adequately',), 1),
#  (('toppinged',), 1),
#  (('burning,',), 1),
#  (('(yea',), 1),
#  (('gloves!)',), 1),
#  (('reclaimed-paper',), 1),
#  (('capacity.',), 1),
#  (('location(',), 1),
#  (('problens',), 1),
#  (('york',), 1),
#  (('SLS.',), 1),
#  (('Landmark',), 1),
#  (('Village.',), 1),
#  (('cosy',), 1),
#  (('$0.85',), 1),
#  (('bag)',), 1),
#  (('"etsu"just',), 1),
#  (('$8.95',), 1),
#  (('Toronto),',), 1),
#  (('lacking/confusing',), 1),
#  (('Baldwin.',), 1),
#  (('Baldwin,',), 1),
#  (('Konnichiwa',), 1),
#  (('Bocca.',), 1),
#  ((',felt',), 1),
#  (('balyaged',), 1),
#  (('constantly!',), 1),
#  (('bellpeppers,',), 1),
#  (('Pam',), 1),
#  (('willingly',), 1),
#  (('accommodated!',), 1),
#  (('(Matt!)',), 1),
#  (('visit--worth',), 1)]

# %% [markdown]
# Here I found two sentences in Chinese:
# - (('不要在这里吃！',), 1),
# - (('我们刚在这里吃午饭，在我们的汤里发现了一个蟑螂，我把它展示给服务员，她说：哦，对不起。你不必付饭费"，这意味着他们的厨房里有很多蟑螂，他们知道，她一点都不惊讶。',),
#
# Most of these rare words have some punctuations.

# %%
text = ' '.join(train_10000_eng.text.values)
text_trigrams = [i for i in ngrams(text.split(), 2)]
Counter(text_trigrams).most_common()[-20:]
# Out:
# [(('visit!', "Haven't"), 1),
#  (('years', 'bc'), 1),
#  (('something', 'drew'), 1),
#  (('whites', 'mixed'), 1),
#  (('with', 'bellpeppers,'), 1),
#  (('bellpeppers,', 'onions'), 1),
#  (('tomatoes,', 'avocado'), 1),
#  (('fruit,', 'with'), 1),
#  (('muffin.', 'Super'), 1),
#  (('Super', 'healthy'), 1),
#  (('with', 'Pam'), 1),
#  (('Pam', 'instead'), 1),
#  (('they', 'willingly'), 1),
#  (('willingly', 'accommodated!'), 1),
#  (('accommodated!', 'This'), 1),
#  (('server', '(Matt!)'), 1),
#  (('(Matt!)', 'was'), 1),
#  (('AWESOME!', 'Come'), 1),
#  (('and', 'visit--worth'), 1),
#  (('visit--worth', 'it!'), 1)]

# %% [markdown]
# ### Check bad words

# %% [markdown]
# #### First emoticons

# %%
def find_emoticons(text):
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)',text)
    if emoticons == []:
        return False
    else:
        return True

# %%
eg1 = np.where(train_10000_eng.text.apply(find_emoticons) == True)[0][0]

# %%
train_10000_eng.iloc[eg1].text
# Out:
# "Man, I love Toronto! Hiding in a strip mall on Overlea, find a dingy looking restaurant that serves up fantastic, cheap kabob...be warned regardless of when you come here you'll likely be waiting for a table as this place is always overrun with people...If you're a fan of perfectly grilled spicy meat, you must try this place out...now that I've been here I need to limit how many times I go here per month :)\n\nTake the drive out and have some kabob...if you don't own a car, borrow one or get a zipcar membership...totally worth it!"

# %% [markdown]
# Here we can find one  :)  together with two '\n'

# %%
re.sub('\\n','',train_10000_eng.iloc[eg1].text)
# Out:
# "Man, I love Toronto! Hiding in a strip mall on Overlea, find a dingy looking restaurant that serves up fantastic, cheap kabob...be warned regardless of when you come here you'll likely be waiting for a table as this place is always overrun with people...If you're a fan of perfectly grilled spicy meat, you must try this place out...now that I've been here I need to limit how many times I go here per month :)Take the drive out and have some kabob...if you don't own a car, borrow one or get a zipcar membership...totally worth it!"

# %% [markdown]
# #### Check typos

# %%
# Most packages can't handle some words like 'nooooo'. 
def check_same(word):
    intervals = {}
    for index,letter in enumerate(word):
        if letter == word[index-1]:
            if letter in intervals.keys():
                interval = intervals.pop(letter)
                lastguy = interval[len(interval)-1] 
                if lastguy[1] == (index-1):
                    lastguy = (lastguy[0],index)
                    interval[len(interval)-1] = lastguy
                    intervals[letter] = interval
                else:
                    lastguy1 = (index-1,index)
                    interval.append(lastguy1)
                    intervals[letter] = interval
            else:
                intervals[letter] = [(index-1,index)]
    return intervals

# %%
# I have never seen a word with three continuous same letter, so I will delete till two.
def no_more_than_2(word,dupli):
    for key in dupli.keys():
        for interval in dupli[key]:
            length = interval[1]-interval[0]+1
            regex = '(%s'%key + '{%i})'%length
            word = re.sub(regex,key+key,word)
    return word

# %%
from pattern.en import suggest
from itertools import combinations
def right_spelling(word,dupli):
    key_list = []
    for key in dupli.keys():
        key_list.append(key)
    n = len(key_list)
    for i in range(n):
        for comb in combinations(key_list,i):
            for letter in comb:
                regex = '(%s'%letter + '{2})'
                new_word = re.sub(regex,letter,word)
                if new_word in brown.words():
                    return new_word
    return suggest(word)[0][0]

# %%
def no_typo(word):
    if len(word) == len(set(word)):
        return word
    if suggest(word)[0][1] == 1:
        return suggest(word)[0][0]
    else:
        duplicates = check_same(word)
        two = no_more_than_2(word,duplicates)
        suggest_two = suggest(two)
        if suggest_two[0][1] == 1:
            return suggest_two[0][0]
        else:
            return right_spelling(two,duplicates)
        
        return right_spelling(word)

# %%
no_typo('finaaallly')
# Out:
# 'finally'

# %% [markdown]
# #### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk import word_tokenize, pos_tag
from nltk.corpus import wordnet

# %%
from nltk.stem.porter import PorterStemmer
porter = PorterStemmer()
def tokenizer_porter(text):
    return [porter.stem(word) for word in text.split()]

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return None
    
wnl = WordNetLemmatizer()
def lemmatizer(text):
    tokens = word_tokenize(text)
    lemmas = []
    tagged = pos_tag(tokens)
    for tag in tagged:
        wordnet_pos = get_wordnet_pos(tag[1]) or wordnet.NOUN
        lemmas.append(wnl.lemmatize(tag[0], pos=wordnet_pos))
    return lemmas

# %% [markdown]
# #### Stop-words

# %% [markdown]
# I think words which mean negative are important.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jywsi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jywsi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jywsi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
stop.pop(stop.index('but'))
stop.pop(stop.index('not'))
preposition = ['of','with','at','from','into','during',
               'including','until','till','against','among',
               'throughout','despite','towards','upon','concerning','to','in',
               'for','on','by','about','like','through','over',
               'before','between','after','since','without','under',
               'within','along','following','across','behind',
               'beyond','plus','except','but','up','out','around','down','off','above','near']
for prep in preposition:
    if prep in stop:
        stop.pop(stop.index(prep))

# %% [markdown]
# #### Convert n't to not

# %%
def no_abbreviation(text):
    text = re.sub('n\'t',' not',text)
    return text

# %% [markdown]
# #### Adversatives

# %%
but = ['yet','however','nonetheless','whereas','nevertheless']
although = ['although','though','notwithstanding','albeit']

# %%
def change_but(text):
    for x in but:
        text = re.sub(x,'but',text)
    return text
def change_although(text):
    for x in although:
        text = re.sub(x,'although',text)
    return text
def change_adversatives(text):
    text = change_but(text)
    text = change_although(text)
    return text

# %% [markdown]
# Now I want to capture the key information near but and although.

# %% [markdown]
# def although_phrase(text):
#     words = text.split()
#     for (index,word) in enumerate(words):
#         if word == 'altough.':
#             for x in range(index,index-10,-1):
#                 if re.sub('(.*)\.([a-z])\..*','\\2',str(wordnet.synsets(words[x])[0])) in ['v','adj']

# %% [markdown]
# #### Phrases

# %%
def preprocessing(text):

    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)',text)

    text = re.sub('\\n',' ',text)

    text = no_abbreviation(text)

    text = re.sub('[\W]+',' ', text.lower())

    text = change_adversatives(text)

    tokens = lemmatizer(text)
    text = ''
    for index, token in enumerate(tokens):

        #tokens[index] = no_typo(token)
        if token in stop:
            tokens[index] = ''
        else:
            text = text + tokens[index] + ' '
    return {'text':text,'emoticons':emoticons}

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jywsi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from tqdm import tqdm, tqdm_pandas
tqdm.pandas()
dictionary = train_10000_eng.text.progress_apply(preprocessing)
# Out:
# 100%|██████████| 9958/9958 [00:46<00:00, 212.47it/s]

# %%
emoticons = [dictionary[i]['emoticons'] for i in train_10000_eng.index]

# %%
texts = [dictionary[i]['text'] for i in train_10000_eng.index]

# %%
from gensim.models.phrases import Phrases, Phraser
# Out:
# D:\anaconda\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
sentence_stream = [sent.split(' ') for sent in texts]

# %%
bigram = Phraser(Phrases(sentence_stream, min_count=5, threshold=5))

# %%
gg = bigram[sentence_stream]

# %% [markdown]
# ## TF IDF

# %%
def concatenate(text):
    for x in text:
        return " ".join(text)

# %%
text1 = []
for i in range(len(gg)):
    text1.append(concatenate(gg[i]))

# %%
text1[5]
# Out:
# 'first to admit not excite_about go to la tavolta food snob group_of friend suggest go for_dinner look online at menu to nothing_special seem overpriced im also not big on order pasta go out ala outnumber thank_goodness order sea_bass special to_die for cooked perfectly_season perfectly perfect portion not say_enough good thing_about dish server ask seem proud_of dish say not chef incredible job hubby get crab tortellini also love heard mmmm good from around table waiter super_nice even give_u free_dessert of last people in restaurant service_slow place_pack but jug of wine large_group with good conversation not seem to bother anyone order calamari fry zucchini appetizer leave out mussel sea_bass special highly_recommend chicken_parm crab tortellini also good big chicken romano bit_bland house_salad teeny make_reservation but_still expect to wait for food go with large_group of people plan for to loud not go with date unless fight not feel_like hear_anything to say ask to sit in side room available'

# %%
TfidfVectorizer?
# Out:
# Object `TfidfVectorizer` not found.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer(analyzer='word', min_df = 1)

# %%
response =  tf.fit_transform(text1)

# %%
response
# Out:
# <9958x23720 sparse matrix of type '<class 'numpy.float64'>'
# 	with 472450 stored elements in Compressed Sparse Row format>

# %%
feature_names = tf.get_feature_names()

# %%
res_df = pd.DataFrame(response.toarray(),columns = feature_names)

# %%
res_df.loc[1]
# Out:
# 00                 0.0
# 000                0.0
# 00_pm              0.0
# 00am               0.0
# 00pm               0.0
# 01                 0.0
# 01pm               0.0
# 02                 0.0
# 025                0.0
# 03                 0.0
# 03pm               0.0
# 04                 0.0
# 05                 0.0
# 055                0.0
# 05am               0.0
# 06                 0.0
# 0600               0.0
# 07                 0.0
# 0700               0.0
# 08                 0.0
# 09                 0.0
# 0_50               0.0
# 0_star             0.0
# 0t                 0.0
# 10                 0.0
# 100                0.0
# 1000               0.0
# 10000              0.0
# 100psi             0.0
# 100th              0.0
#                   ...
# zoe                0.0
# zoey               0.0
# zoinks             0.0
# zoltan             0.0
# zombie             0.0
# zomg               0.0
# zomggggg           0.0
# zone               0.0
# zoo                0.0
# zounds             0.0
# zoës               0.0
# zucchini           0.0
# zuchinni           0.0
# zuma               0.0
# zumba              0.0
# zupas              0.0
# zuppas             0.0
# zzz                0.0
# çoban              0.0
# über               0.0
# 不要在这里吃             0.0
# 他们知道               0.0
# 你不必付饭费             0.0
# 在我们的汤里发现了一个蟑螂      0.0
# 她一点都不惊讶            0.0
# 她说                 0.0
# 对不起                0.0
# 我们刚在这里吃午饭          0.0
# 我把它展示给服务员          0.0
# 这意味着他们的厨房里有很多蟑螂    0.0
# Name: 1, Length: 23720, dtype: float64

# %%
value = sorted(res_df.iloc[1], reverse = True)[:10] 
value
# Out:
# [0.5023863951895555,
#  0.4118875991389761,
#  0.20985853140652785,
#  0.16075285315757512,
#  0.15340990624257073,
#  0.13066062023067374,
#  0.10231668815421514,
#  0.09642974531507637,
#  0.09642974531507637,
#  0.09642974531507637]

# %%
names = np.array(feature_names)[np.argsort(res_df.iloc[1])[-10:]][::-1]
names
# Out:
# array(['travis', 'blowout', 'hair', 'perfectly', 'shampoo', 'stylist',
#        'way', 'pagent', 'scented', 'swoosh'], dtype='<U36')

# %%
dd = dict(zip(names,value))

# %%
def gettoptfidf(df,x):
    feature_names = tf.get_feature_names()
    list1 = []
    for i in range(len(df)):
        value = sorted(df.iloc[i], reverse = True)[:x] 
        names = np.array(feature_names)[np.argsort(df.iloc[i])[-x:]][::-1]
        dd = dict(zip(names,value))
        list1.append(dd)
    return list1

# %%
tfidf_final = gettoptfidf(res_df,15)

# %%
tfidf_final
# Out:
# [{'pill': 0.4821741298410735,
#   '8gs': 0.29372218188546606,
#   'crook': 0.25980187038816643,
#   '69': 0.25980187038816643,
#   'total_bill': 0.2509195143373494,
#   'nerve': 0.2336410421762658,
#   'er': 0.22262848995335996,
#   'cent': 0.2196857311464784,
#   'hospital': 0.2183132563903161,
#   'charge_u': 0.2169992028400498,
#   'horrible_service': 0.20909710683872662,
#   '19': 0.20811684678923278,
#   'avoid': 0.1705599136195089,
#   'online': 0.1645988824294823,
#   'cost': 0.1493018543396883},
#  {'travis': 0.5023863951895555,
#   'blowout': 0.4118875991389761,
#   'hair': 0.20985853140652785,
#   'perfectly': 0.16075285315757512,
#   'shampoo': 0.15340990624257073,
#   'stylist': 0.13066062023067374,
#   'way': 0.10231668815421514,
#   'pagent': 0.09642974531507637,
#   'scented': 0.09642974531507637,
#   'swoosh': 0.09642974531507637,
#   'admirable': 0.09642974531507637,
#   'bouncey': 0.09642974531507637,
#   'beauuuutiful': 0.09642974531507637,
#   'style': 0.09481317985725224,
#   'greets': 0.0923197328342076},
#  {'dental': 0.4374674806421833,
#   'office': 0.4179022844837455,
#   'insurance': 0.2539450459568859,
#   'help': 0.24431589130584022,
#   'synergy': 0.1936998059360066,
#   'phillipp': 0.1936998059360066,
#   'bailey': 0.1750428359457508,
#   'jewel': 0.16819178725255243,
#   'organized': 0.16547290000608084,
#   'feel_comfortable': 0.15558727698930466,
#   'friendly_professional': 0.15407833428758957,
#   'assistant': 0.15012504434494925,
#   'dentist': 0.1392503726215529,
#   'procedure': 0.13856008927562993,
#   'sign_up': 0.1342898838519977},
#  {'summation': 0.2915335209394675,
#   'distribute': 0.2751820703607718,
#   'dawn': 0.2644116452054054,
#   'steak_sandwich': 0.260137325622321,
#   'friendly_accommodate': 0.24715844913656873,
#   'perfect_amount': 0.2236642073948745,
#   'caesar_salad': 0.2212006961650642,
#   'leaf': 0.2178281220721208,
#   'go': 0.20922488889996785,
#   'absolutely_delicious': 0.20861946265642367,
#   'pub': 0.20414570412277416,
#   'dressing': 0.19784903750105726,
#   'across': 0.1961785794735416,
#   'happy_with': 0.17453823378581854,
#   'perfectly': 0.16921209165634288},
#  {'reset': 0.34486667864984283,
#   'timer': 0.22991111909989523,
#   'gum': 0.2220506967833202,
#   'burn': 0.21049800963699844,
#   'session': 0.1825161016421683,
#   'admit': 0.16839840770959877,
#   'neglect': 0.16653802258749018,
#   'to': 0.15704885489677536,
#   'boyfriend': 0.1471619145015023,
#   'teeth': 0.1394519784004603,
#   'in': 0.1232587750059051,
#   'pain': 0.11987118712393219,
#   'at_point': 0.11935236265950587,
#   'room': 0.11206482247333563,
#   'check': 0.1095050262945037},
#  {'tortellini': 0.23761252662346438,
#   'sea_bass': 0.20339351158022048,
#   'large_group': 0.18345476621597342,
#   'crab': 0.17017032583256506,
#   'seem': 0.16963621845590138,
#   'not': 0.16705581806994865,
#   'go': 0.1566826303654126,
#   'to': 0.1556127293951032,
#   'outnumber': 0.13682445809859475,
#   'romano': 0.13682445809859475,
#   'tavolta': 0.13682445809859475,
#   'special': 0.1268609939067785,
#   'jug': 0.12685508541647122,
#   'good': 0.12220394502821731,
#   'also': 0.12001569202338327},
#  {'dessert': 0.421834745957175,
#   'tracy': 0.35007260675697244,
#   'tremendously': 0.21921360404645984,
#   'table': 0.2008867678722781,
#   'increase': 0.19493181859161182,
#   'must_say': 0.1800788165738969,
#   'mango': 0.1611941772192873,
#   'for': 0.15240913710980106,
#   'like': 0.14336871608044838,
#   'in': 0.12511942539916948,
#   'also': 0.11571925871702257,
#   '0_50': 0.11455312625864304,
#   'taro': 0.11455312625864304,
#   'shave_ice': 0.11455312625864304,
#   'markham': 0.10828505217716085},
#  {'down_hill': 0.539492296976919,
#   'quality': 0.2818506524740576,
#   'many_option': 0.24426511681442326,
#   'spend_money': 0.24002970720376818,
#   'service_slow': 0.23625731755590376,
#   'go': 0.2258013092648948,
#   'clearly': 0.1905167256048571,
#   '15': 0.18443019908888614,
#   'write': 0.18416547812505835,
#   'cut': 0.16296325326697175,
#   'change': 0.15224866693849415,
#   'food': 0.1491721967000921,
#   'worth': 0.14838975021537246,
#   'year': 0.1472841865319415,
#   'on': 0.14614421396587246},
#  {'66': 0.5392147291970685,
#   'register': 0.4189800343291456,
#   'big_deal': 0.4189800343291456,
#   'giant': 0.3960573852491243,
#   'buy': 0.27044986272725735,
#   'best': 0.18904955576345042,
#   'about': 0.18751112755446678,
#   'place': 0.12925170137088227,
#   'get': 0.12768871603413526,
#   'with': 0.11581098032457954,
#   'not': 0.10407500016768209,
#   'f21': 0.0,
#   'f_ckin': 0.0,
#   'f_cking': 0.0,
#   'f_ing': 0.0},
#  {'machine': 0.4146183507776704,
#   'play': 0.2750743025456244,
#   'quarter': 0.2534721369286504,
#   'row': 0.24716136268390035,
#   'sister': 0.22964905278010744,
#   'gentler': 0.1796871068248926,
#   'spend': 0.17931326910345396,
#   'pac': 0.16659465421076242,
#   'tilt': 0.16659465421076242,
#   'fun': 0.16175949744994386,
#   'league': 0.15602439815093844,
#   'pin': 0.1512774665672927,
#   'bowling': 0.14748711490019023,
#   'teen': 0.14584360777489735,
#   'saturday_morning': 0.14162877944742736},
#  {'walk_in': 0.42269076503893904,
#   'smdh': 0.27082926214247804,
#   'non_existent': 0.22960563916022095,
#   'over_past': 0.22722544452324117,
#   '5_min': 0.21924819686700553,
#   'different_thing': 0.21754850236597734,
#   'several_year': 0.21441544325781958,
#   'oh_well': 0.20440991700344993,
#   'at_bar': 0.17319182027556249,
#   'walk_out': 0.17002161368197174,
#   'sit_at': 0.17002161368197174,
#   'afternoon': 0.1639936709883371,
#   'on_friday': 0.16292196731878772,
#   'realize': 0.15898411591760353,
#   'list': 0.15509992125819166},
#  {'salad': 0.2759785168674829,
#   'entree': 0.2553696011119104,
#   'delicious': 0.2176352051436754,
#   'calamari': 0.2138435082782715,
#   'tender': 0.18897011766986102,
#   'right': 0.18198579308394316,
#   'eat': 0.16014885683892113,
#   '92': 0.15782012211599172,
#   'wonderful': 0.15109131410522397,
#   'riesling': 0.1370370418020666,
#   'diablo': 0.1348217834274685,
#   'marinara_sauce': 0.1348217834274685,
#   'comfortably': 0.13111987774768322,
#   'bit_bland': 0.13111987774768322,
#   'review': 0.13044455688720838},
#  {'bachelorette': 0.3833044539200078,
#   'reach_out': 0.36570545074931815,
#   'michael': 0.33440907205717296,
#   'save': 0.2558752075306523,
#   'planning': 0.19447072618823613,
#   'overwhelmed': 0.1916522269600039,
#   'vega_trip': 0.18285272537465908,
#   'in_law': 0.1628416567374378,
#   'info': 0.16056092363589963,
#   'vip': 0.15718497124938055,
#   'carpet': 0.15595754397312522,
#   'package': 0.14967927586094432,
#   'smooth': 0.14922346044979506,
#   'sister': 0.1454702851101254,
#   'red': 0.13241204309793164},
#  {'duck': 0.33752654517375213,
#   'congee': 0.2844766521582244,
#   'hubby': 0.2116163606567036,
#   'pho': 0.21061574267734298,
#   'mine': 0.20430458024005216,
#   'before': 0.1922172542526086,
#   'bside': 0.1689504317644175,
#   'gist': 0.1494393031316914,
#   'place': 0.14638917870561152,
#   'order': 0.13889032889072567,
#   'another_couple': 0.1357076095010515,
#   'ahead': 0.13201997702397683,
#   'menu': 0.12761647553757055,
#   'bad_part': 0.12719049008203773,
#   'understaffed': 0.12719049008203773},
#  {'in_downtown': 0.4588621461608017,
#   'lot_of': 0.39285009057233566,
#   'poor_quality': 0.27628134649556996,
#   'anything_wrong': 0.2663573713134369,
#   'high_quality': 0.2114174567736654,
#   'case': 0.20223218922316394,
#   'price_reasonable': 0.20048516639570518,
#   'downtown': 0.19186309395320184,
#   'pasta': 0.1831200374946025,
#   'staff_friendly': 0.17531958359130467,
#   'pizza': 0.144290701667566,
#   'option': 0.1434653912944541,
#   'owner': 0.14273912598150656,
#   'place': 0.1421719466196189,
#   'amazing': 0.14005173543478325},
#  {'tika': 0.2731028995067281,
#   'ovens': 0.2731028995067281,
#   'lunch_today': 0.24015969229938872,
#   'tandoori': 0.23153320029636792,
#   'biryani': 0.2291330236994699,
#   'great_addition': 0.22484197326045197,
#   'bbq_chicken': 0.21335749119610642,
#   'masala': 0.21202455177770818,
#   'staff_helpful': 0.21202455177770818,
#   'in_cleveland': 0.21074835069118783,
#   'scene': 0.20030395668673695,
#   'naan': 0.19943473062446196,
#   'assist': 0.19543063165225105,
#   'casual': 0.18087209745319371,
#   'with': 0.1660990669204027},
#  {'slim': 0.3183412607061384,
#   'sweet_tea': 0.3137274835315406,
#   'grill_chicken': 0.28881463900481497,
#   'texas': 0.2753066057327609,
#   'two_year': 0.2753066057327609,
#   'brew': 0.2721711863100985,
#   'since_open': 0.26926824134461075,
#   'never_disappoint': 0.25529663069690833,
#   'fan': 0.2174926448767747,
#   'ago': 0.21258977538590157,
#   'live': 0.19616214599781737,
#   'plus': 0.1839839643058001,
#   'huge': 0.17044290529107556,
#   'salad': 0.16291015211697826,
#   'fresh': 0.14928268656524954},
#  {'side': 0.31247687077120256,
#   'carb': 0.3054801650939534,
#   'vegetarian': 0.30447071642475576,
#   'on_wednesday': 0.23943718696341923,
#   'except': 0.22374895824997335,
#   'heavy': 0.2048237230943285,
#   'bbq': 0.20226860897649476,
#   'menu': 0.19565285637191668,
#   'main': 0.18935509665163328,
#   'extremely_salty': 0.14994192881455065,
#   'overload': 0.1475180578002479,
#   'night': 0.1404754549082806,
#   'completely_different': 0.13735987356459756,
#   'friendly': 0.13142316622721517,
#   'potato_salad': 0.12293025185370572},
#  {'sandwich_shop': 0.27874754036971633,
#   'search_for': 0.23177957706728783,
#   'deli': 0.22690400675558844,
#   'limit': 0.22261500990185432,
#   'on_strip': 0.21268351017183335,
#   'cashier': 0.20928105977662068,
#   'price_reasonable': 0.2074731438845514,
#   'value': 0.20254135512150587,
#   'snack': 0.20178177946122808,
#   'exactly': 0.19256053642085852,
#   'counter': 0.18819495634296687,
#   'order': 0.18612097593796745,
#   'like': 0.18452997976122418,
#   'prepare': 0.1838478576846364,
#   'walk': 0.16825410323812207},
#  {'on_planet': 0.3697249973669934,
#   'lamb': 0.28671269168535135,
#   'to_die': 0.283971808672797,
#   'mexican': 0.2803700587022098,
#   'chef': 0.25793114686746244,
#   'pick': 0.25545431379199934,
#   'wow': 0.2492134751577025,
#   'taco': 0.24366407551336672,
#   'fish': 0.2411038794913432,
#   'style': 0.23452143790945104,
#   'meat': 0.2062322223678118,
#   'amazing': 0.20358656222759342,
#   'dish': 0.19771605790829835,
#   'flavor': 0.19403398790530751,
#   'drink': 0.1695855672234594},
#  {'plumbsmart': 0.2479794848385968,
#   'sewer': 0.2479794848385968,
#   'landscape': 0.23407088085438923,
#   'wayne': 0.224909517615906,
#   'scott': 0.218066805160123,
#   'pipe': 0.21519808123618786,
#   'plumbing': 0.20805450721736007,
#   'badly': 0.19772187976320527,
#   'competitive': 0.19632528161798649,
#   'superior': 0.19499683793743225,
#   'damage': 0.17884908014500386,
#   'future': 0.1754833571262691,
#   'particularly': 0.16979026954910226,
#   'pleased_with': 0.16551981066370497,
#   'pricing': 0.1642332235546788},
#  {'snap': 0.2439903525243621,
#   'watch': 0.2316931574139798,
#   'jewelry': 0.22208721821860228,
#   'shock': 0.1926105312219458,
#   'repair': 0.1731289718556726,
#   'work': 0.1531385604320776,
#   'fix': 0.15207610077201072,
#   'shouting': 0.15030456667650519,
#   'someone': 0.1401373643148914,
#   'say': 0.13750748512400823,
#   'chalk_up': 0.1305111978785033,
#   'conduct_business': 0.1305111978785033,
#   'exhaust': 0.1305111978785033,
#   'blond': 0.1305111978785033,
#   'completely_unprofessional': 0.12840143237074536},
#  {'pettuccine': 0.4104954868976175,
#   'piccata': 0.3805857576716982,
#   'delicate': 0.3265282613378229,
#   'veal': 0.31335085442510663,
#   'staff_super': 0.28232026690729406,
#   'delightful': 0.28122778784564345,
#   'classic': 0.23565846228106627,
#   'kind': 0.22222508471841584,
#   'morning': 0.21930300365617875,
#   'yummy': 0.2053751322968515,
#   'owner': 0.17854890153044278,
#   'fresh': 0.16444572571050423,
#   'restaurant': 0.13786699943884606,
#   'love': 0.12579514841598455,
#   'also': 0.12002215738600515},
#  {'hot_pot': 0.6621528077753052,
#   'shabu': 0.17391876171545717,
#   'quality_quantity': 0.16797265992963928,
#   'hot_water': 0.16139053862063188,
#   'soup_base': 0.16139053862063188,
#   'perspective': 0.16139053862063188,
#   'miserable': 0.15364599837219062,
#   'appetite': 0.14903384351090512,
#   'quantity': 0.1470638770631832,
#   'judge': 0.13576736323885583,
#   'must_say': 0.13419681025539126,
#   'anyways': 0.13369873787550007,
#   'good': 0.13171148906969724,
#   'im': 0.12968572651766458,
#   'limit': 0.12889066682147074},
#  {'westgate': 0.32012411631508186,
#   'balcony': 0.29076384377464903,
#   'wristband': 0.2713168358523275,
#   'theater': 0.2383047108962215,
#   'seat': 0.21571486271997117,
#   'superbowl': 0.2125467593254183,
#   'bet': 0.19341694107050517,
#   'to': 0.17122751377929216,
#   'in_line': 0.15836064305634806,
#   'watch': 0.14561730921901297,
#   'upstairs': 0.1434849278858186,
#   'at': 0.13977790950625096,
#   'auditorium': 0.13565841792616376,
#   'patron': 0.13217355943408518,
#   'in': 0.12094812310890701},
#  {'lettuce_wrap': 0.40859778912514005,
#   'dish': 0.31297084316061274,
#   'raku': 0.2517071392537953,
#   'panang': 0.23336712670893275,
#   'drunken_noodle': 0.2226389071074326,
#   'seabass': 0.21856022731023975,
#   'meal': 0.20027431657868575,
#   'in_mouth': 0.17834708907434507,
#   'start_off': 0.17380009536757313,
#   'setting': 0.17311280880007984,
#   'terrific': 0.16874495623224667,
#   'intimate': 0.1681759225773363,
#   'duck': 0.1676188694728449,
#   'rating': 0.15249884162496405,
#   'on_yelp': 0.15188348725895157},
#  {'toe': 0.2905012955799531,
#   'toenail': 0.24462246542801466,
#   'charge': 0.2409755551023507,
#   'wait_until': 0.1936675303866354,
#   'girl': 0.18988727540420475,
#   'pay': 0.16524142762702024,
#   'design': 0.15449044389544825,
#   'nail': 0.14645304911267237,
#   'tell': 0.13882732432490802,
#   'to': 0.12713708812386984,
#   'extra': 0.12297736531868324,
#   'stone_massage': 0.12231123271400733,
#   'not_even': 0.11671476036108089,
#   'ask_for': 0.11416177214284898,
#   'appal': 0.11300257805828406},
#  {'scottsdale_location': 0.36581219609850435,
#   'care_less': 0.3605104141152171,
#   'ignore_u': 0.34395797425652347,
#   '10_min': 0.3182759697605152,
#   'manner': 0.29567524456487815,
#   'sit_at': 0.2573668188638738,
#   'walk_out': 0.2573668188638738,
#   'downtown': 0.25035582145465146,
#   'bartender': 0.23387001835210178,
#   'love_place': 0.21443414438818373,
#   'water': 0.20266930075147774,
#   'bar': 0.1797655617540875,
#   'menu': 0.16172528780458634,
#   'could': 0.15040612828161495,
#   'but': 0.0786802276599719},
#  {'gi': 0.3909287270414569,
#   'west_valley': 0.35455994062702956,
#   'resto': 0.34377270606369037,
#   'wont': 0.28800324463705695,
#   'let_u': 0.28309237937925785,
#   'support': 0.2637972966959871,
#   'best': 0.2587456941478487,
#   'chinese': 0.2463934124131333,
#   'trust': 0.23555139384737875,
#   '5_star': 0.21354851242656708,
#   'wrong': 0.21131242039104925,
#   'highly_recommend': 0.18591356839146966,
#   'business': 0.18221896557413672,
#   'come': 0.11066478416949228,
#   'place': 0.08845120279691522},
#  {'freind': 0.34968156322201965,
#   'scampi': 0.34968156322201965,
#   'lasagna': 0.27318340882259573,
#   'hamburger': 0.25761582056112203,
#   'get': 0.19540476627777775,
#   'special': 0.16932597806239497,
#   'under_cook': 0.15601160782964696,
#   'manger': 0.15375050352422306,
#   'pretty_bland': 0.15172787680002656,
#   'dish': 0.15138272099654487,
#   'pretty_disappointed': 0.14989818836734772,
#   'ok_nothing': 0.14989818836734772,
#   'chicken': 0.14690116288904992,
#   'last_weekend': 0.1415413009797489,
#   'attach': 0.1404440195681732},
#  {'in_pittsburgh': 0.46634323763332963,
#   'transformation': 0.31182125889534235,
#   'epitomize': 0.31182125889534235,
#   'rumor': 0.2974863909599031,
#   'must_visit': 0.2606666906750376,
#   'alike': 0.2606666906750376,
#   'visitor': 0.24703192748693395,
#   'none': 0.2286904219772956,
#   'process': 0.1851290486418024,
#   'feel_like': 0.18321754883319538,
#   'second': 0.16857390920214307,
#   'local': 0.1664848717099545,
#   'atmosphere': 0.15352889130423547,
#   'place': 0.1457072789289571,
#   'definitely': 0.1275479209050284},
#  {'tire': 0.5531899877743768,
#   'two': 0.34207981798872694,
#   '280': 0.28256077336959223,
#   'tread': 0.2736355358263705,
#   'new_tire': 0.242250964800717,
#   'tell': 0.21381059480066786,
#   'on': 0.16405969571605247,
#   'car': 0.13787917632543367,
#   'buy': 0.13377301797631064,
#   'couple_month': 0.12423835212091332,
#   'discount_tire': 0.12260396520568409,
#   'new': 0.11676724540755687,
#   'take_car': 0.10608782264336143,
#   'price': 0.10073189265877938,
#   'pressure': 0.09795122686013831},
#  {'coke': 0.29921332567137365,
#   'bring_u': 0.27622965668774246,
#   'somewhere': 0.26819525748383655,
#   'server': 0.24199243325183373,
#   'between': 0.22109118806353584,
#   'handheld': 0.19150025235531623,
#   'hover': 0.17692587781828856,
#   'meet_friend': 0.16066849506408898,
#   'terminal': 0.1576596026523807,
#   'piss': 0.15382604070563444,
#   'get_attention': 0.15382604070563444,
#   '20_min': 0.1477771287442332,
#   'starter': 0.14379805495121872,
#   'napkin': 0.13455976553972657,
#   'credit_card': 0.13234441552507162},
#  {'smokey': 0.2781527498573792,
#   'catfish': 0.2041985867295985,
#   'place': 0.20003080031663537,
#   'garlic_fry': 0.18948915903494934,
#   'buffalo': 0.16596418770159557,
#   'ok': 0.16270149775492457,
#   'go': 0.15861913299357439,
#   'on_wall': 0.15133095330243906,
#   'chili': 0.14999478769963734,
#   'brisket': 0.14564262370071931,
#   'bbq': 0.13520669690635684,
#   'also': 0.13499890383492363,
#   'fairly': 0.13232222735495303,
#   'head': 0.1240673791215592,
#   'delicious': 0.11938375811571111},
#  {'piccadilly': 0.43234912640623535,
#   'frozen_yogurt': 0.39212692745520983,
#   'chocolate_caramel': 0.3140193969355963,
#   'turtle': 0.2893410295907728,
#   'yogurt': 0.2367938011175109,
#   'kiwispoon': 0.22579850952027983,
#   'mochi': 0.19009837198940646,
#   'topping': 0.18594300001636868,
#   'brownie': 0.16782800531106665,
#   'ice_cream': 0.11925815722925122,
#   'at': 0.11136953015847836,
#   'marginally': 0.10808728160155884,
#   'froyo': 0.09986115915328433,
#   'height': 0.09379878993550775,
#   'flavor': 0.09184257023961842},
#  {'banh_mi': 0.3806262182035332,
#   'fish_taco': 0.3242048705767967,
#   'pork_belly': 0.3141703789557045,
#   'crispy': 0.2519823785100812,
#   'baguette': 0.20132937258913539,
#   'bam': 0.19520406931102624,
#   'esp': 0.1881923750223383,
#   'tender_juicy': 0.18118068073365032,
#   'corn_beef': 0.17830994697058405,
#   'benedict': 0.17699216298997272,
#   'hash': 0.17455282219693893,
#   'ham': 0.16141582463014184,
#   'chip_salsa': 0.15544143865477966,
#   'compliment': 0.15440413034145384,
#   'service_excellent': 0.15108617180102957},
#  {'buffet': 0.33967440905731494,
#   'cold': 0.32155618039631373,
#   'food': 0.19759156288309565,
#   'towards_end': 0.18593720419402227,
#   'forgot': 0.1832423828355971,
#   'chief': 0.18083178298692518,
#   'server': 0.17554695469268808,
#   'lamp': 0.16614646305263786,
#   'at_bellagio': 0.16385659982877554,
#   'many_option': 0.1617752076354387,
#   'rio': 0.1617752076354387,
#   'horrible_experience': 0.1617752076354387,
#   'crab_leg': 0.15421943064037574,
#   'freshly_make': 0.15283236734380734,
#   'must_say': 0.14854905388231135},
#  {'ahwahtukee': 0.4017726079133326,
#   'breakfast_spot': 0.32271950780776154,
#   'wait_until': 0.30452595861230236,
#   'family_run': 0.2934453493903357,
#   'croissant': 0.29185143633538685,
#   'flat': 0.262577277917961,
#   'support': 0.2595593026731241,
#   'bomb': 0.25540181582620347,
#   'twice': 0.20665050836829546,
#   'fantastic': 0.19015502439690746,
#   'business': 0.17929155541251762,
#   'item': 0.1752464692565458,
#   'new': 0.15895456609781186,
#   'ca_not': 0.15312213791754115,
#   'well': 0.11972162290864083},
#  {'cooky': 0.3681981042083834,
#   'hate': 0.21228587160585724,
#   'foccacia': 0.16806830240873488,
#   'macadamia': 0.16275953465376447,
#   'wateringly': 0.16275953465376447,
#   'breakfast': 0.1616620273553907,
#   'belief': 0.15864173447299368,
#   'pizza': 0.15437479644929478,
#   'excellent': 0.1533177165024626,
#   'dessert_section': 0.14996847899205987,
#   'portuguese': 0.147794958840296,
#   'white_chocolate': 0.14585067881128908,
#   'chimichurri': 0.14248619108532562,
#   'ice_cold': 0.14100911556964846,
#   'soft_serve': 0.13717742333035526},
#  {'body': 0.5051733303777058,
#   'sac': 0.2628096467942826,
#   'operating': 0.24366067774474712,
#   'slipper': 0.23245924892329886,
#   'room': 0.22661369806612622,
#   'butcher': 0.22451170869521164,
#   'surgery': 0.19303355739532815,
#   'nasty': 0.17805124000144243,
#   'wish_could': 0.17388458834579268,
#   'ruin': 0.1728010721123916,
#   'promise': 0.16621469992902885,
#   'alone': 0.164197298589953,
#   'talk_about': 0.16055702435988303,
#   'dirty': 0.15418854948506977,
#   'out': 0.15279998714072562},
#  {'wonton_soup': 0.6610040527737224,
#   'satay': 0.3305020263868612,
#   'roti': 0.30519748989969425,
#   'fried': 0.24445493183377642,
#   'definitely_back': 0.22375017203494257,
#   'noodle': 0.21825297341316421,
#   'shrimp': 0.20275101444501295,
#   'dish': 0.16688759415391788,
#   'chicken': 0.1619470273197553,
#   'ever': 0.15264579584143675,
#   'one_of': 0.14473718054867835,
#   'delicious': 0.13881734862254594,
#   'best': 0.127575133687363,
#   'service': 0.1045810363532319,
#   'great': 0.09470905376993974},
#  {'inside': 0.24751011566700978,
#   'dress': 0.23875227839187363,
#   'on_list': 0.23362442576263434,
#   'door': 0.2251189602369189,
#   'let': 0.21195036506153797,
#   'caucasian': 0.2018655290375166,
#   'line': 0.2006395537910074,
#   'flip_flop': 0.18330543656837797,
#   'guy': 0.18226038970097172,
#   'heel': 0.17319302914514126,
#   'pull_out': 0.16874930080772993,
#   'of': 0.1617484495431324,
#   'jean': 0.15992248542632068,
#   'people': 0.15319079369407643,
#   'particular': 0.14187673842651966},
#  {'jose': 0.6046300853583461,
#   'excellent_service': 0.421058545108017,
#   'thanks': 0.3420878604155503,
#   'dinner': 0.2869099160267339,
#   'could_not': 0.2831719459269689,
#   'sure': 0.2677988889311476,
#   'back': 0.2198132377878974,
#   'food': 0.15184986109864057,
#   'good': 0.14939501145215067,
#   'for': 0.11042215434792044,
#   'f_ing': 0.0,
#   'ezmart': 0.0,
#   'f13': 0.0,
#   'f21': 0.0,
#   'f_ckin': 0.0},
#  {'coupon': 0.27169597682985813,
#   'eat': 0.22064290897395752,
#   '37': 0.1806486279178201,
#   'crab_legs': 0.1806486279178201,
#   'self_serve': 0.17847018377260765,
#   'mirage': 0.17465193483618302,
#   'retail': 0.17138116989120025,
#   'flag_down': 0.16852039555917894,
#   'bar_area': 0.1626273596339753,
#   'wine_beer': 0.15970555358660235,
#   'price_point': 0.1588091106975507,
#   'two_people': 0.15478888963258208,
#   'drink': 0.15459396618107285,
#   'layout': 0.15137113791853346,
#   'unlimited': 0.14896297964055544},
#  {'playground': 0.4654843825771234,
#   'crap': 0.3158215923387958,
#   'duck': 0.27279346948954336,
#   'green': 0.18526330579631922,
#   'on': 0.18216717915989916,
#   'to': 0.16306322361613876,
#   'im': 0.16210974355615645,
#   'waterfall': 0.139979449071857,
#   'nice': 0.1316759767442293,
#   'swing': 0.13161684671479706,
#   'slide': 0.12915201419629269,
#   'kid': 0.11466082527085456,
#   'equipment': 0.11141739183778199,
#   'in': 0.10878224628859831,
#   'think_about': 0.1077386966314363},
#  {'project': 0.38646363327436456,
#   'paul': 0.27573151087082887,
#   'ace': 0.2732175595397173,
#   'store': 0.2276988285244552,
#   'help': 0.21860824933950032,
#   'yourselfer': 0.17331813844259397,
#   'bra': 0.1606897448153303,
#   'name': 0.16036647497390827,
#   'personalized': 0.15330260809903504,
#   'hardware': 0.15049414906267808,
#   'every_aspect': 0.14806135118806663,
#   'home_depot': 0.14806135118806663,
#   'bounce': 0.14399591648615392,
#   'big': 0.14318572213660347,
#   'in_tempe': 0.13786575543541443},
#  {'burger': 0.4810135520567896,
#   'cajun': 0.236485213516454,
#   'bun': 0.19316234546833047,
#   'beer_batter': 0.18761817096094877,
#   'patio': 0.1815130118157727,
#   'jones': 0.17857748276564783,
#   'topping': 0.1746739466167882,
#   'jalapeños': 0.16872590227709733,
#   'spicy': 0.15325500695586788,
#   'lime': 0.1453179337532336,
#   'ring': 0.14370539413306765,
#   'avocado': 0.1334864728715461,
#   'soda': 0.130714996664597,
#   'strawberry': 0.130714996664597,
#   'small': 0.12493385728146512},
#  {'lamb': 0.29014466996272104,
#   'unsavory': 0.23108728701858203,
#   'rogan': 0.22378794073897043,
#   'bit': 0.20225507419174119,
#   'josh': 0.1959128929346995,
#   'give_chance': 0.19025108009657868,
#   'chicken_tikka': 0.1886135466550879,
#   'run_down': 0.18562504217236978,
#   'samosa': 0.18295173381696708,
#   'masala': 0.179405559370249,
#   'from_outside': 0.17183190812762056,
#   'dining_room': 0.17024558148848604,
#   'naan': 0.16875262371995886,
#   'surprised': 0.16127268620142807,
#   'friday': 0.15637814881976603},
#  {'employee': 0.41735165959801823,
#   'entire_time': 0.30990445831822483,
#   'from_outside': 0.3003638002435064,
#   'chat_with': 0.2949811819813097,
#   'drive_thru': 0.2868948239461421,
#   'window': 0.24583493190035138,
#   'make': 0.24000759099577304,
#   'talk_to': 0.23014132450011124,
#   'head': 0.22674969734865805,
#   'hand': 0.20760274090398748,
#   'cook': 0.19546622369944094,
#   'food': 0.19151646156413699,
#   'busy': 0.18760443413100206,
#   'before': 0.16001036683721506,
#   'people': 0.14842975274097428},
#  {'grill_cheese': 0.2896912521805305,
#   'goat_cheese': 0.2646511073273235,
#   'accomadate': 0.19240220751845089,
#   'fateful': 0.19240220751845089,
#   'ther': 0.1783833008239145,
#   'portobello': 0.17018276610650193,
#   'fritter': 0.16198223138908932,
#   'patrick': 0.15985131420480228,
#   'red_wine': 0.15165077948738973,
#   'rd': 0.1491193540241141,
#   'vegetarian_option': 0.14796332469455292,
#   'never_hear': 0.14390475844064557,
#   'shopping_center': 0.13976278997714037,
#   'let_tell': 0.13976278997714037,
#   'venture': 0.13902725411314143},
#  {'machine': 0.6319295763253716,
#   'break': 0.27903875497186187,
#   'sew': 0.245223904715397,
#   '35th': 0.1991747956759125,
#   'vac': 0.19068560083849237,
#   'repair': 0.17206526899387575,
#   'to': 0.1698936031570462,
#   'ave': 0.1499442150543496,
#   'still': 0.11626100982161475,
#   'people': 0.10510183317759143,
#   'bill': 0.10383059114300497,
#   'sewing': 0.09958739783795625,
#   'kings': 0.09958739783795625,
#   'elna': 0.09958739783795625,
#   'possession': 0.09534280041924618},
#  {'gtfoh': 0.26276393905484097,
#   'continuo': 0.26276393905484097,
#   'permanently': 0.24361830038567228,
#   'forehead': 0.23745478140350498,
#   'deem': 0.23241881971185174,
#   'option': 0.2297463758560373,
#   'hh': 0.22121933903803115,
#   'stamp': 0.21830914273433635,
#   'th': 0.21830914273433635,
#   'staff': 0.1877308839499185,
#   'last_visit': 0.18705832526921395,
#   'hit_miss': 0.18217126592179317,
#   'across': 0.1692826194812313,
#   'personable': 0.16747073608420412,
#   'patron': 0.1634014332941465},
#  {'first_class': 0.6825519138703543,
#   'cocktail': 0.46940466702456196,
#   'overall': 0.35697282012037196,
#   'restaurant': 0.2792868331583081,
#   'great': 0.19559288824406587,
#   'food': 0.18872886401610448,
#   'good': 0.18567781753005325,
#   'f_ckin': 0.0,
#   'eyelash': 0.0,
#   'eyeliner': 0.0,
#   'eyes': 0.0,
#   'ez': 0.0,
#   'ezmart': 0.0,
#   'f13': 0.0,
#   'f21': 0.0},
#  {'club': 0.30554373375173627,
#   'cute': 0.30141200324562223,
#   'mailer': 0.24162208442851563,
#   'music_playing': 0.2284121300930691,
#   'watch_sport': 0.2284121300930691,
#   'at_ease': 0.20562006965165777,
#   'on_monday': 0.1894488454153116,
#   'greet_by': 0.18613842731277902,
#   'shirt': 0.18248314514379296,
#   'good': 0.1791035623817673,
#   'say': 0.16307386919811206,
#   'wear': 0.1626608190119556,
#   'baby': 0.16101672060296887,
#   'toast': 0.15770630250043627,
#   'center': 0.1571441623861193},
#  {'kristine': 0.22885286758355206,
#   'cole': 0.21143572392440485,
#   'anna': 0.21143572392440485,
#   'everyone': 0.2093622421814064,
#   'flood': 0.20124734801413047,
#   'tim': 0.1962049696721717,
#   'award': 0.1962049696721717,
#   'night': 0.19445799037726327,
#   'privacy': 0.19014513951413517,
#   'with': 0.18558205392591717,
#   'communication': 0.16314513422718838,
#   'work': 0.16236557864683268,
#   'compliment': 0.15918429294696326,
#   'blow_away': 0.1581585331041001,
#   'gentleman': 0.1576609400760689},
#  {'boba_tea': 0.6265427631593157,
#   'jelly': 0.2649943621283404,
#   'milk_tea': 0.17666290808556026,
#   'milk': 0.16236995095185472,
#   'chewy': 0.15672816197989206,
#   'ball': 0.14855156257754273,
#   'snack': 0.1429097736055801,
#   'fruit': 0.14264502535825016,
#   'honeydew': 0.12026073886348163,
#   'lee_lee': 0.11149824024723533,
#   'explosion': 0.10637250714411024,
#   'flavored': 0.10637250714411024,
#   'fry': 0.10291959750592058,
#   'popcorn_chicken': 0.10273574163098904,
#   'slush': 0.10124677404098513},
#  {'kale': 0.4282758285613525,
#   'farm': 0.40895643293968026,
#   'fresh_delicious': 0.3946555232891901,
#   'grit': 0.36149552457272055,
#   'yum': 0.3117925491687472,
#   'unique': 0.29200899500890704,
#   'would_definitely': 0.2856523325411688,
#   'choice': 0.2431205220769154,
#   'menu': 0.19928312536225637,
#   'f_ing': 0.0,
#   'ez': 0.0,
#   'ezmart': 0.0,
#   'f13': 0.0,
#   'f21': 0.0,
#   'f_ckin': 0.0},
#  {'snicker': 0.41369810669272605,
#   'ooooooh': 0.22889609434604125,
#   'sanwiches': 0.22889609434604125,
#   'waaaaaaay': 0.22889609434604125,
#   'midwestern': 0.21914012328638047,
#   'veil': 0.2122181516614531,
#   'tasty': 0.19823804607142778,
#   'bachelorette_party': 0.19554020897686497,
#   'red_meat': 0.19270620954213152,
#   'tot': 0.1878778347737446,
#   'super_fun': 0.18207518986066817,
#   'palm': 0.18207518986066817,
#   'but_hey': 0.17013032999732716,
#   'damn_good': 0.16910629523261608,
#   'cookie': 0.1495943531132945},
#  {'teaser': 0.400366351865735,
#   'galley': 0.37119465678578417,
#   'on_earth': 0.31285126662588253,
#   'pair_with': 0.2975780768883247,
#   'milkshake': 0.29578691892163944,
#   'melt_in': 0.28782250665162823,
#   'heaven': 0.2693313829956727,
#   'phenomenal': 0.2478328473982414,
#   'mouth': 0.24564607710899908,
#   'boy': 0.2415864638674343,
#   'potato': 0.21838151102482367,
#   'burger': 0.18158313450112043,
#   'like': 0.10877288045013896,
#   'extremely_salty': 0.0,
#   'extremely_helpful': 0.0},
#  {'vegetarian': 0.26742864211301376,
#   'dinner': 0.2601601864603639,
#   'others': 0.2340384924675299,
#   'server': 0.18349567755939025,
#   'dark': 0.18341239435462822,
#   'would': 0.16889055190177374,
#   'tip': 0.15950773836038212,
#   '165': 0.14520895586088203,
#   'incase': 0.1406222455082516,
#   'not': 0.13227559274252393,
#   'hush_puppy': 0.12769303519535066,
#   'moon': 0.1260132010513331,
#   'on_facebook': 0.12449360622676217,
#   'like': 0.12362155343302561,
#   'grace': 0.12310632484272023},
#  {'cash': 0.46766310852959686,
#   'unqualified': 0.24782543131733892,
#   'take': 0.23870588008444255,
#   'wo_not': 0.23695307243085115,
#   'incapable': 0.22476979596443272,
#   'knight': 0.21506439266834543,
#   'concession': 0.20792525648731977,
#   'slight': 0.19360985319439197,
#   'pink': 0.18341415231595953,
#   'register': 0.1817645090920656,
#   'stupid': 0.17873797284680135,
#   'upstairs': 0.1747487780187955,
#   'worker': 0.16134810891394621,
#   'handle': 0.15409293511732333,
#   'section': 0.15006429484203054},
#  {'pretzel': 0.3523900252145795,
#   'cheese_dip': 0.3062442204613365,
#   'wonton': 0.17619501260728976,
#   'caesar_salad': 0.1676689426130072,
#   'with': 0.15679864494553283,
#   'for': 0.15237465105232806,
#   'tuna': 0.14911707946696653,
#   'sauce': 0.14491276848230664,
#   'on_side': 0.13336808657841362,
#   'patio': 0.13167952412759218,
#   'to': 0.1312570085972038,
#   'sausage': 0.13068089374291003,
#   'guests': 0.11049042349236433,
#   'may': 0.11015062645889807,
#   'of': 0.10717000212110556},
#  {'awful': 0.3009310664313245,
#   'luke_warm': 0.21515198653788747,
#   'pretty': 0.21266361794869248,
#   'fixing': 0.2097612187694999,
#   'national': 0.2097612187694999,
#   'entire_experience': 0.2014292937375151,
#   'grease': 0.18770660093714273,
#   'cheeseburger': 0.18770660093714273,
#   'day': 0.18445466365309712,
#   'tray': 0.18107501305954996,
#   'best_thing': 0.17508054006797621,
#   'napkin': 0.1719164458248333,
#   'shower': 0.17018269900760838,
#   'difficult_to': 0.1690860670764025,
#   'disappointment': 0.16701860476446545},
#  {'system': 0.38503699259453644,
#   'psvr': 0.3240144606693563,
#   'employee': 0.24037621306969176,
#   'tell': 0.23472819732367453,
#   'first': 0.18287669931955752,
#   'get': 0.17334460518405098,
#   '01pm': 0.16200723033467815,
#   'gamestop': 0.16200723033467815,
#   'illiminate': 0.16200723033467815,
#   'name': 0.14990080485813415,
#   'launch': 0.14640285726908445,
#   'department_store': 0.14329793271714278,
#   'come': 0.13171978932129672,
#   'write_down': 0.1288685038784179,
#   'midnight': 0.1211712258795896},
#  {'mario': 0.3290826694583727,
#   'pizza': 0.24995669796543132,
#   'recycle': 0.18949572464936884,
#   'scarpariello': 0.18949572464936884,
#   'local': 0.18760422386211775,
#   'backwards': 0.16761193648515202,
#   'quite_possibly': 0.1618814585020502,
#   'bend': 0.15953528139459444,
#   'ala': 0.15553802500527836,
#   'penne': 0.15221039410359977,
#   'work_hard': 0.14686671434024715,
#   'marketing': 0.14686671434024715,
#   'vodka': 0.1436294213821315,
#   'lasagna': 0.14173089193161906,
#   'jerk': 0.14173089193161906},
#  {'kabob': 0.34344302302965474,
#   'overrun': 0.23764835250914185,
#   'overlea': 0.23764835250914185,
#   'borrow': 0.22033269837551414,
#   'zipcar': 0.22033269837551414,
#   'hiding': 0.22033269837551414,
#   'per_month': 0.20301704424188646,
#   'dingy': 0.1950616852355103,
#   'regardless_of': 0.17774603110188258,
#   'totally_worth': 0.1755723817646293,
#   'strip_mall': 0.16999798621766204,
#   'membership': 0.1668712596659958,
#   'limit': 0.1557813171466217,
#   'must_try': 0.15396370055800215,
#   'likely': 0.15310219420843096},
#  {'severn': 0.29492400745873754,
#   'checkup': 0.2823538057268687,
#   'arise': 0.24829470219980437,
#   'discomfort': 0.24207352293384213,
#   'bella': 0.23937600213647783,
#   'whatsoever': 0.22058462113864669,
#   'family_friend': 0.21310813143918778,
#   'currently': 0.20619025022303888,
#   'plan_on': 0.19451871813972968,
#   'las_vega': 0.1927466968775447,
#   'pain': 0.1813465182294987,
#   'great_experience': 0.17556199311234946,
#   'drop': 0.17523392727789533,
#   'smile': 0.17490929675089156,
#   'live_in': 0.1715461872276067},
#  {'sign': 0.32037277043454215,
#   'stitch': 0.27860963181066645,
#   'wreck': 0.252690088192042,
#   'right': 0.22371569759219562,
#   'toy': 0.2149977920294124,
#   'paperwork': 0.21254921927844506,
#   'wish_would': 0.21254921927844506,
#   'nervous': 0.21139471137388646,
#   'stuffed': 0.1978786813799007,
#   'earlier': 0.1925450667982602,
#   'super_nice': 0.18800477586116102,
#   '5_minute': 0.18096838265787404,
#   'several_time': 0.17667473478614934,
#   'doctor': 0.17595491737304655,
#   'otherwise': 0.17595491737304655},
#  {'expect': 0.2505973398574863,
#   'to': 0.19896434625555554,
#   'restaurant': 0.19585044292413714,
#   'at': 0.1725715453538897,
#   'italian_restaurant': 0.16943929019303638,
#   'kabob': 0.1685475744886784,
#   'venetian': 0.14945500725501415,
#   '4_5': 0.14866398770640243,
#   'not': 0.14239688385252922,
#   'piece_of': 0.1322592390690152,
#   'reservation': 0.13052773308000015,
#   'accommodate': 0.12997671035246525,
#   'sell': 0.12292289568516959,
#   'know': 0.11695075006351545,
#   'waiter': 0.11617750620986199},
#  {'skirt_steak': 0.3162081293622944,
#   'ahi_tuna': 0.2974042820750573,
#   'not_familiar': 0.2974042820750573,
#   'lively': 0.29269203289718576,
#   'ravioli': 0.27501524258454985,
#   'atmosphere_great': 0.27501524258454985,
#   'scottsdale': 0.23722933891014153,
#   'loud': 0.21814861939828292,
#   'fairly': 0.21814861939828292,
#   'list': 0.2086730580148235,
#   'wine': 0.19675733428039296,
#   'guess': 0.18823600940071322,
#   'really_good': 0.18318049794149144,
#   'appetizer': 0.18260894712418255,
#   'huge': 0.17408067401996558},
#  {'bm': 0.534490007093973,
#   'ether': 0.2672450035469865,
#   'fry': 0.22870929000151238,
#   'mmm': 0.214661662617306,
#   'hometown': 0.21257979477173222,
#   'many_thing': 0.19743811094013908,
#   'bloody_mary': 0.1884919940265166,
#   'hand_down': 0.16432691026096466,
#   'presentation': 0.16224504241539087,
#   'rock': 0.16158401520704915,
#   'not_disappoint': 0.15849383043912685,
#   'nail': 0.1531775760250631,
#   'veggie': 0.14614448187501475,
#   'seriously': 0.14558448273021715,
#   'bacon': 0.14294061824617393},
#  {'cost': 0.3008285037477025,
#   'initial': 0.28223328936263203,
#   'insurance': 0.2586305552069327,
#   'additional': 0.24478758328192227,
#   'talk': 0.22238646166844764,
#   'doubled': 0.1972737375676539,
#   'payless': 0.17827253008641733,
#   'traveler': 0.17449171073680095,
#   'waiver': 0.17129507352452616,
#   'misleading': 0.17129507352452616,
#   'collision': 0.16608354248019636,
#   'purposely': 0.1619222153083266,
#   'rent_from': 0.1554905032555644,
#   'experienced': 0.1554905032555644,
#   'small': 0.15492403089625872},
#  {'quiet': 0.3427675648608768,
#   'margarita': 0.33814663422219715,
#   'front': 0.3245686785430602,
#   'grill': 0.31878555898008654,
#   'sign': 0.31267826031247403,
#   'miss': 0.28317931125257506,
#   'almost': 0.2646255411076143,
#   'waitress': 0.26050582255650967,
#   'pizza': 0.24976340184975185,
#   'bar': 0.23846832489107608,
#   'small': 0.2230510194519228,
#   'out': 0.1651340804141705,
#   'great': 0.13361008121358361,
#   'good': 0.12683706704506953,
#   'place': 0.12304794635044462},
#  {'basement': 0.3950338043051423,
#   'sell': 0.26171103918834077,
#   'donnells': 0.24830866580257321,
#   'waterproof': 0.24830866580257321,
#   'subsequently': 0.2302162745445505,
#   'say': 0.2271674169587751,
#   'exactly_need': 0.21212388328652773,
#   'flood': 0.20904953367591333,
#   'would': 0.20737128142885758,
#   'nick': 0.19751690215257114,
#   'bet': 0.16947013000784153,
#   'crew': 0.16822695204890684,
#   'amount': 0.16041617291468654,
#   'hopefully': 0.15588324257936453,
#   'quote': 0.153019903035833},
#  {'yelp': 0.2824543975052633,
#   'chef': 0.27854654007405333,
#   'cielo': 0.2575839714357211,
#   'discerning': 0.23881575818006387,
#   'kudos': 0.22366314882988222,
#   'across_board': 0.21685835625986943,
#   'compel': 0.21685835625986943,
#   'tenderloin': 0.204894935574225,
#   'soo': 0.18612672231856775,
#   'judge': 0.1778579619688381,
#   'of_mine': 0.17715462870584772,
#   'impress': 0.1758005061404322,
#   'even': 0.17016842410403488,
#   'mac_cheese': 0.15838641545019047,
#   'really_nice': 0.15362385761189276},
#  {'allergy': 0.2611766352784598,
#   'on_side': 0.2119843746792724,
#   'music': 0.18947067386517585,
#   'on': 0.16314981358792066,
#   'fryer': 0.16225518222824267,
#   'also': 0.16090418714323204,
#   'bravo': 0.15443665109618832,
#   'chicken_parmesan': 0.15443665109618832,
#   'sever': 0.15240499792730391,
#   'whatever_reason': 0.1488893149762129,
#   'update_review': 0.14334197885623748,
#   'seem_bit': 0.14217296213060007,
#   'tasted': 0.13809831626271812,
#   'olive_oil': 0.1363441192533664,
#   'but': 0.13482119119486316},
#  {'prc': 0.40470854387591565,
#   'roof': 0.3089334038117898,
#   'manage': 0.2854471343608382,
#   'job': 0.1973064173462238,
#   'roofer': 0.1937295619949348,
#   'consult': 0.18761023290572876,
#   'spec': 0.18286371250913833,
#   'investment': 0.17898552296270573,
#   'phoenix_area': 0.1728661938734997,
#   'installation': 0.16424148393047663,
#   'roughly': 0.15812215484127062,
#   'tile': 0.15134827712344212,
#   'inspection': 0.1486291140480898,
#   'initial': 0.14475092450165716,
#   'replacement': 0.14147196196100065},
#  {'par': 0.4324135488624605,
#   'bagel': 0.3539170635355558,
#   'awful': 0.333523002363438,
#   'rude': 0.2780159973639472,
#   'help': 0.23816507314669358,
#   'seem': 0.23410483743683053,
#   'want_to': 0.21014804845920262,
#   'staff': 0.2023563151812277,
#   'not': 0.1976089548132943,
#   'never': 0.19665103786574664,
#   'always': 0.18966406068199473,
#   'up': 0.18814185766813415,
#   'nice': 0.18208608124590753,
#   'out': 0.16467543382722039,
#   'to': 0.16106389182277894},
#  {'practice': 0.3106428666975689,
#   'room': 0.3091993276210978,
#   'compromise': 0.20126105876865114,
#   'friendly_welcome': 0.20126105876865114,
#   'elbow': 0.19861341868504373,
#   'facility_clean': 0.19621833689515106,
#   'factory': 0.192020378220376,
#   'friendly_professional': 0.19015809388773017,
#   'first_timer': 0.1884243486522259,
#   'accessible': 0.18527908164013626,
#   'goal': 0.18527908164013626,
#   'yoga': 0.1811950884155709,
#   'teacher': 0.1799690238549123,
#   'neat': 0.16506572471381878,
#   'push': 0.15867698894117346},
#  {'rude': 0.4319455976227526,
#   'owner': 0.38281139635863104,
#   'odd': 0.2859137423382987,
#   'super_nice': 0.28429049610801593,
#   'mix': 0.2660693619271095,
#   'incredibly': 0.2605016062962052,
#   'idea': 0.23764132940311392,
#   'average': 0.2272610568310872,
#   'space': 0.22588696260545849,
#   'wife': 0.21764159676453199,
#   'hand': 0.2165224025540298,
#   'coffee': 0.20705589574858438,
#   'problem': 0.2063109880116357,
#   'great': 0.10350482652825871,
#   'on': 0.09784521873862527},
#  {'defalco': 0.3525113441947702,
#   'parmigiana': 0.17089321836199953,
#   'bit': 0.17008828155384798,
#   'time': 0.16793738076062772,
#   'ex': 0.1666113817487008,
#   'grub': 0.1666113817487008,
#   'during_busy': 0.1666113817487008,
#   'tricky': 0.1647547653707603,
#   'recommend': 0.16445347382153183,
#   'authentic_italian': 0.1614655555370617,
#   'first_timer': 0.1599934113233334,
#   'favorite_spot': 0.1586163123795211,
#   'unless_want': 0.1586163123795211,
#   'goody': 0.15732272676273149,
#   'hour_wait': 0.1549494355571793},
#  {'sylvia': 0.410998759979718,
#   'charlotte': 0.30018391584141857,
#   'sell': 0.21659113714728995,
#   'apartment': 0.17960971185442506,
#   'to': 0.15581190601746586,
#   'chip': 0.15022726566722844,
#   'notice': 0.13954563919460491,
#   'need': 0.1386638814032971,
#   '626': 0.136999586659906,
#   'give': 0.13639252742495736,
#   'last': 0.12782225338079942,
#   'furnished': 0.12701745367221096,
#   'show': 0.1218305035179789,
#   'graham': 0.11895832947196178,
#   'uptown': 0.11119614720950267},
#  {'individualize': 0.2775921181218601,
#   'fulfil': 0.25736606118997224,
#   'hot_pot': 0.23370309150476107,
#   'hot_water': 0.22784751418321705,
#   'walnut': 0.21514491891964255,
#   'electric': 0.21347703457287326,
#   'temp': 0.21189935132430524,
#   'customize': 0.2104026113510306,
#   'adjust': 0.205082462483591,
#   'pot': 0.19017655441914277,
#   'run_out': 0.18673964166581944,
#   'difficult': 0.18609829646372905,
#   'st': 0.18252075677783156,
#   'in_case': 0.17933431794038068,
#   'locate': 0.16716934338755357},
#  {'rc_wiley': 0.3309889749184002,
#   'purchase': 0.2683689247222126,
#   '500': 0.2620438692966811,
#   'apparently': 0.20503725347792182,
#   'iwent': 0.17286219085359575,
#   'emele': 0.17286219085359575,
#   '2months': 0.17286219085359575,
#   'couldbe': 0.17286219085359575,
#   '2300': 0.1654944874592001,
#   'anything': 0.15600628975180478,
#   'leap': 0.15289931531515225,
#   'pay': 0.1490544232412021,
#   'making': 0.1362494033979927,
#   'supervisor': 0.13397506487969668,
#   'ashley': 0.13397506487969668},
#  {'photo': 0.35869128325239646,
#   'cut': 0.27980067885363746,
#   'show': 0.25089034737351623,
#   'salon': 0.22884814187768873,
#   'exactly': 0.21329433178886767,
#   'hair': 0.2046640318590868,
#   'explain': 0.19630833399126413,
#   'aveda': 0.18006919819143377,
#   'mortify': 0.1743813585493266,
#   'hideous': 0.1633170442671023,
#   'butcher': 0.160676959183028,
#   'try': 0.1599307172710182,
#   'fixed': 0.15834823910094367,
#   'matter_bad': 0.15834823910094367,
#   'big_mistake': 0.15438072479971746},
#  {'napa': 0.329155004337617,
#   'hmmm': 0.3179015366852605,
#   'filter': 0.30204066485766606,
#   'hour_half': 0.2801497694201869,
#   '10_min': 0.2765911605899926,
#   'pull_up': 0.26619745772480535,
#   'take_forever': 0.25799366806447704,
#   'oil': 0.234187021075865,
#   'let_know': 0.232498224011013,
#   'find_out': 0.21466762280792856,
#   'part': 0.2048367745902188,
#   'later': 0.19140403483869345,
#   'not_even': 0.16998394245970563,
#   'guy': 0.15575400203966205,
#   'into': 0.15298808281033358},
#  {'bonus_point': 0.30566065682432125,
#   'laura': 0.30566065682432125,
#   'dive_bar': 0.2857159102961468,
#   'must_see': 0.2750706723253045,
#   'cute_little': 0.2557086698178013,
#   'u_feel': 0.24717849210141452,
#   'chill': 0.2280591362374407,
#   'in_city': 0.2220778436300085,
#   'at_home': 0.20406990507991507,
#   'vibe': 0.2014490946216804,
#   'bartender': 0.19225515954692943,
#   'look_like': 0.18273701826763483,
#   'in_area': 0.1803369490518647,
#   'yummy': 0.17611786480434494,
#   'cut': 0.17455630480800813},
#  {'lay_out': 0.43037836163293797,
#   'in_phoenix': 0.3480138237743919,
#   'interior': 0.3472134287296792,
#   'definitely_come': 0.34117447698432934,
#   'tea': 0.3207687085972031,
#   'unique': 0.30970594779565863,
#   'happy': 0.25034835869678057,
#   'tasty': 0.24233995768015432,
#   'back': 0.18385931714844914,
#   'really': 0.17530917148182554,
#   'well': 0.16676260423001987,
#   'like': 0.15204405928435302,
#   'place': 0.1212260834400744,
#   'to': 0.07956055311024737,
#   'f21': 0.0},
#  {'eggplant': 0.4942114016020078,
#   'northerner': 0.245728901298519,
#   'xlb': 0.245728901298519,
#   'goooood': 0.22782447814305942,
#   'mince': 0.21735106200007207,
#   'obsess': 0.21336925398189704,
#   'americanized': 0.20415611815110563,
#   'dish': 0.20369169677724683,
#   'darn': 0.197379085879111,
#   'obsess_with': 0.197379085879111,
#   'dumpling': 0.17036106698712492,
#   'everything_else': 0.16363779253369343,
#   'to_die': 0.14627719204348447,
#   'sound': 0.14493851827962617,
#   'avoid': 0.14269096024771866},
#  {'beals': 0.42492553383734954,
#   'son': 0.36362289620353017,
#   'dr': 0.2342089037150833,
#   'office': 0.22919144196867497,
#   'minecraft': 0.21246276691867477,
#   'dos': 0.19199856744622923,
#   'conservative': 0.18792664510043963,
#   'feel_rush': 0.1690033145194626,
#   'never_felt': 0.1690033145194626,
#   'satisfied_with': 0.16602105904153971,
#   'med': 0.15890879603411548,
#   'toy': 0.15696550651568292,
#   'wonderful_experience': 0.15696550651568292,
#   'solution': 0.1527390247949236,
#   'answer_question': 0.13370594588229884},
#  {'loco': 0.5546316314543822,
#   'bloodys': 0.3246212502915482,
#   'watering': 0.30096853300936965,
#   'football_game': 0.2773158157271911,
#   'hole': 0.23709579581861254,
#   'since_open': 0.2345669607272088,
#   'mill': 0.23109376288373396,
#   'on_sunday': 0.20233847586236672,
#   'come': 0.17595528549059639,
#   'local': 0.16069047948913448,
#   'great': 0.15270789016000738,
#   'especially': 0.15069934729369347,
#   'breakfast': 0.14946953282944636,
#   'on': 0.14435787602368974,
#   'awesome': 0.12571630396376846},
#  {'skewer': 0.46228590515011264,
#   'kebob': 0.3743182846276093,
#   'barg': 0.19326375807027676,
#   'amex': 0.18715914231380465,
#   'plate': 0.18703905820882932,
#   'koobideh': 0.17855516964855753,
#   'one': 0.1774491978953429,
#   'parsley': 0.16995119698331038,
#   'radish': 0.1638465812268383,
#   'chicken_breast': 0.1605755026332909,
#   'of': 0.14996468803474713,
#   'friendly_attentive': 0.1482717497721934,
#   'two_people': 0.14370708466736257,
#   'flavourful': 0.1405340201398719,
#   'basil': 0.13995261370006684},
#  {'beer': 0.2826171335057411,
#   'cheer_': 0.24948275538198822,
#   'pull_out': 0.22967153251121364,
#   'cell_phone': 0.2262068237593966,
#   'catch_up': 0.2216400857086225,
#   '90': 0.2109572635387033,
#   'eventually': 0.209968282960617,
#   'everytime': 0.20900973743300574,
#   'chat_with': 0.20717683987131758,
#   'hey': 0.20380595730996418,
#   'good': 0.19850248959284525,
#   'im': 0.19544946124472862,
#   'wait_staff': 0.18789360034692681,
#   'weird': 0.18181741020515002,
#   'non': 0.1729547686048325},
#  {'girlfriend': 0.2338796023970248,
#   'encountered': 0.18848302143070852,
#   'epoxy': 0.18848302143070852,
#   'resin': 0.18848302143070852,
#   'attentative': 0.18848302143070852,
#   'william': 0.17474967644978873,
#   'equate': 0.17032852686365027,
#   '10_buck': 0.17032852686365027,
#   'residue': 0.16671618462648355,
#   'feel': 0.16508125293817072,
#   '05': 0.15868269280317834,
#   'sticker': 0.15868269280317834,
#   'bucket': 0.15298283964556372,
#   'server': 0.1520186708607997,
#   'table': 0.14350341115748502},
#  {'mission': 0.3654056985064253,
#   'on_menu': 0.21337451450490527,
#   'great': 0.2068967583112299,
#   'upside_down': 0.18786109624811098,
#   'candle': 0.1718381175866707,
#   'skeptical': 0.15974257124771743,
#   'melt_in': 0.15809070640982026,
#   'wine_list': 0.15510381289805644,
#   'huge_fan': 0.15510381289805644,
#   'caramel': 0.15441372368620723,
#   'live_up': 0.15374363990343454,
#   'date_night': 0.15245907211719084,
#   'possibly': 0.15184260166773983,
#   'setting': 0.15124214526247284,
#   'to_perfection': 0.1464422972584325},
#  {'bubble_tea': 0.4223054006352253,
#   'thai_food': 0.3954292516734932,
#   'curry': 0.352006297460273,
#   'mango': 0.3512554988469639,
#   'polite': 0.34161992379274525,
#   'especially': 0.2669128907480535,
#   'ever': 0.21796311634843935,
#   'everything': 0.20875229468906656,
#   'nice': 0.184814089162862,
#   'best': 0.18216468756172643,
#   'love': 0.17619380268800539,
#   'service': 0.1493313881908567,
#   'great': 0.1352351723302704,
#   'fabrication': 0.0,
#   'fa': 0.0},
#  {'hoodies': 0.40757910746763837,
#   'antigua': 0.40757910746763837,
#   'shop': 0.3721092346534179,
#   'fortunate': 0.3386242643025518,
#   'saving': 0.3386242643025518,
#   'several_year': 0.30892702978572173,
# ...
#   'whether': 0.15662772258419547},
#  {'pie': 0.47414042002412105,
#   'cabbage': 0.22221935852147823,
#   'chop': 0.22221935852147823,
#   'flavour': 0.1843548386316632,
#   'texture': 0.18232334814959883,
#   'ilicious': 0.1545555886511573,
#   'julienne': 0.14796814619479978,
#   'apricot': 0.14329428139088615,
#   'finely': 0.13420240954550322,
#   'braised': 0.13203297413061502,
#   'beef_rib': 0.13203297413061502,
#   'large_piece': 0.13203297413061502,
#   'enjoy': 0.12482226342552269,
#   'savoury': 0.12414510724733048,
#   'butter_chicken': 0.12414510724733048},
#  {'tom': 0.4259749275842773,
#   'philly': 0.41858877959181046,
#   'cause': 0.32447531087089665,
#   'steak': 0.289389012212509,
#   'pizza': 0.25199085718438985,
#   'cheese': 0.25026535219237417,
#   'amaze': 0.22356629523016916,
#   'ever': 0.21726439508184242,
#   'little': 0.20079990254032049,
#   'take': 0.17616522659606168,
#   'well': 0.17077840261635224,
#   'one': 0.1679293320736234,
#   'order': 0.15704789560235327,
#   'great': 0.134801650858922,
#   'food': 0.13007099932158062},
#  {'alternator': 0.28658723301001005,
#   'safety': 0.2762476529101396,
#   'vehicle': 0.22136584433002926,
#   'ron': 0.21641056675615514,
#   'check': 0.17655538242914887,
#   'new_battery': 0.15886568445162516,
#   'to': 0.15320298151757458,
#   'assistant_manager': 0.1492212697127355,
#   'say': 0.14605828991067835,
#   'despite': 0.14365007162616636,
#   'call': 0.1385075456728474,
#   'on': 0.13311802252814034,
#   'cost': 0.12172835781427478,
#   'clamp': 0.11463489320400401,
#   'rav': 0.11463489320400401},
#  {'wic': 0.622020097772045,
#   'store': 0.3113091530579116,
#   'tell': 0.19312055563486646,
#   'call': 0.17131494417384144,
#   'manager': 0.16500640168656994,
#   'cashier': 0.16427961557979698,
#   'take': 0.16388422005217776,
#   'sign_post': 0.15431636074439103,
#   'front': 0.1523174099913763,
#   'to': 0.13896020903071027,
#   'speak_with': 0.12129353658186962,
#   'milk': 0.11997428459051995,
#   'say': 0.1083925110099464,
#   'window': 0.10354846241882937,
#   'on': 0.0987893034440412},
#  {'aside': 0.4247402224954444,
#   'in_charlotte': 0.3690180797697811,
#   'likely': 0.35581640427142425,
#   'sushi': 0.27914426299377537,
#   'charge': 0.26044110760933215,
#   'place': 0.23927594062688062,
#   'amazing': 0.23570761693404615,
#   'go_back': 0.2179583094398324,
#   'over': 0.19892284026996546,
#   'drink': 0.19634208407116743,
#   'nice': 0.17753309001808484,
#   'well': 0.16457794336089018,
#   'would': 0.15374989923219956,
#   'service': 0.14344827768434182,
#   'great': 0.12990740117093638},
#  {'cursing': 0.37229578592793283,
#   'word': 0.3013395055253541,
#   'nasty': 0.2720493390452659,
#   'puta': 0.26770267818981086,
#   'in_front': 0.22282939547973066,
#   'disrespectful': 0.20918621547624397,
#   'korean': 0.177121998997771,
#   'customer': 0.17303050536672945,
#   'unprofessional': 0.16930931139048583,
#   'worker': 0.16686077033019872,
#   'totally': 0.14794773559291974,
#   'use': 0.1474536328729144,
#   'understand': 0.13620707767498252,
#   'insults': 0.13385133909490543,
#   'chingado': 0.13385133909490543},
#  {'26th': 0.25022314738079116,
#   'stunna': 0.25022314738079116,
#   'wknd': 0.23955817823276493,
#   'gaudy': 0.2319912622003254,
#   'grown': 0.2319912622003254,
#   'anyhow': 0.20098904050287345,
#   'first_trip': 0.19903977478102153,
#   'definitely': 0.18978823487924024,
#   'living_room': 0.1896581357770414,
#   'sexy': 0.18837480563299527,
#   'spent': 0.17988488084920623,
#   'living': 0.17419755354334138,
#   'gold': 0.173476876946119,
#   'shade': 0.173476876946119,
#   'suite': 0.16076128144854937},
#  {'dentist': 0.5943621857158382,
#   'resident': 0.30918548637822746,
#   'teeth': 0.2217809438255455,
#   'crown': 0.16965285145728123,
#   'schedule_appointment': 0.15459274318911373,
#   'problem': 0.14535552720048975,
#   'change': 0.143631821741046,
#   'find_out': 0.1192327640342504,
#   'to': 0.11753721258698693,
#   'work': 0.10529467006609738,
#   'implant': 0.1033460789560567,
#   'drawn': 0.1033460789560567,
#   'coaching': 0.09894127965921738,
#   'extraction': 0.09581602482197293,
#   'without': 0.0944141227997104},
#  {'francisco': 0.24931123364150767,
#   'anne': 0.23785004070766746,
#   'from_san': 0.22638884777382723,
#   'marie': 0.22071653340973635,
#   'fell_in': 0.21194945234261925,
#   'last_weekend': 0.20841149333969805,
#   'adorable': 0.2024384657159532,
#   'yard': 0.1998669864919697,
#   'picky': 0.19751005691141124,
#   'drink': 0.19118848639178418,
#   'much_fun': 0.19053211744323564,
#   'hidden_gem': 0.1879990702847452,
#   'last_year': 0.18642828953776125,
#   'blast': 0.1790709245093954,
#   'super_nice': 0.17372166257373142},
#  {'vicuna': 0.4875346418949566,
#   'million': 0.360186036917594,
#   'thorough': 0.32257096169904464,
#   'not_mind': 0.31238008412144713,
#   'fabulous': 0.29721834883902143,
#   'question': 0.2845475269595723,
#   'lol': 0.28216342971586533,
#   'patient': 0.2724328742335428,
#   'dr': 0.26871756321673657,
#   'ask': 0.18865737906605176,
#   'fabian': 0.0,
#   'f13': 0.0,
#   'f21': 0.0,
#   'f_ckin': 0.0,
#   'f_cking': 0.0},
#  {'club': 0.5073831708756263,
#   'hard_rock': 0.34996027123652207,
#   'rain': 0.33208499465907587,
#   'currently': 0.31041460547257926,
#   'on_sunday': 0.27674875530814064,
#   'hand_down': 0.27301294726178005,
#   'similar': 0.2684558977711641,
#   'in_vega': 0.2162848565893255,
#   'hot': 0.19972669523327038,
#   'night': 0.18059557559345168,
#   'new': 0.17566159910052426,
#   'best': 0.14067379953281992,
#   'place': 0.09617757552773178,
#   'in': 0.0842185071683177,
#   'to': 0.0631212432889619},
#  {'call': 0.30575265090181114,
#   'associate': 0.2443102896569947,
#   'clicklist': 0.21690363910316748,
#   'email': 0.20674549814940274,
#   'husband': 0.20617166832878614,
#   'cell_phone': 0.17294412591780275,
#   'to': 0.1610440633826556,
#   'confirm': 0.15405284380621853,
#   'store': 0.14882301683427596,
#   'of': 0.1472697262768468,
#   'take': 0.13928130456028093,
#   'well': 0.13502232629409394,
#   'number': 0.13268881575082098,
#   'order': 0.12416659178770971,
#   'nellis': 0.11328002169478552},
#  {'rock': 0.355231216565805,
#   'granny': 0.29375977447238033,
#   'yardbird': 0.23367094516530248,
#   'back_soon': 0.22954755588011547,
#   'exception': 0.22115036517710757,
#   'dude': 0.21576641108018302,
#   'chic': 0.21455529311612206,
#   'legit': 0.21226687230121422,
#   'find_new': 0.21118326814440194,
#   'fry_chicken': 0.20049041385648086,
#   'gluten_free': 0.19498618872231294,
#   'favorite_place': 0.1882219132255036,
#   'country': 0.18225625505238835,
#   'hate': 0.1776156082829025,
#   'make': 0.167101747494005},
#  {'argumentative': 0.26053205619568787,
#   '00am': 0.2291052147856892,
#   '00pm': 0.21858610038406964,
#   'operation': 0.21264638038032765,
#   'many_option': 0.20226512621574905,
#   'on_website': 0.19663804258965967,
#   'professionalism': 0.19663804258965967,
#   'horrible_service': 0.19372645255434442,
#   'acknowledge': 0.19281825107398795,
#   'lead_to': 0.18715925897407104,
#   'communication': 0.18572866369267962,
#   'in_charlotte': 0.18182179161106932,
#   'walk_away': 0.1806297047989917,
#   '45': 0.17630360017517036,
#   'pm': 0.17483630707755882},
#  {'carl': 0.650745793773664,
#   'ok': 0.31936030759122114,
#   'burger': 0.30828031086176333,
#   'jr': 0.3006099714854195,
#   'n_out': 0.2594300929302149,
#   'think': 0.25126586396477224,
#   'truly': 0.184213333391255,
#   'far': 0.17112912431515834,
#   'cool': 0.16794131086087363,
#   'big': 0.14038592161718905,
#   'thing': 0.12232502229562366,
#   'people': 0.11955906399062273,
#   'go': 0.07783679898722302,
#   'good': 0.07588559659120607,
#   'in': 0.06446459307390628},
#  {'bff': 0.5927083826001434,
#   'happy_hour': 0.3435469182917895,
#   'meet': 0.3292140225027445,
#   'love_place': 0.3100209205223109,
#   'atmosphere': 0.28260906527751106,
#   'everything': 0.22477793890137693,
#   'drink': 0.22008557928096723,
#   'price': 0.21129839242031706,
#   'come': 0.16778492011137844,
#   'service': 0.16079536610995745,
#   'great': 0.14561700195271096,
#   'food': 0.14050680270988736,
#   'to': 0.08801343004622263,
#   'faanncyyy': 0.0,
#   'fab': 0.0},
#  {'kelly': 0.2943505945793084,
#   'drink': 0.281569485956105,
#   'table': 0.22613761546257402,
#   'crumbs': 0.19801202251443709,
#   'to': 0.1970520676027334,
#   'abound': 0.18957238720027886,
#   'mysterious': 0.18957238720027886,
#   'bar': 0.1662522622333503,
#   'stain': 0.15115205506953025,
#   'wipe': 0.15008440044269317,
#   'regardless_of': 0.14810054747189505,
#   '22': 0.14810054747189505,
#   'sticky': 0.1446233665157435,
#   'let_start': 0.1416447651285349,
#   'pay_attention': 0.1416447651285349},
#  {'lunch': 0.28802953947539345,
#   'ravi': 0.2739533126593842,
#   'wrap': 0.17321412945671624,
#   'combo': 0.17321412945671624,
#   'space': 0.15561322381398685,
#   'to': 0.15084149975566025,
#   'about': 0.14290029121756914,
#   'blackboard': 0.14053210472458977,
#   'large': 0.1377577953713423,
#   'communal_table': 0.1369766563296921,
#   'today': 0.13611436092918994,
#   'prefect': 0.134071643468507,
#   'lucky_enough': 0.1276111822124242,
#   'return_soon': 0.12593242486508002,
#   'turn_down': 0.12441380412158595},
#  {'update_review': 0.3675408309804858,
#   'edible': 0.3288389442439755,
#   'min': 0.3030203901623882,
#   '3_star': 0.29456774193615193,
#   'solid': 0.27999199963133076,
#   'average': 0.24290933289222222,
#   'fix': 0.23794908723962838,
#   'sushi': 0.2377248560452593,
#   'fish': 0.2377248560452593,
#   'quick': 0.223445122678284,
#   'good': 0.2100471241478408,
#   'house': 0.2081436975279477,
#   'come_back': 0.19429022391023743,
#   'since': 0.18538426503606018,
#   'from': 0.13029554042210176},
#  {'vietnamese': 0.4232751617000249,
#   'egg_roll': 0.40953487281188095,
#   'compliment': 0.39008590937277565,
#   'pho': 0.36511898701872636,
#   'crispy': 0.3183035811595455,
#   'prepare': 0.31711558275968676,
#   'hear': 0.29920547910874723,
#   'delicious': 0.20194805389247503,
#   'nice': 0.1882924222010749,
#   'fabreze': 0.0,
#   'fabrication': 0.0,
#   'eyes': 0.0,
#   'ez': 0.0,
#   'ezmart': 0.0,
#   'f13': 0.0},
#  {'safe': 0.4572126280092666,
#   'inch': 0.173235149516251,
#   'wide': 0.1723763989334821,
#   'agree': 0.14849946222035332,
#   'foot': 0.14371717318819327,
#   'call': 0.13937310049883345,
#   'four': 0.13061469524940864,
#   'scuffed': 0.12048662495786827,
#   'covering': 0.12048662495786827,
#   'highlander': 0.12048662495786827,
#   'indentation': 0.12048662495786827,
#   'spend': 0.12023595340923025,
#   'move': 0.11616238538489253,
#   'linoleum': 0.1153512641753985,
#   'seamlessly': 0.1153512641753985},
#  {'venetian': 0.22720526512923103,
#   'evolve': 0.20526971277702227,
#   'aspect_of': 0.18322015145158527,
#   'indeed': 0.16673723264097456,
#   'room': 0.15288166136719902,
#   'shopping': 0.14633579474258354,
#   'to': 0.1344313817175116,
#   'of': 0.13171421428340355,
#   'crowd': 0.12389945383164794,
#   'ambition': 0.11820049057967791,
#   'troubadors': 0.11820049057967791,
#   'dubai': 0.11820049057967791,
#   'disneyworld': 0.11820049057967791,
#   'auspex': 0.11820049057967791,
#   'straddle': 0.11820049057967791},
#  {'2000': 0.5232194405767273,
#   'chill': 0.4129811612045663,
#   'vibe': 0.3647943353335036,
#   'sandwich': 0.2836052975344779,
#   'pizza': 0.2802791657612144,
#   'since': 0.2512432088426145,
#   'awesome': 0.246866048947193,
#   'eat': 0.2156189472105625,
#   'love': 0.19534496111831443,
#   'food': 0.1446726741871588,
#   'good': 0.14233385306137328,
#   'but': 0.11712559978617357,
#   'f13': 0.0,
#   'ezmart': 0.0,
#   'ez': 0.0},
#  {'salon': 0.3114638306654333,
#   'tea': 0.293448393057071,
#   'bang': 0.28044926597517805,
#   'stylist': 0.2601423748706086,
#   'hair': 0.20891182305185532,
#   'cut_hair': 0.19540633447258274,
#   'layer': 0.1774721677969426,
#   'wavy': 0.12799297860439246,
#   'swept': 0.12799297860439246,
#   'to': 0.12737247341023986,
#   'blunt': 0.12253768327193269,
#   'fringe': 0.12253768327193269,
#   'person': 0.12160789609497544,
#   'converse': 0.11566482396713629,
#   'forehead': 0.11566482396713629},
#  {'really': 0.2193268262444871,
#   'table': 0.19990091022115897,
#   'carcassonne': 0.17503847581659665,
#   'slat': 0.17503847581659665,
#   'to': 0.1741898958038097,
#   'lattes': 0.16757801516840307,
#   'overlooked': 0.16757801516840307,
#   '22nd': 0.15817894632626117,
#   'couch_area': 0.1548242734516329,
#   'snake': 0.1519879379501407,
#   'lo': 0.14736381280343927,
#   'criticism': 0.14736381280343927,
#   'table_ready': 0.1436715201824386,
#   'behold': 0.1436715201824386,
#   'board_game': 0.1436715201824386},
#  {'great_job': 0.42232130905762144,
#   'nail': 0.4043224263522742,
#   'veena': 0.3527055038622621,
#   'kathy': 0.31197354252035325,
#   'nail_shop': 0.30130749119839667,
#   'fav': 0.25355922584000257,
#   'not_mind': 0.22599045380313643,
#   'friendly_staff': 0.20729509113960934,
#   'daughter': 0.19709076221067606,
#   'love_place': 0.1766223618620969,
#   'busy': 0.15682634589173342,
#   'around': 0.14086412346576768,
#   'clean': 0.1398383638299401,
#   'wait': 0.12027356212037416,
#   'always': 0.11809200180378755},
#  {'watermelon': 0.48425143576327295,
#   'spiced': 0.22271382372071072,
#   'chicken': 0.21562892980542617,
#   'well_seasoned': 0.21532076205572817,
#   'not_overly': 0.18822952667501308,
#   'fry_chicken': 0.182954164659293,
#   'fried_chicken': 0.18096425940255598,
#   'totally': 0.14814828220883475,
#   'doubtful': 0.13403277771566968,
#   'persistently': 0.13403277771566968,
#   'mean': 0.13178582831262595,
#   'with': 0.13007210501789565,
#   'greasiness': 0.12832005507539965,
#   'issue': 0.126039865182188,
#   'juiciness': 0.12426681385776893},
#  {'doughy': 0.5552021868031088,
#   'tasteless': 0.47385553957085086,
#   'yummy': 0.35241634375243897,
#   'dry': 0.3508375012218335,
#   'pot_sticker': 0.292612406971627,
#   'chicken_wing': 0.2495497088846215,
#   'fried_rice': 0.2386108984671765,
#   'not': 0.12286166608916291,
#   'f_ckin': 0.0,
#   'eyeliner': 0.0,
#   'eyes': 0.0,
#   'ez': 0.0,
#   'ezmart': 0.0,
#   'f13': 0.0,
#   'f21': 0.0},
#  {'thing_happen': 0.3182836315707114,
#   'ihop': 0.31498416124553175,
#   'another': 0.30482898853890944,
#   'denny': 0.2914655187056554,
#   'nope': 0.27658405285804183,
#   'give_another': 0.2676363558785354,
#   'burnt': 0.25863964418076546,
#   'figure': 0.2473916922886353,
#   'shot': 0.2432954224594881,
#   'toast': 0.23129774570158648,
#   'to': 0.22299504314550259,
#   'honestly': 0.2150024118525274,
#   'go': 0.1796225799999906,
#   'think': 0.1449604279034126,
#   'find': 0.13283348342751894},
#  {'gift_card': 0.5356502460732137,
#   'sarra': 0.3557590677196644,
#   'herbst': 0.3557590677196644,
#   'issue': 0.3345437265192572,
#   'nearby': 0.2267405228965142,
#   'terrible': 0.1974169715258945,
#   'thanks': 0.1818942805009397,
#   'receive': 0.1738728952530467,
#   'worth': 0.16063559778455977,
#   'store': 0.15579427843814608,
#   'with': 0.13809855053713757,
#   'leave': 0.1335173009396165,
#   'use': 0.13063738551904738,
#   'one_of': 0.1278789684249699,
#   'after': 0.11438461504138898},
#  {'to': 0.24537903103631686,
#   '911': 0.22032729706992057,
#   'painter': 0.20355900298814603,
#   'wide_open': 0.19982986146561854,
#   'dangerous': 0.18485435296492897,
#   'complex': 0.16808605888315445,
#   'addict': 0.1638309937191882,
#   'living': 0.16021359158569434,
#   'paint': 0.15428370313253187,
#   'apartment': 0.15085695973147029,
#   'home': 0.14940161084892767,
#   'management': 0.1380471125356631,
#   'come': 0.1247412691383239,
#   'live': 0.12114479298799927,
#   'door': 0.11897311893036937},
#  {'gm': 0.4958193584745427,
#   'hire': 0.3591664886734159,
#   'would_highly': 0.34858448179957424,
#   'ice_cream': 0.29606357222180685,
#   'worth': 0.2531067730227427,
#   'recommend': 0.2270719583095658,
#   'new': 0.22177400285138751,
#   'since': 0.22093553600986438,
#   'location': 0.21947376574031963,
#   'use': 0.2058398483329968,
#   'make': 0.15943241376658512,
#   'to': 0.15938202613239885,
#   'like': 0.15229337456059955,
#   'come': 0.1519194315445378,
#   'place': 0.12142486473165136},
#  {'many': 0.305177945985348,
#   'breakfast_burrito': 0.2848936237085038,
#   'rainbow': 0.2848936237085038,
#   'fresh_delicious': 0.2770791220438269,
#   'freshly_make': 0.2601270016324537,
#   'donut': 0.2557956621275905,
#   'creative': 0.24510856512697446,
#   'pastry': 0.23736493139356957,
#   'delish': 0.23489159758863426,
#   'solid': 0.2205256316815442,
#   'yum': 0.21890281697686687,
#   'regular': 0.18602111272097738,
#   'fast': 0.18212367093607224,
#   'stuff': 0.17705915274694944,
#   'breakfast': 0.17057462675139923},
#  ...]

# %%
len(tfidf_final)
# Out:
# 9958

# %%
list(tfidf_final[1])
# Out:
# ['travis',
#  'blowout',
#  'hair',
#  'perfectly',
#  'shampoo',
#  'stylist',
#  'way',
#  'pagent',
#  'scented',
#  'swoosh',
#  'admirable',
#  'bouncey',
#  'beauuuutiful',
#  'style',
#  'greets']

# %%
wordlist = []
for i in range(len(tfidf_final)):
    wordlist.extend(list(tfidf_final[i]))

# %%
wordlist = list(set(wordlist))

# %%
wordfreq  = 0
for i in range(len(tfidf_final)):
    if wordlist[1] in tfidf_final[i]:
        wordfreq += 1

# %%
len(wordlist)
# Out:
# 21690

# %%
freq =[0]*21690
for i in range(len(wordlist)):
    for j in range(len(tfidf_final)):
        if wordlist[i] in tfidf_final[j]:
            freq[i]  += 1

# %%
freq_final = sorted(freq,reverse = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-e19644d0b570> in <module>()
# ----> 1 freq_final = freq,reverse = True
#
# TypeError: 'bool' object is not iterable

# %%
mydict = dict(zip(wordlist,freq))

# %%
dictfinal = sorted(mydict.items(),key = lambda item:item[1],reverse = True)

# %%
dictfinal
# Out:
# [('to', 1438),
#  ('great', 666),
#  ('food', 657),
#  ('not', 642),
#  ('for', 551),
#  ('good', 520),
#  ('place', 470),
#  ('f13', 466),
#  ('of', 464),
#  ('ezmart', 454),
#  ('service', 434),
#  ('f21', 408),
#  ('with', 394),
#  ('get', 388),
#  ('but', 383),
#  ('in', 377),
#  ('ez', 368),
#  ('f_ckin', 366),
#  ('order', 364),
#  ('love', 328),
#  ('go', 317),
#  ('best', 304),
#  ('always', 281),
#  ('pizza', 272),
#  ('f_cking', 262),
#  ('eyes', 244),
#  ('time', 228),
#  ('drink', 225),
#  ('try', 222),
#  ('awesome', 221),
#  ('burger', 221),
#  ('on', 218),
#  ('delicious', 214),
#  ('at', 213),
#  ('restaurant', 211),
#  ('chicken', 210),
#  ('nice', 205),
#  ('f_ing', 204),
#  ('like', 204),
#  ('wait', 202),
#  ('staff', 200),
#  ('come', 198),
#  ('price', 196),
#  ('amaze', 196),
#  ('eat', 193),
#  ('would', 188),
#  ('work', 185),
#  ('sandwich', 185),
#  ('one', 183),
#  ('location', 183),
#  ('store', 178),
#  ('well', 176),
#  ('breakfast', 168),
#  ('make', 168),
#  ('really', 167),
#  ('fa', 164),
#  ('room', 163),
#  ('fresh', 162),
#  ('clean', 160),
#  ('eyeliner', 154),
#  ('amazing', 153),
#  ('fry', 151),
#  ('car', 148),
#  ('take', 147),
#  ('out', 147),
#  ('dish', 146),
#  ('server', 146),
#  ('say', 146),
#  ('excellent', 145),
#  ('one_of', 144),
#  ('friendly', 142),
#  ('salad', 135),
#  ('definitely', 135),
#  ('flavor', 134),
#  ('also', 134),
#  ('people', 134),
#  ('bad', 134),
#  ('everything', 133),
#  ('table', 133),
#  ('coffee', 133),
#  ('from', 132),
#  ('tell', 132),
#  ('sushi', 132),
#  ('need', 130),
#  ('menu', 129),
#  ('taco', 129),
#  ('little', 129),
#  ('sauce', 129),
#  ('find', 128),
#  ('meal', 127),
#  ('experience', 126),
#  ('buffet', 125),
#  ('guy', 124),
#  ('ever', 124),
#  ('back', 124),
#  ('customer_service', 123),
#  ('highly_recommend', 122),
#  ('call', 122),
#  ('waitress', 120),
#  ('use', 120),
#  ('love_place', 120),
#  ('owner', 119),
#  ('atmosphere', 116),
#  ('recommend', 116),
#  ('soup', 114),
#  ('kid', 114),
#  ('shop', 113),
#  ('never', 112),
#  ('fab', 111),
#  ('favorite', 111),
#  ('hotel', 110),
#  ('friend', 109),
#  ('give', 108),
#  ('bar', 107),
#  ('really_good', 106),
#  ('beer', 106),
#  ('dog', 105),
#  ('taste', 104),
#  ('quality', 103),
#  ('new', 101),
#  ('quick', 100),
#  ('cheese', 100),
#  ('ca_not', 100),
#  ('after', 100),
#  ('customer', 100),
#  ('look', 100),
#  ('year', 99),
#  ('thing', 99),
#  ('go_back', 99),
#  ('see', 99),
#  ('visit', 98),
#  ('meat', 98),
#  ('item', 98),
#  ('enjoy', 98),
#  ('fun', 97),
#  ('day', 97),
#  ('know', 97),
#  ('faanncyyy', 97),
#  ('fantastic', 96),
#  ('ice_cream', 95),
#  ('spot', 95),
#  ('small', 95),
#  ('fabreze', 94),
#  ('fast', 94),
#  ('come_back', 93),
#  ('way', 93),
#  ('sweet', 93),
#  ('family', 93),
#  ('roll', 93),
#  ('night', 93),
#  ('professional', 93),
#  ('employee', 93),
#  ('dinner', 93),
#  ('for_lunch', 92),
#  ('wife', 92),
#  ('dr', 92),
#  ('shrimp', 92),
#  ('seat', 91),
#  ('steak', 91),
#  ('even', 91),
#  ('pretty', 90),
#  ('super', 90),
#  ('much', 90),
#  ('help', 90),
#  ('wonderful', 90),
#  ('special', 90),
#  ('show', 90),
#  ('thank', 90),
#  ('husband', 89),
#  ('company', 89),
#  ('waiter', 88),
#  ('这意味着他们的厨房里有很多蟑螂', 88),
#  ('yummy', 88),
#  ('first_time', 88),
#  ('worth', 87),
#  ('about', 87),
#  ('lunch', 87),
#  ('beef', 87),
#  ('over', 87),
#  ('tasty', 87),
#  ('busy', 86),
#  ('manager', 86),
#  ('perfect', 86),
#  ('spicy', 86),
#  ('hair', 85),
#  ('dessert', 85),
#  ('by', 85),
#  ('think', 85),
#  ('selection', 85),
#  ('want', 85),
#  ('fabian', 85),
#  ('bit', 85),
#  ('lot_of', 84),
#  ('nail', 84),
#  ('bread', 84),
#  ('fish', 83),
#  ('hot', 83),
#  ('plate', 82),
#  ('serve', 82),
#  ('wine', 82),
#  ('free', 82),
#  ('close', 82),
#  ('thanks', 81),
#  ('buy', 81),
#  ('happy_hour', 81),
#  ('today', 81),
#  ('right', 80),
#  ('sure', 80),
#  ('beautiful', 80),
#  ('wing', 80),
#  ('rice', 79),
#  ('noodle', 79),
#  ('check', 78),
#  ('ask_for', 78),
#  ('business', 78),
#  ('in_town', 78),
#  ('in_vega', 78),
#  ('still', 78),
#  ('staff_friendly', 78),
#  ('happy', 77),
#  ('egg', 77),
#  ('fix', 77),
#  ('eyelash', 76),
#  ('wo_not', 75),
#  ('definitely_back', 75),
#  ('everyone', 74),
#  ('cake', 74),
#  ('cheap', 74),
#  ('helpful', 74),
#  ('appointment', 74),
#  ('usually', 74),
#  ('every_time', 74),
#  ('rude', 73),
#  ('pretty_good', 73),
#  ('option', 73),
#  ('game', 73),
#  ('look_for', 73),
#  ('two', 73),
#  ('portion', 72),
#  ('friendly_staff', 72),
#  ('side', 72),
#  ('house', 72),
#  ('especially', 71),
#  ('daughter', 70),
#  ('burrito', 70),
#  ('quite', 70),
#  ('charge', 70),
#  ('before', 70),
#  ('up', 69),
#  ('cool', 69),
#  ('cook', 69),
#  ('leave', 69),
#  ('return', 68),
#  ('ok', 68),
#  ('could', 68),
#  ('home', 68),
#  ('job', 68),
#  ('area', 68),
#  ('hour', 68),
#  ('big', 68),
#  ('stay', 68),
#  ('delivery', 68),
#  ('fabric', 67),
#  ('line', 67),
#  ('move', 67),
#  ('bartender', 67),
#  ('come_out', 66),
#  ('girl', 66),
#  ('pay', 66),
#  ('stop', 65),
#  ('fabulous', 65),
#  ('huge', 65),
#  ('name', 65),
#  ('open', 65),
#  ('party', 65),
#  ('choice', 65),
#  ('massage', 65),
#  ('keep', 64),
#  ('care', 64),
#  ('seem', 64),
#  ('wow', 64),
#  ('inside', 63),
#  ('old', 63),
#  ('although', 63),
#  ('cold', 62),
#  ('cut', 62),
#  ('make_sure', 62),
#  ('son', 62),
#  ('play', 62),
#  ('average', 62),
#  ('fabrication', 62),
#  ('something', 61),
#  ('appetizer', 61),
#  ('expensive', 61),
#  ('style', 61),
#  ('park', 61),
#  ('would_recommend', 60),
#  ('music', 60),
#  ('pick_up', 60),
#  ('different', 60),
#  ('local', 60),
#  ('bowl', 60),
#  ('vega', 60),
#  ('decent', 60),
#  ('authentic', 60),
#  ('water', 59),
#  ('repair', 59),
#  ('nothing', 59),
#  ('issue', 59),
#  ('lady', 59),
#  ('must', 59),
#  ('want_to', 59),
#  ('on_menu', 59),
#  ('fabrice', 58),
#  ('in_area', 58),
#  ('actually', 58),
#  ('fabricate', 58),
#  ('outstanding', 58),
#  ('10', 58),
#  ('veggie', 58),
#  ('could_not', 58),
#  ('stuff', 58),
#  ('ask', 58),
#  ('problem', 58),
#  ('pool', 58),
#  ('offer', 58),
#  ('5_star', 58),
#  ('chip', 57),
#  ('sit', 57),
#  ('crepe', 57),
#  ('around', 56),
#  ('extremely', 56),
#  ('expect', 56),
#  ('unique', 56),
#  ('long', 56),
#  ('many', 56),
#  ('to_die', 55),
#  ('cute', 55),
#  ('product', 55),
#  ('pho', 55),
#  ('overall', 55),
#  ('feel', 55),
#  ('lot', 55),
#  ('week', 55),
#  ('half', 55),
#  ('would_definitely', 54),
#  ('take_out', 54),
#  ('salon', 54),
#  ('bring', 54),
#  ('office', 53),
#  ('chef', 53),
#  ('twice', 53),
#  ('large', 53),
#  ('salmon', 53),
#  ('tea', 53),
#  ('boyfriend', 53),
#  ('off', 53),
#  ('star', 53),
#  ('attentive', 53),
#  ('stop_in', 53),
#  ('seafood', 53),
#  ('okay', 53),
#  ('real', 53),
#  ('since', 53),
#  ('anyone', 53),
#  ('disappoint', 53),
#  ('walk_in', 53),
#  ('bbq', 53),
#  ('topping', 52),
#  ('first', 52),
#  ('wish', 52),
#  ('doctor', 52),
#  ('great_job', 52),
#  ('italian', 52),
#  ('bagel', 52),
#  ('hand', 52),
#  ('change', 52),
#  ('regular', 52),
#  ('plus', 52),
#  ('pork', 52),
#  ('club', 51),
#  ('margarita', 51),
#  ('share', 51),
#  ('great_atmosphere', 51),
#  ('money', 51),
#  ('bacon', 51),
#  ('check_out', 50),
#  ('pasta', 50),
#  ('polite', 50),
#  ('decor', 50),
#  ('chocolate', 50),
#  ('drive', 50),
#  ('not_even', 50),
#  ('often', 49),
#  ('in_line', 49),
#  ('great_experience', 49),
#  ('cost', 49),
#  ('return_', 49),
#  ('with_friend', 49),
#  ('taste_like', 49),
#  ('deliver', 49),
#  ('review', 49),
#  ('glad', 48),
#  ('purchase', 48),
#  ('ambiance', 48),
#  ('reason', 48),
#  ('crowd', 48),
#  ('machine', 48),
#  ('affordable', 48),
#  ('pedicure', 48),
#  ('fine', 48),
#  ('dry', 48),
#  ('horrible', 48),
#  ('slow', 48),
#  ('plenty_of', 47),
#  ('kind', 47),
#  ('please', 47),
#  ('wrap', 47),
#  ('pancake', 47),
#  ('cafe', 47),
#  ('sausage', 47),
#  ('definitely_come', 47),
#  ('kitchen', 47),
#  ('enough', 47),
#  ('by_far', 47),
#  ('really_enjoy', 47),
#  ('vegetarian', 47),
#  ('next', 47),
#  ('extra', 46),
#  ('trip', 46),
#  ('althought', 46),
#  ('receive', 46),
#  ('smell', 46),
#  ('size', 46),
#  ('three', 46),
#  ('add', 46),
#  ('anything', 46),
#  ('dress', 46),
#  ('knowledgeable', 46),
#  ('full', 46),
#  ('another', 46),
#  ('sell', 46),
#  ('kind_of', 46),
#  ('happy_with', 45),
#  ('maybe', 45),
#  ('every', 45),
#  ('run', 45),
#  ('next_time', 45),
#  ('selection_of', 45),
#  ('far', 45),
#  ('curry', 45),
#  ('take_care', 45),
#  ('bathroom', 45),
#  ('fast_food', 45),
#  ('price_reasonable', 45),
#  ('thai', 45),
#  ('accommodate', 45),
#  ('event', 45),
#  ('terrible', 44),
#  ('door', 44),
#  ('without', 44),
#  ('absolutely', 44),
#  ('provide', 44),
#  ('vibe', 44),
#  ('able_to', 44),
#  ('bland', 44),
#  ('really_nice', 43),
#  ('tip', 43),
#  ('alalthough', 43),
#  ('brisket', 43),
#  ('floor', 43),
#  ('crispy', 43),
#  ('spend', 43),
#  ('potato', 43),
#  ('month', 43),
#  ('watch', 43),
#  ('for_dinner', 43),
#  ('combo', 43),
#  ('casino', 43),
#  ('salsa', 43),
#  ('town', 43),
#  ('wrong', 43),
#  ('ramen', 42),
#  ('saw', 42),
#  ('hard_to', 42),
#  ('mushroom', 42),
#  ('may', 42),
#  ('patio', 42),
#  ('bean', 42),
#  ('outside', 42),
#  ('decide_to', 42),
#  ('space', 42),
#  ('simple', 42),
#  ('almost', 42),
#  ('brunch', 42),
#  ('crust', 42),
#  ('less', 42),
#  ('favorite_place', 42),
#  ('incredible', 42),
#  ('downtown', 42),
#  ('waffle', 42),
#  ('easy_to', 41),
#  ('bun', 41),
#  ('ready', 41),
#  ('disappointed', 41),
#  ('group', 41),
#  ('pleasant', 41),
#  ('super_friendly', 41),
#  ('pick', 41),
#  ('person', 41),
#  ('spice', 41),
#  ('yes', 41),
#  ('bill', 41),
#  ('mexican', 41),
#  ('start', 41),
#  ('arrive', 41),
#  ('quickly', 41),
#  ('pie', 41),
#  ('include', 41),
#  ('environment', 41),
#  ('yelp', 41),
#  ('class', 41),
#  ('tonight', 41),
#  ('mac_cheese', 40),
#  ('look_forward', 40),
#  ('recommend_place', 40),
#  ('last', 40),
#  ('choose', 40),
#  ('continue_to', 40),
#  ('truly', 40),
#  ('team', 40),
#  ('not_disappoint', 40),
#  ('would_highly', 40),
#  ('loud', 40),
#  ('impressed', 40),
#  ('overprice', 40),
#  ('chinese', 40),
#  ('date', 40),
#  ('patient', 40),
#  ('morning', 40),
#  ('tire', 40),
#  ('miss', 39),
#  ('entree', 39),
#  ('smile', 39),
#  ('hand_down', 39),
#  ('oh', 39),
#  ('vegan', 39),
#  ('flavorful', 39),
#  ('else', 39),
#  ('into', 39),
#  ('down', 39),
#  ('mediocre', 39),
#  ('whole', 39),
#  ('rib', 39),
#  ('ingredient', 39),
#  ('treat', 39),
#  ('lamb', 39),
#  ('yum', 39),
#  ('remember', 39),
#  ('homemade', 39),
#  ('high', 39),
#  ('idea', 39),
#  ('bomb', 39),
#  ('fruit', 39),
#  ('dollar', 39),
#  ('crazy', 39),
#  ('reservation', 39),
#  ('relax', 39),
#  ('warm', 38),
#  ('sometimes', 38),
#  ('prepare', 38),
#  ('slice', 38),
#  ('omg', 38),
#  ('deal', 38),
#  ('box', 38),
#  ('spa', 38),
#  ('glass', 38),
#  ('lovely', 38),
#  ('enchilada', 38),
#  ('book', 38),
#  ('mango', 37),
#  ('establishment', 37),
#  ('section', 37),
#  ('dirty', 37),
#  ('grill', 37),
#  ('personable', 37),
#  ('for_brunch', 37),
#  ('put', 37),
#  ('pay_for', 37),
#  ('color', 37),
#  ('stand', 37),
#  ('minute', 37),
#  ('probably', 37),
#  ('complaint', 37),
#  ('rock', 37),
#  ('mom', 37),
#  ('phone', 37),
#  ('meatball', 37),
#  ('in_phoenix', 37),
#  ('extremely_friendly', 37),
#  ('pack', 37),
#  ('incredibly', 37),
#  ('reasonably_price', 37),
#  ('management', 37),
#  ('greasy', 36),
#  ('end', 36),
#  ('walk', 36),
#  ('pad_thai', 36),
#  ('on_weekend', 36),
#  ('on_yelp', 36),
#  ('haircut', 36),
#  ('cocktail', 36),
#  ('asian', 36),
#  ('soft', 36),
#  ('light', 36),
#  ('list', 36),
#  ('wedding', 36),
#  ('replace', 36),
#  ('course', 36),
#  ('diner', 36),
#  ('fill', 36),
#  ('variety', 36),
#  ('live', 36),
#  ('look_at', 36),
#  ('choose_from', 36),
#  ('suck', 35),
#  ('gym', 35),
#  ('welcome', 35),
#  ('stop_by', 35),
#  ('completely', 35),
#  ('couple', 35),
#  ('must_try', 35),
#  ('chair', 35),
#  ('phenomenal', 35),
#  ('online', 35),
#  ('others', 35),
#  ('short', 35),
#  ('on_point', 35),
#  ('finish', 35),
#  ('comfortable', 35),
#  ('over_price', 35),
#  ('someone', 35),
#  ('wait_staff', 35),
#  ('crave', 35),
#  ('excellent_service', 35),
#  ('end_up', 35),
#  ('fly', 35),
#  ('girlfriend', 35),
#  ('four', 34),
#  ('late', 34),
#  ('airport', 34),
#  ('sample', 34),
#  ('awful', 34),
#  ('available', 34),
#  ('hope', 34),
#  ('seriously', 34),
#  ('buck', 34),
#  ('vehicle', 34),
#  ('smoke', 34),
#  ('grab', 34),
#  ('definitely_recommend', 34),
#  ('explain', 34),
#  ('appreciate', 34),
#  ('mean', 34),
#  ('00', 34),
#  ('tv', 34),
#  ('hard', 34),
#  ('20', 34),
#  ('front', 34),
#  ('seating', 34),
#  ('long_time', 34),
#  ('but_still', 34),
#  ('french_toast', 34),
#  ('hungry', 34),
#  ('afternoon', 33),
#  ('hostess', 33),
#  ('feel_like', 33),
#  ('compare_to', 33),
#  ('request', 33),
#  ('drive_thru', 33),
#  ('reasonable_price', 33),
#  ('process', 33),
#  ('onion', 33),
#  ('design', 33),
#  ('travel', 33),
#  ('through', 33),
#  ('last_time', 33),
#  ('let', 33),
#  ('chain', 33),
#  ('garlic', 33),
#  ('flavour', 33),
#  ('toast', 33),
#  ('go_wrong', 33),
#  ('counter', 33),
#  ('top', 33),
#  ('child', 33),
#  ('worker', 33),
#  ('recently', 33),
#  ('chinese_food', 33),
#  ('starbucks', 33),
#  ('forget', 33),
#  ('guest', 33),
#  ('pricey', 33),
#  ('save', 33),
#  ('fan', 33),
#  ('red', 33),
#  ('chipotle', 32),
#  ('read', 32),
#  ('typical', 32),
#  ('new_favorite', 32),
#  ('cozy', 32),
#  ('little_bit', 32),
#  ('cookie', 32),
#  ('neighborhood', 32),
#  ('movie', 32),
#  ('lemon', 32),
#  ('nacho', 32),
#  ('avoid', 32),
#  ('felt', 32),
#  ('believe', 32),
#  ('birthday', 32),
#  ('traditional', 32),
#  ('soda', 32),
#  ('high_quality', 32),
#  ('station', 32),
#  ('groupon', 32),
#  ('beat', 32),
#  ('lol', 32),
#  ('30_minute', 32),
#  ('fairly', 32),
#  ('variety_of', 32),
#  ('coupon', 32),
#  ('delish', 32),
#  ('mall', 32),
#  ('show_up', 32),
#  ('sweet_potato', 32),
#  ('extremely_helpful', 32),
#  ('entire', 32),
#  ('strip', 32),
#  ('ticket', 32),
#  ('guess', 32),
#  ('on_friday', 32),
#  ('venetian', 32),
#  ('lack', 31),
#  ('joint', 31),
#  ('calamari', 31),
#  ('rush', 31),
#  ('staff_always', 31),
#  ('pricing', 31),
#  ('cover', 31),
#  ('detail', 31),
#  ('evening', 31),
#  ('ambience', 31),
#  ('tortilla', 31),
#  ('cashier', 31),
#  ('quote', 31),
#  ('call_back', 31),
#  ('absolutely_love', 31),
#  ('stylist', 31),
#  ('might', 31),
#  ('efficient', 31),
#  ('weekend', 31),
#  ('surprise', 31),
#  ('chili', 31),
#  ('mexican_food', 31),
#  ('pain', 31),
#  ('attitude', 31),
#  ('look_like', 31),
#  ('either', 31),
#  ('salt', 31),
#  ('give_try', 31),
#  ('suite', 31),
#  ('during', 31),
#  ('white', 31),
#  ('top_notch', 31),
#  ('on_top', 31),
#  ('dance', 31),
#  ('totally', 31),
#  ('fajitas', 31),
#  ('several', 31),
#  ('worth_wait', 31),
#  ('couple_of', 31),
#  ('sale', 31),
#  ('hummus', 31),
#  ('50', 30),
#  ('cause', 30),
#  ('facility', 30),
#  ('food_ok', 30),
#  ('guacamole', 30),
#  ('friendly_helpful', 30),
#  ('honest', 30),
#  ('beer_selection', 30),
#  ('original', 30),
#  ('full_of', 30),
#  ('classic', 30),
#  ('ton_of', 30),
#  ('flight', 30),
#  ('venue', 30),
#  ('gem', 30),
#  ('suggest', 30),
#  ('meet', 30),
#  ('super_nice', 30),
#  ('in_charlotte', 30),
#  ('life', 30),
#  ('consider', 30),
#  ('corn', 30),
#  ('wall', 30),
#  ('baby', 30),
#  ('amazing_job', 30),
#  ('second', 30),
#  ('exceptional', 30),
#  ('service_fast', 30),
#  ('tofu', 30),
#  ('great_selection', 30),
#  ('long_wait', 30),
#  ('window', 30),
#  ('quiet', 30),
#  ('presentation', 30),
#  ('woman', 30),
#  ('sashimi', 30),
#  ('nothing_special', 30),
#  ('broth', 30),
#  ('treatment', 30),
#  ('fried_rice', 30),
#  ('chill', 30),
#  ('value', 30),
#  ('non', 29),
#  ('help_u', 29),
#  ('recommendation', 29),
#  ('12', 29),
#  ('eye', 29),
#  ('phoenix', 29),
#  ('double', 29),
#  ('in_city', 29),
#  ('keep_up', 29),
#  ('cheesecake', 29),
#  ('away', 29),
#  ('eyeglass', 29),
#  ('strawberry', 29),
#  ('pleased_with', 29),
#  ('email', 29),
#  ('finally', 29),
#  ('sub', 29),
#  ('avocado', 29),
#  ('street', 29),
#  ('favourite', 29),
#  ('host', 29),
#  ('fan_of', 29),
#  ('in_scottsdale', 29),
#  ('head', 29),
#  ('funny', 29),
#  ('state', 29),
#  ('bite', 29),
#  ('crab', 29),
#  ('easy', 29),
#  ('spinach', 29),
#  ('sit_at', 29),
#  ('stick', 29),
#  ('last_night', 29),
#  ('best_ever', 29),
#  ('definitely_return', 29),
#  ('at_least', 29),
#  ('juicy', 29),
#  ('cup', 29),
#  ('service_excellent', 29),
#  ('snack', 29),
#  ('building', 29),
#  ('pub', 29),
#  ('until', 29),
#  ('apartment', 29),
#  ('salty', 28),
#  ('hit', 28),
#  ('fry_chicken', 28),
#  ('piece_of', 28),
#  ('break', 28),
#  ('point', 28),
#  ('terrific', 28),
#  ('cleaning', 28),
#  ('la', 28),
#  ('understand', 28),
#  ('ice', 28),
#  ('cuisine', 28),
#  ('client', 28),
#  ('disappointing', 28),
#  ('at_bar', 28),
#  ('beyond', 28),
#  ('even_although', 28),
#  ('dont', 28),
#  ('at_home', 28),
#  ('poor', 28),
#  ('fish_taco', 28),
#  ('creative', 28),
#  ('courteous', 28),
#  ('fee', 28),
#  ('toronto', 28),
#  ('reasonable', 28),
#  ('gyro', 28),
#  ('schedule', 28),
#  ('service_quick', 28),
#  ('casual', 28),
#  ('felt_like', 28),
#  ('together', 28),
#  ('wash', 28),
#  ('answer_question', 28),
#  ('gelato', 28),
#  ('empty', 28),
#  ('plan', 28),
#  ('suppose_to', 28),
#  ('20_minute', 28),
#  ('true', 28),
#  ('result', 28),
#  ('turkey', 28),
#  ('already', 28),
#  ('sad', 28),
#  ('hate', 28),
#  ('soon_', 28),
#  ('discount', 27),
#  ('gluten_free', 27),
#  ('parking', 27),
#  ('lobster', 27),
#  ('folk', 27),
#  ('of_course', 27),
#  ('15_minute', 27),
#  ('carpet', 27),
#  ('fried', 27),
#  ('question', 27),
#  ('french', 27),
#  ('vegetable', 27),
#  ('several_time', 27),
#  ('card', 27),
#  ('on_strip', 27),
#  ('def', 27),
#  ('cupcake', 27),
#  ('dip', 27),
#  ('satisfy', 27),
#  ('live_in', 27),
#  ('split', 27),
#  ('one_star', 27),
#  ('fast_service', 27),
#  ('yesterday', 27),
#  ('complete', 27),
#  ('thai_food', 27),
#  ('center', 27),
#  ('3_star', 27),
#  ('foot', 27),
#  ('din', 27),
#  ('system', 27),
#  ('alright', 27),
#  ('in_la', 27),
#  ('hire', 27),
#  ('juice', 27),
#  ('korean', 27),
#  ('definitely_worth', 27),
#  ('seem_like', 27),
#  ('to_vegas', 27),
#  ('truck', 27),
#  ('green', 27),
#  ('part', 27),
#  ('market', 27),
#  ('bad_experience', 27),
#  ('25', 27),
#  ('hang_out', 27),
#  ('scottsdale', 27),
#  ('pet', 27),
#  ('literally', 27),
#  ('desert', 27),
#  ('talk', 27),
#  ('never_disappoint', 27),
#  ('on_saturday', 26),
#  ('carne_asada', 26),
#  ('romantic', 26),
#  ('latte', 26),
#  ('deserve', 26),
#  ('set', 26),
#  ('early', 26),
#  ('group_of', 26),
#  ('friday', 26),
#  ('on_phone', 26),
#  ('booth', 26),
#  ('sunday', 26),
#  ('well_worth', 26),
#  ('normally', 26),
#  ('healthy', 26),
#  ('naan', 26),
#  ('spring_roll', 26),
#  ('butter', 26),
#  ('thick', 26),
#  ('every_day', 26),
#  ('ranch', 26),
#  ('hear', 26),
#  ('bakery', 26),
#  ('pastry', 26),
#  ('bunch_of', 26),
#  ('sign', 26),
#  ('sugar', 26),
#  ('staff_super', 26),
#  ('crew', 26),
#  ('pass', 26),
#  ('overall_great', 26),
#  ('mention', 26),
#  ...]
